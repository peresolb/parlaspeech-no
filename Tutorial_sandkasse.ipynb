# %% [markdown]
# # Tutorial
#
# This notebook demonstrates the whole process of aligning audio files to a collection of transcripts.
#
# The requirements for this process are:
# * a collection of audio files
# * a collection of human transcripts
#
# The two collections above need not be corresponding to each other. We will merge all the transcripts together into one huge file and match the audio to the transcripts automatically.
#
# As an example, we will download a sample MP3 roughly 15 minutes in length and a transcription file that contains much more text than the aforementioned audio. We will also download a language model used for initial speech recognition and some Kaldi models for aligning the matched transcript to the audio.

# %%
# !wget https://github.com/clarinsi/parlaspeech/releases/download/data/sample.mp3
# !wget https://github.com/clarinsi/parlaspeech/releases/download/data/sample.txt
# !wget https://github.com/clarinsi/parlaspeech/releases/download/data/kaldi_models.tar.xz
# !wget https://github.com/clarinsi/parlaspeech/releases/download/data/lm.tar.xz
# !tar xvf lm.tar.xz
# !tar xvf kaldi_models.tar.xz

# %% [markdown]
# We need the files to be sampled at 16 kHz, mono and saved as a simple PCM wave file:

# %%
# !sox sample.mp3 -r 16k -c 1 -e signed-integer sample.wav

# %% [markdown]
# This is what the file looks like after conversion:

# %%
#!ffprobe -hide_banner ../data/Stortinget-20160602-155510.wav

# %% [markdown]
# ## VAD
#
# The file cannot be processed when it's that long. We need to split it into smaller segments and to do that we will use Voice Activity Detection (VAD) in the form of this lovely Torch library:

# %%
from stringprep import map_table_b2
import torch

# %%
vad_model, vad_utils = torch.hub.load(repo_or_dir='snakers4/silero-vad', model='silero_vad')
vad_model = vad_model

(get_speech_timestamps,
 save_audio,
 read_audio,
 VADIterator,
 collect_chunks) = vad_utils
# Out:
# Using cache found in /home/pers/.cache/torch/hub/snakers4_silero-vad_master

# %%
sample = "../data/Stortinget-20160601-095509.wav"

# %% [markdown]
# This is how VAD is applied to the audio:

# %%
wav = read_audio(sample, sampling_rate=16000)
vad_ts = get_speech_timestamps(wav, vad_model, sampling_rate=16000, speech_pad_ms=1000, min_silence_duration_ms = 10, return_seconds=True)
print(f'Found {len(vad_ts)} segments')
# Out:
# Found 2722 segments

# %% [markdown]
# Initially, we get lots of small segments, but we can merge them together if they are close to each other while making sure the final segments aren't longer than 30 seconds:

# %%
from utils import vad

vad_ts = vad.resample(vad_ts)
print(f'Reduced number of segments to {len(vad_ts)}')
# Out:
# Error: max_len (30) is smaller than one of the segments ({'start': 592.3, 'end': 622.9})!
# Added {'start': 592.3, 'end': 607.5999999999999}
# Added {'start': 607.5999999999999, 'end': 622.9}
# Error: max_len (30) is smaller than one of the segments ({'start': 953.1, 'end': 988.3})!
# Added {'start': 953.1, 'end': 970.7}
# Added {'start': 970.7, 'end': 988.3}
# Error: max_len (30) is smaller than one of the segments ({'start': 1274.6, 'end': 1327.0})!
# Added {'start': 1274.6, 'end': 1300.8}
# Added {'start': 1300.8, 'end': 1327.0}
# Error: max_len (30) is smaller than one of the segments ({'start': 1352.8, 'end': 1387.1})!
# Added {'start': 1352.8, 'end': 1369.9499999999998}
# Added {'start': 1369.9499999999998, 'end': 1387.1}
# Error: max_len (30) is smaller than one of the segments ({'start': 4211.3, 'end': 4249.6})!
# Added {'start': 4211.3, 'end': 4230.450000000001}
# Added {'start': 4230.450000000001, 'end': 4249.6}
# Error: max_len (30) is smaller than one of the segments ({'start': 8317.0, 'end': 8355.9})!
# Added {'start': 8317.0, 'end': 8336.45}
# Added {'start': 8336.45, 'end': 8355.9}
# Error: max_len (30) is smaller than one of the segments ({'start': 9818.6, 'end': 9851.0})!
# Added {'start': 9818.6, 'end': 9834.8}
# Added {'start': 9834.8, 'end': 9851.0}
# Error: max_len (30) is smaller than one of the segments ({'start': 10829.3, 'end': 10871.8})!
# Added {'start': 10829.3, 'end': 10850.55}
# Added {'start': 10850.55, 'end': 10871.8}
# Error: max_len (30) is smaller than one of the segments ({'start': 10951.8, 'end': 11001.5})!
# Added {'start': 10951.8, 'end': 10976.65}
# Added {'start': 10976.65, 'end': 11001.5}
# Error: max_len (30) is smaller than one of the segments ({'start': 13180.9, 'end': 13214.6})!
# Added {'start': 13180.9, 'end': 13197.75}
# Added {'start': 13197.75, 'end': 13214.6}
# Error: max_len (30) is smaller than one of the segments ({'start': 13214.6, 'end': 13252.7})!
# Added {'start': 13214.6, 'end': 13233.650000000001}
# Added {'start': 13233.650000000001, 'end': 13252.7}
# Reduced number of segments to 545

# %% [markdown]
# We can draw a sample segment using Matplotlib:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Audio

# %% [markdown]
# This graph shows a piece of audio roughly 30 seconds long:

# %%
plt.figure(figsize=(15, 5))
beg = vad_ts[0]['start']
end = vad_ts[0]['end']
nb = int(beg * 16000)
ne = int(end * 16000)
plt.plot(np.linspace(beg, end, ne - nb), wav[nb:ne])

# %% [markdown]
# And this code allows us to listen to it:

# %%
Audio(wav[nb:ne], rate=16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## ASR
#
# Now we can do an initial pass of an Automatic Speech Recognition (ASR) procedure. Here we will use a library that requires files to be saved on the drive. That is why we will save the above segment to a new file. The segment was automatically converted to float while reading, so we have to convert it back to 16-bit integers bewfore saving:

# %%
seg = (wav[nb:ne] * torch.iinfo(torch.int16).max).to(torch.int16)
save_audio('segment.wav', seg, sampling_rate=16000)

# %% [markdown]
# Now we can load the ASR models using the HuggingSound library. Due to a small incompatibility between the models and the library, we need to make a small hack with the `token_set`, but otherwise the model works fine. We will also use a language model that was trained on all the human transcripts:

# %%
from huggingsound import SpeechRecognitionModel, KenshoLMDecoder

model = SpeechRecognitionModel("NbAiLab/nb-wav2vec2-1b-bokmaal", device="cuda")
#model.token_set.tokens.pop(48)
#decoder = KenshoLMDecoder(model.token_set, lm_path='lm.binary')
# Out:
# 12/07/2022 15:25:59 - INFO - huggingsound.speech_recognition.model - Loading model...
# 12/07/2022 15:26:11 - WARNING - root - bos_token <s> not in provided tokens. It will be added to the list of tokens
# 12/07/2022 15:26:11 - WARNING - root - eos_token </s> not in provided tokens. It will be added to the list of tokens

# %% [markdown]
# This is an example of how to recognize a single segment:

# %%
transcription = model.transcribe(['segment.wav'])#, decoder=decoder)
print(transcription[0]['transcription'])
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.50s/it]
# stortingets møte er lovlig satt representanten frank jjensen som har vært permittert har igjen tatt sete fra fremskrittspartiets stortingsgruppe foreligger det søknad om permisjon for representanten åse michaelsen i dagene andre og tredje juni for å delta i ossokonferanse i marlin denne søknaden foreslås behandlet straks og innvilget og det anses vedtatt

# %% [markdown]
# We can obviously run this on many files. A utility script was created to process multiple audio files in parallel. It creates a `cache` directory where all the segments are temporarily stored. After the procedure is done, this folder can be purged. The results are dumped to a JSON list file:

# %%
from pathlib import Path
import json
from utils import recognition


res = recognition.process_files([Path(sample)], inv_normalized=True) #tilpass norsk

with open('asr_results.json', 'w') as f:
    for seg in res:
        f.write(json.dumps(seg, ensure_ascii=False) + '\n')
# Out:
# 12/07/2022 15:26:13 - INFO - huggingsound.speech_recognition.model - Loading model...
# Using cache found in /home/pers/.cache/torch/hub/snakers4_silero-vad_master
# 12/07/2022 15:26:24 - WARNING - root - bos_token <s> not in provided tokens. It will be added to the list of tokens
# 12/07/2022 15:26:24 - WARNING - root - eos_token </s> not in provided tokens. It will be added to the list of tokens
# Error: max_len (30) is smaller than one of the segments ({'start': 592.3, 'end': 622.9})!
# Added {'start': 592.3, 'end': 607.5999999999999}
# Added {'start': 607.5999999999999, 'end': 622.9}
# Error: max_len (30) is smaller than one of the segments ({'start': 732.2, 'end': 770.4})!
# Added {'start': 732.2, 'end': 751.3}
# Added {'start': 751.3, 'end': 770.4}
# Error: max_len (30) is smaller than one of the segments ({'start': 953.1, 'end': 988.3})!
# Added {'start': 953.1, 'end': 970.7}
# Added {'start': 970.7, 'end': 988.3}
# Error: max_len (30) is smaller than one of the segments ({'start': 1007.6, 'end': 1053.1})!
# Added {'start': 1007.6, 'end': 1030.35}
# Added {'start': 1030.35, 'end': 1053.1}
# Error: max_len (30) is smaller than one of the segments ({'start': 1063.0, 'end': 1106.5})!
# Added {'start': 1063.0, 'end': 1084.75}
# Added {'start': 1084.75, 'end': 1106.5}
# Error: max_len (30) is smaller than one of the segments ({'start': 1137.4, 'end': 1195.7})!
# Added {'start': 1137.4, 'end': 1166.5500000000002}
# Added {'start': 1166.5500000000002, 'end': 1195.7}
# Error: max_len (30) is smaller than one of the segments ({'start': 1263.9, 'end': 1327.0})!
# Added {'start': 1263.9, 'end': 1284.9333333333334}
# Added {'start': 1284.9333333333334, 'end': 1305.9666666666667}
# Added {'start': 1305.9666666666667, 'end': 1327.0}
# Error: max_len (30) is smaller than one of the segments ({'start': 1352.8, 'end': 1387.1})!
# Added {'start': 1352.8, 'end': 1369.9499999999998}
# Added {'start': 1369.9499999999998, 'end': 1387.1}
# Error: max_len (30) is smaller than one of the segments ({'start': 1402.9, 'end': 1472.4})!
# Added {'start': 1402.9, 'end': 1426.0666666666668}
# Added {'start': 1426.0666666666668, 'end': 1449.2333333333336}
# Added {'start': 1449.2333333333333, 'end': 1472.4}
# Error: max_len (30) is smaller than one of the segments ({'start': 1702.8, 'end': 1741.1})!
# Added {'start': 1702.8, 'end': 1721.9499999999998}
# Added {'start': 1721.9499999999998, 'end': 1741.1}
# Error: max_len (30) is smaller than one of the segments ({'start': 1766.4, 'end': 1813.2})!
# Added {'start': 1766.4, 'end': 1789.8000000000002}
# Added {'start': 1789.8000000000002, 'end': 1813.2}
# Error: max_len (30) is smaller than one of the segments ({'start': 1899.9, 'end': 1958.5})!
# Added {'start': 1899.9, 'end': 1929.2}
# Added {'start': 1929.2, 'end': 1958.5}
# Error: max_len (30) is smaller than one of the segments ({'start': 2508.3, 'end': 2540.8})!
# Added {'start': 2508.3, 'end': 2524.55}
# Added {'start': 2524.55, 'end': 2540.8}
# Error: max_len (30) is smaller than one of the segments ({'start': 3126.0, 'end': 3157.5})!
# Added {'start': 3126.0, 'end': 3141.75}
# Added {'start': 3141.75, 'end': 3157.5}
# Error: max_len (30) is smaller than one of the segments ({'start': 3441.6, 'end': 3475.9})!
# Added {'start': 3441.6, 'end': 3458.75}
# Added {'start': 3458.75, 'end': 3475.9}
# Error: max_len (30) is smaller than one of the segments ({'start': 4174.3, 'end': 4249.6})!
# Added {'start': 4174.3, 'end': 4199.400000000001}
# Added {'start': 4199.400000000001, 'end': 4224.500000000001}
# Added {'start': 4224.5, 'end': 4249.6}
# Error: max_len (30) is smaller than one of the segments ({'start': 4405.3, 'end': 4477.4})!
# Added {'start': 4405.3, 'end': 4429.333333333333}
# Added {'start': 4429.333333333333, 'end': 4453.366666666666}
# Added {'start': 4453.366666666667, 'end': 4477.4}
# Error: max_len (30) is smaller than one of the segments ({'start': 4792.1, 'end': 4830.7})!
# Added {'start': 4792.1, 'end': 4811.4}
# Added {'start': 4811.4, 'end': 4830.7}
# Error: max_len (30) is smaller than one of the segments ({'start': 5064.9, 'end': 5107.7})!
# Added {'start': 5064.9, 'end': 5086.299999999999}
# Added {'start': 5086.299999999999, 'end': 5107.7}
# Error: max_len (30) is smaller than one of the segments ({'start': 5107.7, 'end': 5139.2})!
# Added {'start': 5107.7, 'end': 5123.45}
# Added {'start': 5123.45, 'end': 5139.2}
# Error: max_len (30) is smaller than one of the segments ({'start': 5365.8, 'end': 5397.4})!
# Added {'start': 5365.8, 'end': 5381.6}
# Added {'start': 5381.6, 'end': 5397.4}
# Error: max_len (30) is smaller than one of the segments ({'start': 5501.6, 'end': 5545.5})!
# Added {'start': 5501.6, 'end': 5523.55}
# Added {'start': 5523.55, 'end': 5545.5}
# Error: max_len (30) is smaller than one of the segments ({'start': 5954.7, 'end': 5996.5})!
# Added {'start': 5954.7, 'end': 5975.6}
# Added {'start': 5975.6, 'end': 5996.5}
# Error: max_len (30) is smaller than one of the segments ({'start': 6780.8, 'end': 6811.2})!
# Added {'start': 6780.8, 'end': 6796.0}
# Added {'start': 6796.0, 'end': 6811.2}
# Error: max_len (30) is smaller than one of the segments ({'start': 7666.5, 'end': 7705.1})!
# Added {'start': 7666.5, 'end': 7685.8}
# Added {'start': 7685.8, 'end': 7705.1}
# Error: max_len (30) is smaller than one of the segments ({'start': 7960.3, 'end': 7991.0})!
# Added {'start': 7960.3, 'end': 7975.65}
# Added {'start': 7975.65, 'end': 7991.0}
# Error: max_len (30) is smaller than one of the segments ({'start': 8110.2, 'end': 8142.7})!
# Added {'start': 8110.2, 'end': 8126.45}
# Added {'start': 8126.45, 'end': 8142.7}
# Error: max_len (30) is smaller than one of the segments ({'start': 8202.0, 'end': 8258.6})!
# Added {'start': 8202.0, 'end': 8230.3}
# Added {'start': 8230.3, 'end': 8258.6}
# Error: max_len (30) is smaller than one of the segments ({'start': 8259.7, 'end': 8306.7})!
# Added {'start': 8259.7, 'end': 8283.2}
# Added {'start': 8283.2, 'end': 8306.7}
# Error: max_len (30) is smaller than one of the segments ({'start': 8317.0, 'end': 8367.9})!
# Added {'start': 8317.0, 'end': 8342.45}
# Added {'start': 8342.45, 'end': 8367.9}
# Error: max_len (30) is smaller than one of the segments ({'start': 8461.1, 'end': 8503.4})!
# Added {'start': 8461.1, 'end': 8482.25}
# Added {'start': 8482.25, 'end': 8503.4}
# Error: max_len (30) is smaller than one of the segments ({'start': 8644.5, 'end': 8681.8})!
# Added {'start': 8644.5, 'end': 8663.15}
# Added {'start': 8663.15, 'end': 8681.8}
# Error: max_len (30) is smaller than one of the segments ({'start': 8732.9, 'end': 8780.0})!
# Added {'start': 8732.9, 'end': 8756.45}
# Added {'start': 8756.45, 'end': 8780.0}
# Error: max_len (30) is smaller than one of the segments ({'start': 9818.6, 'end': 9862.8})!
# Added {'start': 9818.6, 'end': 9840.7}
# Added {'start': 9840.7, 'end': 9862.8}
# Error: max_len (30) is smaller than one of the segments ({'start': 10653.3, 'end': 10687.9})!
# Added {'start': 10653.3, 'end': 10670.599999999999}
# Added {'start': 10670.599999999999, 'end': 10687.9}
# Error: max_len (30) is smaller than one of the segments ({'start': 10806.2, 'end': 10871.8})!
# Added {'start': 10806.2, 'end': 10828.066666666668}
# Added {'start': 10828.066666666668, 'end': 10849.933333333334}
# Added {'start': 10849.933333333332, 'end': 10871.8}
# Error: max_len (30) is smaller than one of the segments ({'start': 10929.0, 'end': 11001.5})!
# Added {'start': 10929.0, 'end': 10953.166666666666}
# Added {'start': 10953.166666666666, 'end': 10977.333333333332}
# Added {'start': 10977.333333333334, 'end': 11001.5}
# Error: max_len (30) is smaller than one of the segments ({'start': 11152.6, 'end': 11186.9})!
# Added {'start': 11152.6, 'end': 11169.75}
# Added {'start': 11169.75, 'end': 11186.9}
# Error: max_len (30) is smaller than one of the segments ({'start': 12786.7, 'end': 12826.1})!
# Added {'start': 12786.7, 'end': 12806.400000000001}
# Added {'start': 12806.400000000001, 'end': 12826.1}
# Error: max_len (30) is smaller than one of the segments ({'start': 13169.9, 'end': 13214.6})!
# Added {'start': 13169.9, 'end': 13192.25}
# Added {'start': 13192.25, 'end': 13214.6}
# Error: max_len (30) is smaller than one of the segments ({'start': 13214.6, 'end': 13252.7})!
# Added {'start': 13214.6, 'end': 13233.650000000001}
# Added {'start': 13233.650000000001, 'end': 13252.7}
# Error: max_len (30) is smaller than one of the segments ({'start': 13272.9, 'end': 13306.5})!
# Added {'start': 13272.9, 'end': 13289.7}
# Added {'start': 13289.7, 'end': 13306.5}
# Error: max_len (30) is smaller than one of the segments ({'start': 13306.5, 'end': 13344.7})!
# Added {'start': 13306.5, 'end': 13325.6}
# Added {'start': 13325.6, 'end': 13344.7}
# 100%|██████████| 143/143 [15:23<00:00,  6.46s/it]

# %% [markdown]
# Here is a preview of that file:

# %%
# !head asr_results.json

# %% [markdown]
# ## Matching
#
# Now we will attempt to match the ASR output to the large human transcript. The `Matcher` class is initialized with the large transcript and a `match` method can be used to match a sequence of ASR results. The output is a list of position objects containing the slices within both the reference and the ASR output:

# %%
import sqlite3
con = sqlite3.connect("/media/pers/storage/storage/parlamint/parlamint.db")
sql_query = 'SELECT sent_text FROM sentences WHERE sent_id LIKE "%2016-06-01%";'
cur = con.cursor()
with open("parlamint_2016-06-01.txt", "w") as f:
    for row in cur.execute(sql_query):
        f.write(row[0] + "\n")
con.close()

# %%
from pathlib import Path
from utils.matching import Matcher, load_segments

matcher = Matcher('parlamint_2016-06-01.txt')
asr_results = load_segments(Path('asr_results.json'))
positions = matcher.match(asr_results) # lag norsk normalisering

# %% [markdown]
# We have a small debug routine to observe the match results. Each segment is shown aligned with the human transcript and the ratio value is the quality of the match (wrt to the edit errors):

# %%
matcher.print_debug(positions)
# Out:
# Printing 109 segments:
# ==============
# CORPUS	å	møte	enkeltmenneskene.	Det	er	f.eks.	Gloria	på	16	år,	som	ble	tvunget	til	å	selge	sex	utenfor	Oslo	City.	Det	er	Hannah	på	14	år,	som	ble	voldtatt	av	menneskesmuglere	og	tatt	til	Norge	for	å	selge	sex,	eller	Linda	på	16	år,	som	måtte	jobbe	gratis	som	vaskehjelp	og
# SEGMENT	stortingets	møte	er	lovlig	satt	representanten	frank	jjensen	som	har	vært	permittert	har	igjen	tatt	sete	fra	fremskrittspartiets	stortingsgruppe	foreligger	det	søknad	om	permisjon	for	representanten	åse	michaelsen	i	dagene	andre	og	3.	juni	for	å	delta	i	ossokonferanse	i	marlin	denne	søknaden	foreslås	behandlet	straks	og	innvilget	og	det	anses	vedtatt
# RATIO 	 0.13592233009708743
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS	på	Oslo	universitetssykehus,	OUS,	på	én	klinikk,	skal	det	befinne	seg	over	15	000	pasienter	i	såkalte	interne	ventelister.	Pasientene	holdes	for	narr,	er	den	harde	dommen	fra	pasientombudet	for	Oslo	og	Akershus,	Anne-Lise	Kristensen.	Ventetid	er	komplisert	–	det	har	jeg	selv	erfart.	Det	må	håndteres	med	varsomhet.	Det	vi	har	hørt,	er	ganske	skråsikre	politikere	som	uten	særlig	faglig	begrunnelse	påstår	at	ventebildet	er	totalt	endret	på	få	år.	Denne	saken	er	alvorlig,	for	når	du	er	syk,	er	det	få	ting	som	betyr	mer	enn	tillit,	tillit	til	at	helsetjenesten	har	ditt	beste	øverst	på	agendaen,	ikke	styrt	av	politiske	mål	om	hvilken	liste	du	står	på.	Kvalitetssjefen	ved	Lovisenberg	sykehus	sier	at	de	dramatiske	endringene	i	ventetidene	de	siste	tre–fire	årene	er	«best	for	politikerne,	ikke	like	bra	for	pasientene».	Statsministeren	påstår	at	42	000	færre	pasienter	står	i	kø	nå	enn	i	2013.	Er	hun	sikker	på	at	disse	pasientene	faktisk	er	i	gang	med	behandling,	eller	er	mange	av	dem	bare	flyttet	til	en	kø	som	ikke	er	synlig	i	den	offisielle	statistikken?	Det	er	slik	at	helsekøene	i	Norge	går	ned.	Vi	har	flere	indikasjoner	på	at	de	går	ned.	Vi	er	også	veldig	opptatt	av	at	dersom	det	kan	settes	spørsmålstegn	ved	statistikken,	skal	man	gå	grundig	igjennom	den.	Men	det	er	gjort	et	stort	arbeid	for	å	redusere	ventetidene	rundt	omkring	på	norske	sykehus.	Man	blir	målt	på	det	i	sterkere	grad,	og	vi	ser	også	på	andre	indikatorer	enn	de	vanlige	ventelistene,	bl.a.	indikatoren	fra	når	henvisningene	er	mottatt	på	sykehusene,	til	pasientene
# SEGMENT	på	ous	på	en	klinikk	så	skal	det	befinne	seg	over	15000	pasienter	i	såkalte	interne	ventelister	pasientene	holdes	for	nar	er	den	hardedommen	fra	pasientombudet	for	oslo	og	akershus	anelise	christensen	president	ventetid	er	komplisert	det	har	jeg	selv	erfart	det	må	håndteres	med	varsomhet	det	vi	har	hørt	er	ganske	skråsikre	politikere	som	uten	særlig	faglig	begrunnelse	påstår	at	ventebildet	er	totalt	endret	på	få	år	denne	saken	er	alvorlig	for	når	du	er	syk	så	er	det	få	ting	som	betyr	mer	enn	tillit	tillit	til	at	helsetjenesten	har	ditt	beste	øverst	på	agendaen	ikke	styrt	av	politiske	mål	om	hvilken	liste	du	står	på	kvalitetssjefen	ved	lovisenberg	sykehus	sier	at	de	dramatiske	endringene	i	ventetidene	de	siste	tre	fire	årene	er	sitat	best	for	politikerne	ikke	like	bra	for	pasientene	statsministeren	påstår	at	42000	færre	pasienter	står	i	kø	enn	i	2013	er	hun	sikker	på	at	disse	pasientene	faktisk	er	i	gang	med	behandling	eller	er	mange	av	dem	bare	flyttet	til	en	kø	som	ikke	er	synlig	i	den	offisielle	statistikkenstatsminister	erna	solberg	vær	så	god	president	det	er	slik	at	helsekøene	i	norge	går	ned	vi	har	flere	indikasjoner	på	eee	at	de	går	ned	så	er	vi	også	veldig	opptatt	av	at	hvis	det	kan	stilles	spørsmålstegn	ved	statistikken	så	skal	man	gå	grundig	igjennom	den	statistikken	men	det	er	et	gjort	et	stort	arbeid	for	å	redusere	ventetidene	rundt	omkring	på	norske	sykehus	man	blir	målt	sterkere	på	det	ja	men	vi	ser	jo	også	på	andre	indikatorerenn	vanlige	ventelistene	bl.a.	på	indikatoren	eee	eee	am	henvisninger	når	henvisninger	er	mottatt	til	sykehusene	til	pasientene
# RATIO 	 0.639344262295082
# --------------
# CORPUS	nedgang	på	medianventetiden	på	syv	dager	fra	2013	til	2015.	Det	er	altså	andre	tall	enn	de	vanlige	ventelistetallene,	som	sier	at	det	foregår	en	endring,	at	folk	behandles	raskere	nå	enn	tidligere.	Men	vi	tar	på	alvor	oppslagene	som	har	vært	i	Dagens	Medisin,	for	vi	mener	at	det	ikke	er	riktig	at	man	bare	skal	henvises	for	en	konsultasjon,	eventuelt	en	kartlegging,	og	så	på	nytt	vente	for	å	få	behandling.	Et	av	de	viktigste	grepene	vi	tar	nettopp	for	ikke	å	ha	det	slik,	er	det	vi	har	gjort	med	pakkeforløp	for	kreft.	Da	skal	man	først	henvises	for	å	bli	undersøkt	for	om	man	har	kreft.	Så	er	det	et	detaljert	pakkeforløp	som	forteller	hvor	raskt	man	skal	igjennom,	og	om	stegene	på	veien.	Og	man	organiserer	seg	slik	at	behandlingen	skjer.	Pakkeforløp	er	en	av	de	tingene	denne	regjeringen	har	gjennomført	–	ut	fra	nye	ideer	om	hvordan	man	bruker	helsevesenet	på	en	bedre	måte.	Vi	jobber	nå	med	å	innføre	dette	for	flere	sykdomsbilder,	ikke	bare	på	kreftområdet,	for	det	har	gitt	så	vellykkede	erfaringer.	Vi	er	opptatt	av	at	man	skal	gå	igjennom	dette,	derfor	vil	Helsedirektoratet	få	i	oppdrag	fra	Helsedepartementet	å	gå	igjennom	opplysningene	og	sjekke	om	noen	sykehus	faktisk	bryter	regelverket	ved	å	sette	folk	på	en	ny	liste	i	stedet	for	gå	direkte	over	til	behandling	når	man	har	kartlagt	behovene	for	behandling.	Jeg	må	jo	tolke	det	dit	hen	at	statsministeren	kanskje	da	vil	være	varsom	med	bare	å	slå	fast	at	42	000	færre	mennesker	står	i	kø,	underforstått	at	de	får	behandling.	Vi	har	nå	fått	avdekket	at	veldig	mange	av	dem	står	på	interne	lister	–	de	er	kommet	til	sykehuset	etter	henvisning,	er	blitt	henvist	videre	til	behandling,	er	blitt	tikket	ut	som	behandlet,	og	så	står	de	på	interne	lister.	Jeg	tror	det	illustrerer	at	vi	som	politikere	trekker	veldig	kraftfulle	konklusjoner	av	tall	som	selv	fagfolkene	er	varsomme	med	og	advarer	mot.	Det	skal	vi	ta	med	oss.	Få	politikere,	om	noen,	har	bidratt	mer	enn	Erna	Solberg,	Bent	Høie	og	Siv	Jensen	til	å	slå	fast	–	så	ingen	kan	misforstå	–	at	42	000	flere	har	fått	behandling.	Det	mener	jeg	at	statsministeren	nå	bør	korrigere.	Jeg	har	lyst	til	å	spørre:	Gjør	det	inntrykk	på	henne	når	fagfolkene	sier	at	her	er	det	tall	som	mer	er	til	for	å	glede	politikerne	enn	for	å	være	til	det	beste	for	pasientene?	Gjør	det	inntrykk	på	statsministeren?	Jeg	vet	at	det	vi	gjør	på	helsesektoren,	er	til	det	beste	for	pasientene.	Jeg	ser	gjennom	oppslag	i	avisene	at	folk	har	opplevd	rekordrask	behandling	mot	kreft.	Vi	ser	gjennomføringsevnen	det	er	på	pakkeforløp	for	kreft.	Vi	har	sagt	at	vi	skal	gå	igjennom	disse	tallene	for	å	se	om	det	er
# SEGMENT	nedgang	på	medianventetiden	på	syv	dager	fra	2013	til	2015	ja	altså	andre	tall	enner	de	vanlige	ventelistallene	som	sier	at	det	foregår	en	endring	ved	at	folk	behandles	raskere	nå	enn	de	gjorde	tidligere	men	så	tar	vi	på	alvor	de	oppslagene	som	har	vært	i	dagens	medisin	for	vi	mener	jo	at	det	ikke	er	riktig	at	du	skal	eee	bare	henvises	til	å	få	en	konsultasjon	eventuelt	en	kartlegging	for	også	vente	på	ny	form	for	behandling	et	av	de	viktigste	grepene	vi	gjør	for	nettopp	å	ikke	ha	det	det	er	jo	det	vi	har	gjort	med	pakkeforløp	for	kreft	for	der	r	ikke	det	bare	de	da	skal	du	først	henvises	til	eee	til	å	bli	undersøkt	for	om	du	har	kreft	ja	men	da	er	der	et	detaljert	pakkeforløp	som	forteller	hvor	raskt	du	skal	igjennom	og	forteller	hvilke	steg	på	veien	hom	an	organis	ere	seg	sånn	at	behandlingen	er	dette	med	pakkeforløpet	er	jo	en	av	de	tingene	denne	regjeringen	har	gjort	som	nye	ideer	for	hvordan	vi	kan	bruke	helsevesenet	på	en	bedre	måte	og	vi	jobber	jo	nå	med	å	innføre	det	på	flere	sykdomsbilder	enn	bare	på	på	kreftområdet	for	det	har	så	vellykkete	eee	erfaringer	men	vi	er	opptatt	av	at	vi	skal	gå	igjennom	derfor	vil	helsedirektoratet	få	et	oppdrag	fra	helsedepartementet	for	å	gå	igjennom	de	opplysningene	og	sjekke	om	noen	sykehus	faktisk	bryter	regelverket	ved	å	å	sette	folk	på	en	ny	liste	istedenfor	å	gå	direkte	over	til	behandling	når	man	har	karta	at	hvilken	behov	som	er	for	behandlingjonas	gahr	støre	til	oppfølgingsspørsmål	vær	så	god	president	jeg	må	jo	tolke	det	di	tin	at	statsministeren	kanskje	da	vil	være	varsom	med	å	bare	slå	fast	at	42000	mennesker	færre	står	i	kø	unnerforså	at	de	får	behandling	når	vi	nå	får	avdekket	at	veldig	mange	av	dem	står	på	interne	lister	at	de	er	kommet	på	sykehuset	til	henvisning	er	blitt	henvist	videre	til	behandling	jeg	er	blitt	tak	tikket	ut	som	behandlet	men	så	står	de	på	interne	lister	og	president	jeg	tror	det	illustrerer	at	det	at	vi	som	politikere	skal	sj	trekke	veldig	kraftfulle	konklusjoner	av	tall	som	selv	fagfolkene	er	varsomme	med	og	advare	mot	det	skal	vi	ta	med	og	få	politikere	om	noen	har	bidratt	mer	enn	dette	enn	erna	solberg	bent	høie	og	siv	jensen	med	å	slå	fast	så	ingen	kan	misforstå	at	42000	flere	har	fått	behandling	og	det	mener	jeg	statsministeren	nå	bør	korrigere	og	jeg	har	lyst	på	å	spørre	han	gjør	det	inntrykk	poenget	når	fagfolkene	sier	at	her	er	det	tall	som	mere	er	til	for	å	glede	politikerne	enn	være	til	det	beste	for	pasientene	gjør	det	inntrykk	på	statsministerenstatsminister	erna	solberg	vær	så	godjeg	vet	at	det	vi	gjør	på	helse	sektoren	til	det	beste	for	pasientene	jeg	ser	det	gje	når	jeg	sår	oppslaget	i	avisen	om	folk	som	har	opplevd	rekordrask	behandling	for	psykefåforbilder	f.eks.	på	kreft	når	vi	ser	gjennomføringsevnen	det	er
# RATIO 	 0.6885245901639344
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS	en	annen	måte.	Men	det	er	noen	som	blir	sendt	til	utredning	som	ikke	får	behandling	etterpå	fordi	de	ikke	skal	ha	behandling.	En	av	de	tingene	som	skjer	med	pakkeforløp,	f.eks.,	er	at	folk	blir	sendt	til	utredning.	Så	finner	man	ut	at	de	ikke	har	kreft,	det	er	kanskje	noe	annet,	som	skal	behandles	på	en	helt	annen	måte,	eller	som	kanskje	vil	gå	over	av	seg	selv.	Man	vil	få	flere	som	kommer	til	utredning	raskere.	Det	er	en	del	av	det	pakkeforløpet	for	kreft	f.eks.	gjør:	Noen	flere	som	viser	seg	ikke	å	ha	kreft	og	ikke	trenger	behandling,	kommer	til	utredning.	Vi	skal	gå	gjennom	disse	tallene,	men	jeg	merker	meg	nå	at	Arbeiderpartiet	forsøker	å	snakke	ned	et	resultat	av	den	politikken	vi	fører,	og	som	flere	indikatorer	faktisk	viser	veldig	tydelig.	Jeg	synes	det	er	leit	for	alle	i	helsesektoren	som	står	på	og	jobber	døgnet	rundt	for	å	skape	disse	resultatene.	Det	blir	oppfølgingsspørsmål	–	først	Tove	Karoline	Knutsen.	Statsministeren	og	helseministeren	har	nå	i	lang	tid	påstått	at	regjeringa	har	kuttet	helsekøene	med	over	40	000.	Dagens	Medisin	har	avslørt	at	tallet	er	uriktig,	at	minst	like	mange	pasienter	er	sluset	forbi	statistikken	og	inn	på	en	venteliste	som	ikke	kan	gjenfinnes	i	offentlige	tall,	og	at	andelen	behandlinger	for	dem	som	er	utredet,	har	gått	dramatisk	ned,	fra	37	pst.	til	15	pst.	Uansett	tall:	Det	snodige	er	at	Norsk	pasientregister	understreker	at	antall	ventende	–	eller	helsekøen,	som	statsministeren	gjerne	snakker	om	–	er	tall	som	verken	sier	noe	om	behandlingskapasitet	eller	kvalitet	i	helsetjenestene.	Helseministeren	og	statsministeren	har	trukket	opp	enkelttabeller	med	pinsett	og	holdt	dem	fram	for	å	kunne	tegne	et	glansbilde	av	egen	politikk,	og	helseministeren	har	ikke	endret	retorikk	etter	avsløringene	som	nå	har	kommet.	Mitt	spørsmål	er:	Vil	statsministeren	fremdeles,	som	helseministeren,	insistere	på	den	fortellingen	om	helsekøen	som	vi	har	hørt	til	nå,	eller	vil	det	som	er	avdekket,	endre	den	fortellingen?	Helsekøene	i	Helse-Norge	går	ned,	det	viser	alle	de	andre	indikatorene	også.	Om	de	har	gått	ned	så	mye,	er	spørsmålet	etter	Dagens	Medisins	oppslag.	Vi	skal	altså	foreta	en	kontroll	av	om	det	er	slik	at	sykehusene	faktisk	bryter	loven	og	regelverket	de	styres	av,	ved	å	føre	andre	typer	lister	og	ikke	få	folk	til	behandling.	Vi	er	opptatt	av	å	se	at	vi	faktisk	møter	mange	andre	kvalitetskriterier:	Det	å	få	kortere	tid	for	avklaring	av	om	man	er	syk	eller	ikke,	hvilken	sykdom	man	har,	det	å	jobbe	med	pakkeforløp,	det	å	jobbe	med	kvalitetsregister	og	systemer	fremover	–	som	bidrar	til	å	løfte	kvaliteten	–	er	en	like	viktig	del	av	dette.	Men	med	alle	styringssystemer	vil	det	av	og	til	være	noen	utslag	hvor	man	forsøker	å	tilpasse	seg	styringssystemet.	Det	er	ikke	noen	ny	debatt,	slik	har	det	vært	under	tidligere	regjeringer	også.	Vi	er	opptatt	av	å	løse	opp	i	dette,	for	norske	pasienter	som	trenger	behandling,	skal	ha	raskere	behandling.	Olaug	V.	Bollestad	–	til	oppfølgingsspørsmål.	Nye	tall	fra	Norsk	pasientregister	viser	at	i	denne	perioden	gjentar	problematikken	med	usynlige	ventelister	seg.	Dette	er	ikke	noe	nytt	i	norsk	helsevesen.	Kristelig	Folkeparti	deler	regjeringens	ambisjoner	om	at	flere	pasienter	skal	få	raskere	hjelp,	utredning	og	behandling.	Lengden	på	ventetiden	må	være	medisinsk	begrunnet	–	og	ingenting	annet.	Derfor	er	utviklingen	vi	nå	ser,	bekymringsfull.	Som	helseministeren	skriver:	«Bevisst	flytting	av	ventetiden	til	etter	første	konsultasjon,	for	å	innfri	fristen,	men	samtidig	gi	pasienten	den	reelle	ventetiden	etter,	er	i	strid	med	loven	og	ikke	akseptabelt.»	Ansvaret	for	dette	kan	vi	ikke	bare	legge	på	sykehusledelsen	og	de	ansatte.	Vi	er	nødt	til	å	se	på	systemene	og	om	kravene	virker	inn	på	prioriteringene	i	sykehus.	Ser	statsministeren	at	det	kunne	vært	hensiktsmessig	å	sette	medisinsk	begrunnede	frister	for	behandling	av	ulike	pasientgrupper,	nettopp	for	å	sikre	at	en	ikke	får	usynlige	ventelister?	Det	er	mulig	å	sette	ulike	medisinske	frister.	Det	som	er	vanskelig, ...
# SEGMENT	en	av	de	tingene	som	skjer	med	pakkeforløp	f.eks.	er	at	folk	blir	sendt	for	utredning	så	finner	man	ut	i	at	harike	kreft	det	er	kanskje	noe	annet	som	skal	behandles	på	en	helt	annen	måte	eller	som	kanskje	vil	gå	over	av	seg	selv	og	da	vil	du	altså	få	flere	som	kommer	til	utredning	raskere	eee	det	er	en	del	av	det	pakkeforløpene	på	kreft	f.eks.	gjør	er	at	noen	flere	kommer	til	utredning	som	derved	viser	seg	ikke	har	kreft	og	ikke	trenger	behandling	men	vi	skal	gå	igjennom	de	tallene	men	jeg	merka	meg	nå	at	arbeiderpartiet	forsøker	å	snakke	ned	et	resultat	av	den	politikken	som	vi	fører	som	flere	andre	indikatorer	faktisk	viser	seg	veldig	tydelig	og	jeg	syns	det	er	leit	for	alle	de	i	helsesektoren	som	står	på	og	jobber	døgnet	rundt	for	å	skape	disse	resultatene	det	blir	gitt	anledning	til	tilleggsspørsmål	første	tilleggsspørsmål	er	fra	representanten	tove	karoline	knutsen	deretter	olaug	bollestad	knutsen	vær	så	god	ja	president	eee	statsministeren	og	helseministeren	har	jo	i	lang	tid	nå	påstått	at	regjeringa	har	kutta	helsekøen	over	eee	40000	dagens	medisin	har	nå	avslørt	at	det	tall	er	uriktig	og	at	minst	like	mange	pasienter	slusa	forbistatistikken	og	inn	på	en	venteliste	som	ikke	kan	gjenfinnes	i	offentlige	tall	og	at	andelen	behandlinger	av	de	som	er	utreda	har	gått	dramatisk	ned	fra	syvogtredve	prosent	til	15%	men	noensett	tall	det	snodige	er	jo	at	norsk	eee	pasientregister	understreker	at	antall	ventene	eller	helsekøen	som	statsministeren	gjerne	snakker	om	er	et	tall	som	verken	sier	noe	om	behandlingskapasitet	eller	kvalitet	i	helsetjenestene	eee	helseministeren	og	statsministeren	har	trukket	opp	enkelttabeller	med	pinsett	og	holdt	den	fram	for	å	kunne	tegne	et	glandsbilde	av	egen	politikk	eee	og	helseministeren	har	ikke	endra	retorikk	etter	de	avsløringene	som	nå	er	kommen	mitt	spørsmål	er	vil	også	statsministeren	fremdeles	som	helseministeren	insistere	på	den	fortellinga	om	helsekøen	som	vi	har	hørt	til	nå	eller	det	som	vil	det	som	er	avdekka	endre	den	fortellinga	statsminister	erna	solberg	vær	så	god	eee	president	helsekvøen	i	helsenorge	går	ned	det	viser	alle	de	andre	indikatorene	også	om	de	har	gått	ned	så	mye	er	spørsmålet	etter	dagens	næringsliv	eee	dagens	medisinske	oppslag	eee	og	det	skal	vi	altså	foreta	en	kontroll	og	vi	skal	foreta	en	kontroll	av	om	det	er	slik	at	sykehusene	eee	ee	faktisk	bryter	loven	og	bryter	regelverket	de	styres	un	dar	ved	å	føre	andre	typer	lister	og	ikke	levere	folk	til	behandling	men	vi	er	opptatt	av	å	se	at	vi	faktisk	på	mange	andre	kriterier	har	møter	kvalitetskriteriene	også	det	å	få	kortere	aee	tid	for	avklaring	om	du	er	syk	eller	ikke	eee	om	hva	slags	sykdom	du	har	det	å	jobbe	med	pakkeforløp	det	å	jobbe	med	kvalitetsregisteret	og	systemer	fremover	som	bidrar	til	å	løfte	mer	kvalitet	er	en	like	viktig	del	av	dette	men	det	er	sånn	at	med	alle	styringssystemer	så	vil	det	være	noen	utslag	av	og	til	hvor	man	forsøker	å	eee	tilpasse	seg	styringssystemet	det	er	ikke	noe	ny	debatt	det	hadde	vært	under	tidligere	regjeringer	også	men	vi	er	altså	opptatt	av	å	løse	opp	i	dette	for	norske	norske	pasienter	som	trenger	behandling	skal	ha	raskere	behandlingneste	tilleggsspørsmål	er	fra	representanten	olaug	bollestad	deretter	kjersti	toppe	bollestad	vær	så	god	takk	president	nye	tall	ifra	pasient	ee	norsk	pasientregister	viser	at	i	denne	perioden	så	gjentar	problematikken	seg	om	usynlige	ventelister	dette	er	ikke	noe	nytt	i	norsk	helsevesen	krf	med	deler	regjeringen	sine	ambisjoner	om	at	flere	pasienter	skal	få	raskere	hjelp	og	utredning	og	behandling	lengden	på	ventetida	med	å	være	be	medisinsk	begrunna	og	ingenting	annet	derfor	er	utviklingen	vi	nå	ser	bekymringsfullt	som	s	helseministeren	skriver	bevisst	flytting	av	ventetid	etter	fyrste	konsultasjon	f	for	å	innfri	fristen	men	samtidig	gir	pasienten	reelle	ventetid	etter	er	i	strid	med	loven	og	ikke	akseptabelt	ansvaret	for	dette	kan	vi	ikke	bare	legge	på	sykehusledelsen	og	de	ansatte	vi	er	nødt	for	å	se	på	system	emene	og	om	krav	å	virk ...
# RATIO 	 0.5764705882352941
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS	at	det	er	en	utfordring	særlig	med	folk	som	har	sammensatte	symptomer	og	annet.	Det	er	en	av	grunnene	til	at	vi	på	Stortinget	i	forrige	periode	ivret	for	diagnosesentre,	som	gjør	at	man	ikke	gir	slipp	på	en	pasient	som	kommer	med	en	ikke	avklart	sykdom,	men	at	man	faktisk	avklarer	hvordan	den	sykdommen	er.	Jeg	har	vært	og	besøkt	noen	av	de	første	diagnosesentrene.	De	gjør	en	fantastisk	jobb.	Det	er	en	lettelse	for	de	pasientene	som	har	vært	der,	og	som	kanskje	opplever	å	få	beskjed	om	at	de	ikke	har	kreft,	men	en	annen	type	sykdom.	Så	kan	behandlingsløpet	gå,	istedenfor	at	de	blir	sendt	via	fastlegen	til	nye	henvisninger	for	hver	enkelt	utredning.	Derfor	jobber	vi	også	med	å	etablere	diagnosesentre	på	andre	områder,	bl.a.	det	som	vi	kaller	muskelutmattelse	–	den	typen	immunnedsettelser	–	som	er	representert	ved	en	av	de	svakeste	gruppene	i	helsevesenet,	men	som	oftest	opplever	ikke	å	få	svar.	Derfor	er	det	viktig	hvordan	vi	organiserer	inne	i	sykehusene,	også	for	å	sørge	for	at	vi	får	et	ordentlig	svar	på	det	som	ikke	er	helt	avklarte	sykdommer.	Ketil	Kjenseth	–	til	oppfølgingsspørsmål.	Fra	2002,	da	staten	overtok	sykehusene,	og	fram	til	i	dag	har	sykehusbudsjettet	vokst	fra	50	mrd.	til	140	mrd.	kr	årlig.	Lønns-	og	kostnadsvekst	og	flere	innbyggere	er	en	naturlig	del	av	forklaringen,	men	et	stadig	mer	intrikat	byråkrati	for	å	holde	orden	på	tellekanter,	ventetider,	rapportering	og	papirer	er	også	en	stor	del	av	veksten.	Mens	Arbeiderpartiet	og	Høyre	knives	om	å	forklare	oss	om	vi	står	i	feil	kø,	og	detaljregulere	sykehussektoren	med	oppdrag,	DRG-er,	rapportering	og	tilhørende	byråkrati,	er	Venstres	svar	å	satse	mer	på	forebygging,	folkehelse	og	velferdsteknologi,	så	folk	slipper	å	bli	venteliste-	eller	svingdørspasienter.	De	første	evalueringene	av	det	store	nasjonale	prosjektet	med	velferdsteknologi	rettet	mot	kronikere	tyder	på	en	halvering	av	sykehusinnleggelser.	Vil	statsministeren	bli	med	Venstre	på	å	satse	litt	mer	på	folkehelse	og	forebygging	og	litt	mindre	på	fritt	valg	av	usynlige	ventelister?	Regjeringen	mener	at	det	forebyggende	arbeidet	er	det	absolutt	viktigste	i	det	lange	løp	for	å	gjøre	noe	med	helsen.	Det	å	sørge	for	at	folk	kan	mestre	sin	egen	helse	på	en	bedre	måte	kan	i	stor	grad	avlaste	en	del	av	de	offentlige	helsetilbudene.	Det	vi	gjør	bl.a.	ved	at	sykepleierne	får	flere	muligheter	for	spesialisering,	at	de	får	være	i	kommunene	og	ha	ansvar	for	enkelte	grupper,	gir	også	en	lettere	oppfølging,	og	folk	kan	bo	hjemme.	Alt	dette	er	en	del	av	den	meldingen	vi	hadde	om	primærhelsetjenesten,	som	altså	skal	være	forebyggende,	men	også	avlastende,	for	at	de	som	har	kroniske	sykdommer,	får	bedre	hjelp	uten	at	de	skal	inn	i	sykehusene.	Det	blir	en	oppbygging	av	den	typen	helsetjenester	ute	i	kommunene	i	årene	som	kommer.	Velferdsteknologi	er	også	viktig,	ikke	minst	for	å	sørge	for	at	eldre	mennesker	skal	kunne	klare	å	bo	lenger	hjemme	og	føle	mer	kontroll	og	mer	verdighet	i	sitt	eget	liv	når	de	får	hjelp.	Men	vi	må	behandle	folk	som	har	fått	kreft,	på	sykehus,	og	vi	må	også	behandle	lårhalsbrudd	og	annet	på	sykehus.	Så	det	går	ikke	an	å	la	være	å	si	at	vi	ikke	skal	gjøre	det.	Vi	må	også	gjøre	det.	Audun	Lysbakken	–	til	oppfølgingsspørsmål.	Det	Dagens	Medisin	har	avdekket,	er	en	skandale,	og	jeg	synes	det	er	oppsiktsvekkende	at	statsministeren	tar	det	med	så	stor	ro	som	disse	svarene	gir	inntrykk	av.	Disse	svarene	har	en	smak	av	bortforklaring.	Vi	må	bort	fra	den	debatten	som	sånne	saker	alltid	ender	i,	nemlig	at	man	peker	på	individuelle	ledere	eller	spesielle	institusjoner	i	helsevesenet,	og	at	Høyre	og	Arbeiderpartiet	utveksler	gjensidige	beskyldninger.	Og	så	må	vi	snakke	om	det	systemet	som	skaper	sånne	skandaler.	Systemet	er	problemet,	og	i	Norge	har	vi	et	sykehussystem	med	omfattende	stykkprisfinansiering,	med	sterkt	politisk	press	for	å	få	ned	ventelistene	så	det	ser	bra	ut	for	helseministeren.	For	mye	rigges	etter	hva	vi	kan	måle,	i	stedet	for	etter	det	pasientene	har	behov	for.	Systemet	settes	for	oft ...
# SEGMENT	at	det	er	en	utfordring	særlig	med	folk	som	har	sammensatte	symptomer	og	annet	det	er	en	av	grunnene	til	at	vi	på	stortinget	forrige	periode	e	ivret	for	diagnosesentret	som	gjør	at	du	da	ikke	vil	slippe	på	på	en	pasient	som	kommer	med	en	med	en	ikke	avklart	sykdom	men	du	faktisk	avklarer	hvordan	den	sykdommen	er	jeg	har	hatti	besøkt	noen	av	de	første	diagnosesentrene	de	gjør	en	fantastisk	jobb	og	det	er	en	lettelse	for	de	pasientene	som	faktisk	har	vært	der	og	som	opplever	at	ja	kanskje	de	får	beskjed	om	at	de	ikke	har	kreft	men	de	har	en	annen	type	sykdom	og	så	kanne	behandlingsvep	på	gå	istedenfor	at	de	blir	sendt	via	fastlegggen	til	nye	henvisninger	for	hver	enkelt	eee	utredning	derfor	jobber	jo	vi	også	med	å	etablere	diagnosesentre	på	andre	områder	bl.a.	på	det	som	da	vi	kaller	altså	muskelutmattelse	den	typen	imune	og	eee	nedsettelser	som	er	en	av	de	svakeste	gruppene	i	helsevesenet	og	som	oftest	opplever	at	de	ikke	får	svar	derfor	så	er	det	viktig	hvordan	vi	organiserer	inn	i	sykehusene	også	for	å	sørge	for	at	vi	får	et	ordentlig	svar	på	det	som	ikke	er	helt	avklarte	sykdommer	og	neste	tilleggsspørsmål	er	fra	representanten	ketil	kjenseth	og	til	slutt	audun	lysbakken	kjenseth	vær	så	godtakk	president	fra	2002	da	staten	overtok	eee	sykehusene	og	fram	tid	i	dag	har	sykehusbudsjettet	vokst	fra	50	milliarder	til	140	milliarder	kroner	årlig	lønns	og	kostnadsvekst	av	flere	innbyggere	er	en	naturlig	del	av	forklaringen	men	et	stadig	mer	integrart	byråkrati	for	å	holde	orden	på	telekanter	ventetider	rapportering	og	papirer	er	også	en	stor	del	av	veksten	mens	arbeiderpartiet	og	høyre	knives	om	å	forklare	oss	om	det	står	i	feil	kø	detaljregulere	sykehussektoren	med	oppdrag	drger	rapportering	og	tilhørende	byråkrati	er	venstres	svar	å	satse	mer	på	forebygging	folkehelse	og	velferdsteknologi	så	folk	slipper	å	bli	ventelista	eller	svingders	pasient	de	første	elve	evalueringene	av	det	store	nasjonale	prosjektet	med	velferdsteknologi	retta	mot	kronikere	tyder	på	en	halvering	av	eee	sykehusinnleggelser	vil	statsministeren	bli	med	venstre	på	å	satse	litt	mer	på	folkehelse	og	forebygging	og	litt	mindre	på	frittvalget	av	ei	synlig	ventelistestatsminister	erna	solberg	vær	så	godsit	regjeringen	mener	at	det	forebyggende	arbeide	er	det	absolutt	viktigste	i	det	lange	løp	for	for	å	gjøre	noe	med	helse	og	det	å	sørge	for	at	folk	kan	mestre	sin	egen	helse	på	en	bedre	måte	kan	avlastedet	i	stor	grad	også	en	del	av	de	offentlige	helsetilbudene	det	vi	gjør	bl.a.	med	å	si	at	sykepleiere	bør	kunne	få	mer	muligheter	i	eee	på	spesialisering	og	være	i	kommunene	ha	ansvar	for	enkelte	grupper	pe	gir	oss	en	lettere	oppfølging	hvor	folk	kan	bo	hjemme	alt	dette	var	jo	en	del	av	av	eee	den	meldingen	vi	hadde	om	primærhelsetjenesten	som	altså	skal	være	forebyggende	men	også	avlastende	for	de	som	har	kroniske	sykdommer	får	bedre	hjelp	med	å	kunne	få	det	uten	at	de	skal	inn	i	spesialistsy	sykehusene	så	det	blir	jo	en	oppbygging	av	den	typen	helsetjenester	ute	i	kommunene	i	årene	så	k	ommer	velferdsteknologi	er	også	viktig	ikke	minst	for	å	sørge	for	at	eldre	mennesker	kan	kunne	klare	å	bo	lenger	i	hjemmet	og	følge	mer	kontroll	og	mer	verdighet	i	sitt	eget	liv	når	de	får	hjelpen	men	vi	må	også	behandle	folk	som	har	fått	kreft	på	sykehus	og	vi	må	også	behandle	lårehalsbrudd	og	annet	så	det	går	ikke	an	å	la	være	å	si	at	vi	ikke	skal	gjøre	det	vi	må	også	gjøre	detsiste	tilleggsspørsmål	er	ved	audun	lysbakken	lysbakken	vær	så	god	president	det	dagens	medisiner	her	avdekket	er	en	eee	skandale	og	jeg	eee	synes	det	er	oppsiktsvekkende	at	statsministeren	tar	det	med	så	stor	ro	som	disse	svarene	gir	inntrykk	av	disse	svarene	har	en	smak	abortforklaring	vi	må	bort	fra	den	debatten	som	sånne	saker	alltid	ender	i	nemlig	at	man	peker	på	individuelle	leder	eller	spesielle	institusjoner	i	helsevesenet	og	at	høyre	og	arbeiderpartiet	utveksler	gjensidige	beskyldninger	og	så	må	vi	snakke	om	det	systemet	som	skaper	sånne	skandaler	systemet	er	problemet	i	norge	har	vi	et	sykeh ...
# RATIO 	 0.7177033492822966
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS	områder	som	ikke	er	så	lette	å	ta	inn	i	det.	Vi	behandler	flere	i	norsk	helsevesen	i	dag	enn	vi	gjorde	tidligere.	Vi	gjør	det	bl.a.	fordi	vi	har	et	system	som	gjør	at	vi	får	incentiver	til	å	behandle	flere.	Vi	bruker	ressursene	på	en	mer	effektiv	måte	i	norsk	helsevesen	enn	det	vi	gjorde	tidligere.	Det	tror	jeg	ikke	vi	kan	komme	bort	fra.	Jeg	skjønner	at	SV	ønsker	et	helt
# SEGMENT	områder	som	ikke	er	så	lett	å	ta	inn	i	det	men	det	er	sånn	at	vi	behandler	flere	i	norsk	helsevesen	i	dag	enn	det	vi	gjorde	tidligere	vi	gjør	det	bl.a.	fordi	vi	har	et	system	som	gjør	at	du	får	eee	et	insentiv	til	å	behandle	flere	vi	bruker	ressursene	på	en	mer	effektiv	måte	i	norsk	helsevesen	enn	det	vi	gjorde	tidligere	eee	det	tror	jeg	ikke	vi	kan	komme	bort	fra	eee	jeg	skjønner	at	sv	ønsker	et	helt
# RATIO 	 0.759493670886076
# --------------
# CORPUS	annet	finansieringssystem,	de	ønsker	gjerne	ikke	å	se	hvilke	områder	det	er	utfordringer	på.	En	del	av	det	vi	gjør	når	vi	har	kontrollsystemer,	er	faktisk	å	sikre	at	pasientene	får	de	rettighetene	de	skal	ha,	at	vi	setter	pasienten	og	ikke	systemet	i	sentrum.	Det	SV	foreslår,	er	å	sette	profesjonene	i	sentrum	i	stedet	for	pasientene.	Det	synes	ikke	jeg	er	noen	god
# SEGMENT	annet	finansieringssystem	de	ønsker	gjerne	ikke	å	se	hvilke	områder	der	er	utfordringer	på	for	di	at	når	en	del	av	det	som	som	vi	gjør	når	vi	har	kontrollsystemet	ont	det	er	jo	faktisk	å	sikre	at	pasientene	får	de	rettighetene	de	skal	at	vi	setter	pasientene	i	sentrum	og	ikkesystemet	det	sv	foreslår	er	å	sette	profesjonene	i	sentrum	eee	istedenfor	pasientene	det	synes	ikke	er	noen	god
# RATIO 	 0.6617647058823529
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS	som	måtte	jobbe	gratis	som	vaskehjelp	og	ble	holdt	fanget.	Det	er	noen	av	enkeltmenneskene.	I	flere	av	historiene	som	Fafo-rapporten	beskriver,	kommer	det	fram	at	voksne	visste	–	eller	iallfall	hadde	en	anelse	om	–	hva	som	foregikk.	De	skjønte	at	den	unge	jenta	på	mottaket	ble	misbrukt	som	sexslave,	eller	at	den	unge	gutten	ble	tvunget	til	å	selge	narkotika,	men	de	gjorde	ingenting.	I	noen	tilfeller	var	barnevern	og	politi	varslet,	men	likevel	skriver	Fafo	at	ting	ikke	ble	gjort.	Det	er	totalt	uakseptabelt.	Derfor	er	mitt	spørsmål	til	statsministeren:	Hvilket	inntrykk	gjør	det	på	statsministeren	når	hun	hører	eller	leser	historier	om	at	barn	i	vårt	eget	land	blir	utnyttet	på	denne	måten?	Det	gjør	et	sterkt	inntrykk.	Det	gjør	et	inntrykk	også	fordi	det	viser	at	vi	ennå	ikke	klarer	å	hjelpe	alle	i	vårt	samfunn.	Det	er	helt	uakseptabelt	at	dette	forekommer,	og	det	er	helt	uakseptabelt	at	det	ikke	meldes	fra	om,	av	dem	som	eventuelt	har	mistanke	eller	annet,	at	barn	utnyttes,	at	man	har	menneskesmugling,	at	man	utnyttes	i	prostitusjon	eller	på	andre	områder.	Vi	vet	at	noe	av	det	viktigste	vi	kan	gjøre,	er	å	slåss	mot	bakmennene	og	systemene	som	er	knyttet	til	dette.	Veldig	mange	av	disse	systemene	knyttes	sammen	med	det	som	vi	også	ser	driver	arbeidslivskriminaliteten.	Det	vi	ser	nå,	er	at	det	samarbeidet	som	vi	gjør	på	arbeidslivskriminalitetsområdet,	avdekker	folk	som	jobber	til	en	minimumslønn,	som	jobber	på	dårlige	vilkår	–	ja,	nærmest	slavelignende	vilkår.	Derfor	er	det	så	viktig	at	vi	har	dette	samarbeidet	mellom	etatene,	som	kan	se	både	på	økonomi	og	på	skattebetalingen,	som	er	på	innvandringssiden	og	på	politisiden,	for	å	følge	med.	I	dette	tette	samarbeidet	har	man	avslørt	bakmenn	som	driver	med	det	vi	vil	kalle	menneskesmugling,	og	som	diversifiserer,	for	de	gjør	ofte	flere	forskjellige	ting	på	en	gang	–	de	er	blandet	inn	i	flere	kriminelle	nettverk.	Dette	kan	bidra	til	å	gjøre	noe	med	nettopp	menneskesmugling.	Så	er	det	viktig	at	vi	har	et	godt	støtteapparat	for	dem	som	finnes.	Der	vet	vi	at	vi	ikke	er	gode	nok,	også	fordi	det	ofte	er	et	spørsmål	om	bevisføring.	Det	er	ting	vi	alltid	må	se	bedre	på,	om	vi	kan	klare	å	få	bedre	oppfølgingstiltak	for	dem	som	har	vært	ofre,	og	som	det	avklares	at	har	vært	ofre	for	slavehandel	og	for	menneskesmuglere	og	utnyttelse	i	det	norske	samfunnet.	Jeg	vil	takke	statsministeren	for	svaret	og	engasjementet	hun	viser.	Det	er	ekstremt	viktig	at	vi	som	politikere	tar	et	større	ansvar,	og	i	denne	salen	tror	jeg	at	jeg	har	mast	kanskje	opp	mot	ti	ganger	på	justisministeren	for	å	få	en	handlingsplan,	for	den	forrige	gikk	ut	i	2014.	Det	ville	vært	koordinering	på	alle	de	områdene	som	statsministeren	er	opptatt	av.	Men	jeg	skal	love	statsministeren	at	gjennom	justiskomiteens	arbeid	har	vi	løftet	inn	flere	millioner	kroner	til	arbeid	for	politi,	støtteapparat	osv.	Et	viktig	vedtak	som	ble	fattet	i	denne	sal,	var	at	det	skulle	opprettes	menneskehandel-team	på	hvert	mottak	der	det	er	mindreårige	mellom	15	og	18	år.	På	Hvalstad	transittmottak	hadde	de	et	slikt	team,	og	bare	i	2011	identifiserte	de	26	mulige	ofre,	og	i	2012	identifiserte	de	42	mulige	ofre.	Altså	fikk	mange	barn	hjelp	på	grunn	av	de	teamene.	Nå	har	Stortinget	sagt	at	dette	skal	komme.	Men	mitt	spørsmål	er:	Hvordan	ligger	det	an	med	den	typen	arbeid?	Jeg	kan	ikke	svare	detaljert	på	hvor	langt	vi	er	kommet	når	det	gjelder	dette.	Det	er	viktig	at	de	som	jobber	på	mottakene,	har	kompetanse	på	disse	spørsmålene,	at	de	har	kompetanse	på	hvor	de	skal	henvende	seg,	og	hvem	de	skal	melde	til.	Det	er	også	viktig	at	man	er	tydelig	på	at	når	ungdom	og	barn	forsvinner	fra	mottak,	skal	det	igangsettes	politietterforskning.	Det	ligger	i	dagens	retningslinjer	at	det	skal	være	politietterforskning	av	de	sakene.	En	del	ganger	er	det	fordi	de	har	foreldre	som	er	et	annet	sted	–	det	vet	vi.	Vi	vet	også	at	mange	av	de	som	jobber	på	mottakene,	merker	seg	det	og	ser	at	noen	f.eks.	har	foreldre	som	har	kommet	til	Tyskland,	i	en	situasjon	hvor	de	er	f ...
# SEGMENT	som	måtte	jobbe	gratis	som	vaskehjelp	og	blei	holdt	fanga	det	er	noen	av	enkeltmenneskene	og	i	flere	av	historiene	som	faforapporten	eee	beskriver	så	kjem	det	fram	at	voksne	visste	eller	i	allfall	hadde	en	anelse	av	hva	som	foregikk	de	skjønte	at	en	unge	jenter	på	mottaket	blei	misbrukt	som	seklave	eller	at	den	unge	gutten	blei	tvunget	til	å	selge	narkotika	men	de	gjorde	ingenting	i	noen	tilfeller	så	var	au	barnevern	og	politi	varsla	men	likevel	så	skriver	fare	for	at	ting	blei	ikke	gjort	president	det	er	totalt	uakseptabelt	så	derfor	så	er	mitt	spørsmål	til	statsministeren	og	sin	inntrykk	gjør	statsministeren	når	hun	hører	historia	eller	lese	historie	om	barn	i	vor	eget	land	blir	utnytta	på	denne	måtenstatsminister	erna	solberg	vær	så	god	predent	det	gjør	et	sterkt	inntrykk	eee	det	gjør	et	inntrykk	ee	også	for	det	det	viser	at	vi	enneikke	klarer	å	hjelpe	alle	i	vårt	samfunn	og	det	er	helt	uakseptabelt	eee	at	dette	eee	forekommer	og	det	er	helt	uakseptabelt	at	det	ikke	meldes	fra	om	fra	de	som	eventuelt	har	mistanke	eller	annet	om	at	eee	fo	at	barn	utnyttes	at	eee	at	man	har	menneskesmugling	at	man	eee	utnyttes	i	posisjon	eller	andre	områder	så	vet	jo	vi	at	noe	av	den	viktigste	vi	kan	gjøre	er	også	slåss	mot	bakmennene	og	systemene	som	er	knyttet	til	dette	og	veldig	mange	av	disse	systemene	knyttet	sammen	il	det	som	vi	også	ser	på	som	driver	arbeidslivskriminaliteten	det	vi	ser	nå	er	at	det	samarbeidet	som	vi	gjør	på	arbeidslivskriminalitetsområdet	avdekker	folk	som	jobber	til	en	minimum	sjøn	som	jo	var	på	dårlige	vilkår	ja	så	ligger	i	nærmestesave	slavelignende	vilkår	og	derfor	så	er	det	så	viktig	at	vi	har	disse	samarbeidet	mellom	etatene	som	kan	se	både	på	økonomi	eee	på	skattebetalingen	som	er	på	innvandringssiden	og	som	er	på	politisiden	for	å	følge	med	og	at	vi	har	dette	tette	samarbeidet	i	det	samarbeidet	så	har	man	avslått	bakmenn	for	det	vi	vil	kaller	menneskesmogling	den	andre	siden	er	vikt	eee	og	og	som	som	diversifiserer	for	de	gjør	ofte	flere	forskjellige	ting	på	en	gang	de	er	blandet	inn	i	flere	kriminelle	kriminelle	nettverk	og	eee	det	kan	bidra	til	å	å	å	gjøre	noe	med	med	nettopp	eee	menneskesmugling	så	er	det	viktig	at	vi	har	et	godt	støtte	apparat	for	de	som	finnes	der	vet	at	vi	ikke	er	gode	nok	også	fordi	at	det	ofte	er	et	spørsmål	om	bevisføring	eee	det	er	ting	vi	alltid	må	se	bedre	på	om	vi	kan	klare	å	få	bedre	oppfølgingstiltak	for	de	som	har	vært	ofre	og	som	avklares	at	d	t	har	vært	ofre	for	slavehandel	og	for	for	menneskesmugler	og	utnyttelse	i	det	norske	samfunnet	kjell	ingolf	ropstad	til	oppfølgingsspørsmål	vær	så	god	gode	president	ee	f	jeg	vil	takke	statsministeren	for	svaret	og	for	engasjement	å	vise	det	er	ekstremt	viktig	at	vi	som	politikere	tar	et	større	ansvar	og	i	denne	salen	så	drarr	jeg	mast	kanskje	opp	mot	ti	ganger	president	eee	på	justisministeren	for	å	få	en	handlingsplan	for	den	forrige	gikk	ut	i	totusenogfr	jorten	det	ville	vært	koordinering	på	alle	de	områdene	som	statsministeren	er	opptatt	av	men	jeg	skal	love	statsministeren	at	gjennom	gjennom	justiskomiteens	arbeid	så	har	vi	løfta	inn	flere	millioner	til	arbeid	for	politi	å	få	støtteapparatet	osv.	og	et	viktig	vedtak	som	ble	fatta	i	denne	sal	var	at	det	skulle	ko	opprettes	menneskehandelteam	på	hvert	mottak	eee	f	der	det	er	mindre	år	mellom	15	og	18	år	eee	på	valstad	transittmottak	så	hadde	de	et	sånt	team	og	bare	i	2011	så	ide	identifiserte	de	26	mulige	ofre	og	i	2012	så	identifiserte	de	42	mulige	ofre	altså	mange	mennesker	eller	barn	fikk	hjelp	pga.	de	mo	eee	de	i	timene	nå	har	stortinget	sagt	at	dette	skal	komme	men	mitt	spørsmål	er	åssen	ligger	det	an	med	den	type	arbeid	statsminister	erna	solberg	vær	så	god	president	det	kan	jeg	ikke	svare	detaljert	på	hvor	langt	vi	er	oe	hvor	langt	vi	er	kommet	i	forhold	til	dette	det	er	viktig	å	og	eee	det	er	viktig	at	de	som	jobber	på	mottakene	også	har	kompetanse	på	disse	spørsmålene	at	de	har	kompetanse	for	hvor	de	skal	henvende	seg	hvem	de	skal	melde	til	og	det	er	viktig	at	man	o ...
# RATIO 	 0.6766917293233083
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS	ganske	ødeleggende	for	disse	barna,	og	kanskje	er	det	flere	enn	dem	vi	blir	opplyst	om	gjennom	denne	avisreportasjen.	Det	spesielle	er	at	disse	er	allerede	kjent	i	sektoren.	De	er	oppdaget	og	sett.	Statsministeren	og	Statsministerens	kontor	har	ansvaret	for	å	koordinere	tiltak	mellom	departementene.	Disse	barna	trenger	tiltak	fra	flere	departementer,	og	de	trenger	tiltak	som	virker,	og	som	er	koordinerte.	Det	har	bl.a.	forlikspartiene	og	Arbeiderpartiet	lagt	inn	i	forliket	om	mottak	av	flyktninger.	Hva	gjør	statsministeren	for	å	koordinere	tiltakene	for	disse	barna	mellom	departementene?	Statsministerens	oppgave	er	å	utpeke	hvilket	departement	som	har	koordineringsansvaret	for	det.	Er	barna	under	15	år,	er	det	barne-	og	familieministeren	som	har	det	helhetlige	ansvaret	for	det	tiltaket	som	gjøres.	Er	barna	over	15	år,	er	ansvaret	mellom	Justis-	og	beredskapsdepartementet	og	Barne-,	likestillings-	og	inkluderingsdepartementet.	Det	gjøres	viktig	arbeid	i	samhandlingen	mellom	disse	to	departementene	på	kompetanse,	kunnskap	og	ikke	bare	på	menneskesmugling	knyttet	til	de	som	er	barn,	for	dette	er	også	et	spørsmål	for	en	del	voksne,	det	er	et	spørsmål	for	en	del	kvinner.	Så	slavehandel	og	slavelignende	tilstander	skjer	også	blant	voksne	som	har	kommet	hit	på	ulike	måter.	Særlig	er	det	vanskelig	når	det	gjelder	veldig	mange	av	dem	som	ikke	lenger	har	opphold,	og	som	dermed	oppholder	seg	ulovlig	i	Norge,	og	som	står	i	en	veldig	sårbar	situasjon	for	å	kunne	bli	utnyttet	til	slavelignende	arbeid.	Marit	Arnstad	–	til	oppfølgingsspørsmål.	Som	flere	har	pekt	på,	er	mange	av	de	barna	som	dette	gjelder,	barn	som	har	bodd,	eller	som	bor	i	asylmottak.	Vi	kan	slå	fast	at	langvarig	opphold	i	asylmottak	er	ikke	bra	for	barn.	De	forsvinningene	fra	asylmottak	vi	har	sett,	er	også	veldig	problematisk.	Når	det	gjelder	det	å	få	bosatt	barn	i	asylmottak,	er	det	faktisk	det	eneste	området	der	det	er	kø,	og	årsaken	til	det	er	finansieringen.	Årsaken	til	det	er	at	kommunene	ikke	vil	bosette,	fordi	storsamfunnet	ikke	stiller	opp	med	den	finansieringen	som	trengs.	Kommunene	har	ikke	noen	egen	pott	til	å	bosette,	heller	ikke	til	å	bosette	barn.	Spørsmålet	mitt	er	rett	og	slett:	Hva	vil	statsministeren	gjøre	for	å	få	enslige	mindreårige	asylsøkere	raskere	bosatt	i	kommunene	og	bedre	ivaretatt	også	av	det	lokale	barnevernet,	og	hvordan	vil	en	bidra	til	en	bedre	finansiering	for	å	få	til	det?	Vi	ser	nå	heldigvis	at	bosettingstallene	for	de	yngste	enslige	mindreårige	øker	betydelig	ute	i	kommunene,	og	tilstrømningen	er	noe	mindre.	Derfor	er	det	en	litt	bedre	balanse	i	situasjonen	for	øyeblikket.	Det	er	god	barnefaglig	kompetanse	på	de	institusjonene	som	barn	under	15	år	er	på.	Det	er	institusjoner	i	barnevernets	regi,	og	som	har	god	oppfølging	av	dem.	Vi	har	foreslått	overfor	KS	–	og	vært	i	forhandlinger	med	KS	om	–	å	innføre	en	mer	stykkprisorientert	modell	for	dette,	slik	vi	har	for	andre	som	bosettes.	Den	refusjonsordningen	som	vi	har	i	dag,	har	den	utfordringen	ved	seg	at	man	da	får	refundert	uansett	hvilke	tiltak	man	legger	inn.	Det	betyr	også	at	man	har	et	veldig	feil	incentiv	til	å	øke	på	med	tiltak	som	kanskje	ikke	hadde	vært	nødvendig,	eller	til	ikke	nødvendigvis	å	være	kritisk	nok	til	hvilke	tiltak	man	gjennomfører,	og	om	de	er	de	beste.	Vi	mener	at	det	bør	være	en	mulighet	for	kommunene	som	er	gode	på	dette,	til	faktisk	–	når	de	får	en	stykkprisfinansiering	av	hver	bosetting,	som	skal	ta	høyde	for	de	store	kostnadene	–	å	tjene	på	det	til	andre	oppgaver	på	den	bosettingen.	Karin	Andersen	–	til	oppfølgingsspørsmål.	Vi	kan	prate	om	menneskehandel,	men	hvis	en	ikke	er	i	stand	til	å	reagere	i	enkeltsakene,	så	hjelper	det	lite.	Når	pågår	saken	om	Yasmin,	som	som	10-åring	ble	foreldreløs,	og	gjennom	15	år	har	vært	utsatt	for	menneskehandel	og	prostitusjon	i	mange	land.	Hun	kom	til	Norge	og	klarte	å	rømme	til	et	krisesenter,	men	nå	bruker	Norge	Dublin-reglene	for	å	kaste	henne	ut	til	Ungarn,	der	vi	veit	at	det	ikke	akkurat	er	«velkommen	hit»	til	menne ...
# SEGMENT	eee	ødeleggende	for	disse	barna	og	kanskje	flere	enn	det	vi	får	eee	opplyst	gjennom	den	avisreportasjen	det	spesielle	er	at	disse	er	allerede	kjent	i	sektoren	de	er	oppdaga	og	de	er	sett	og	statsministeren	har	og	statsministerens	kontor	har	ansvar	for	å	koordinere	tiltak	mellom	departementene	disse	barna	trenger	tiltak	fra	flere	departementer	og	de	trenger	tiltak	som	virker	og	som	er	koordinert	det	har	eee	bl.a.	forlikspartiene	og	arbeiderpartiet	lagt	inn	i	den	enigheten	som	er	på	eee	forliksavtalen	om	mottak	av	flyktninger	hva	gjør	statsministeren	for	å	koordinere	tiltakene	for	disse	barna	mellom	departementene	statsminister	erna	solberg	vær	så	godstatsministerens	oppgave	er	å	utpeke	hvilket	departement	som	har	koordineringsansvaret	for	det	er	barna	under	15	år	så	er	det	barne	e	så	er	det	barne	og	familieministeren	som	har	helhetlig	ansvar	for	det	tiltaket	som	gjøres	er	de	over	eee	over	eee	15	år	så	er	det	mellom	justisdepartementet	og	eee	og	barne	og	familiedepartementet	eee	og	og	det	gjøres	jo	da	eee	viktig	arbeid	i	samhandlingen	mellom	disse	to	departementene	på	kompetanse	på	kunnskap	og	på	ikke	bare	på	menneskesmuling	knyttet	til	de	som	er	barn	for	dette	er	jo	også	et	spørsmål	for	en	del	voksne	det	er	en	del	spørsmål	for	kvinner	eee	så	slaver	handel	eee	og	slav	eee	lignende	eee	tilstande	eee	det	skjer	også	blant	voksne	som	har	kommet	til	å	ha	ulike	på	ulike	måter	og	særlig	er	det	vanskelig	i	forhold	til	veldig	mange	av	de	som	er	eee	ikke	lengre	har	opphold	dermed	oppholder	seg	ulovlig	i	norge	og	som	står	i	en	veldig	sårbar	situasjon	for	å	kunne	bli	utnyttet	til	eee	slavelignende	arbeidneste	tilleggsspørsmål	er	fra	representanten	marit	arnstad	eee	og	deretter	karin	andersen	arnstad	vær	så	god	president	eee	som	flere	har	pekt	på	så	er	det	mange	av	de	barna	det	her	gjelder	er	barn	som	har	bodd	i	asylmottak	eller	som	bor	i	asylmottak	eee	og	vi	kan	jo	slå	fast	at	langvarig	opphold	i	asylmottak	er	ikke	bra	for	barn	eee	og	det	forsvinningene	vi	har	sett	ifra	asylmottak	er	også	veldig	problematisk	eee	så	er	det	jo	sånn	at	det	å	få	bosatt	barn	i	asylmottak	det	er	faktisk	det	eneste	område	der	det	er	kø	og	årsaken	til	det	er	finansieringa	årsaken	til	det	er	at	kommunene	ikke	vil	bosette	fordi	storsamfunnet	ikke	stiller	opp	med	den	finansieringa	som	trengs	eee	det	finnes	eee	ikke	kommunene	har	ikke	noe	egen	pott	til	å	bosette	heller	ikke	bosette	barn	så	spørsmålet	mitt	rett	og	slett	hva	vil	statsministeren	gjøre	for	å	få	enslige	mindreårige	asylsøkere	raskere	bosatt	i	kommunene	og	bedre	ivaretatt	også	av	det	lokale	barnevernet	og	hvordan	vil	en	bidra	til	en	bedre	finansiering	for	å	få	til	detstatsminister	erna	solberg	vær	så	god	president	vi	ser	nå	heldigvis	at	bosetningstallene	for	de	yngste	jenslige	mindreårigene	eee	øker	betydelig	ute	i	kommunene	og	tilstrømningen	er	noe	mindre	derfor	så	er	det	en	litt	bedre	balanse	i	i	situasjonen	for	øyeblikket	eee	nå	er	det	god	barnefaglig	kompetanse	på	de	eee	institusjonene	som	barn	eee	som	barn	under	15	år	er	på	det	er	institusjoner	i	barnevernets	regi	og	som	har	god	oppfølging	eee	av	de	men	eee	det	som	for	meg	altså	vi	har	foreslått	overfor	k	ks	og	vi	har	vært	i	forhandlinger	med	ks	om	å	innføre	en	en	mer	stykkeprisorientert	modell	for	dette	slik	som	vi	har	for	andre	eee	som	bosettes	eee	det	som	den	refusjonsordningen	som	vi	har	i	dag	den	har	den	utfordringen	ved	seg	at	at	du	da	re	får	refundert	uansett	hvilke	tiltak	du	legger	inn	eee	og	da	betyr	det	at	du	også	har	en	veldig	feil	insentiv	til	kanskje	å	øke	på	med	tiltak	som	ikke	hadde	vært	nødvendig	eller	ikke	nødvendigvis	være	kritisk	nok	på	hvilke	tiltak	man	gjennomfører	om	de	ir	de	de	beste	vi	mener	at	det	bør	være	en	mulighet	for	kommuner	som	er	gode	på	dette	og	faktisk	eee	når	di	får	n	syprisfinansiering	av	hver	bosetning	som	skal	ta	høyde	for	de	store	ukostnadenefaktisk	tjene	på	at	det	til	andre	oppgaver	og	den	boset	og	da	er	siste	tilleggsspørsmål	fra	representanten	karin	andersen	andersen	vær	så	god	ja	president	vi	kan	prate ...
# RATIO 	 0.6168224299065421
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS	kommunestyrerepresentanter	og	innbyggere.	Folk	stemmer	nei	og	atter	nei	i	folkeavstemninger.	Omtalen	av	reformen	varierer	mellom	«reformen	vakler	videre»,	«det	er	fiasko»	eller	«det	er	kaos».	Men	kommunalministeren	er	likevel	tilfreds.	Han	mener	prosessene	er	gode	og	at	det	tydelige	nei-flertallet	i	et	stort	flertall	av	kommunene	er	som	forventet.	Deler	statsministeren	kommunalministerens	vurdering	av	at	reformarbeidet	er	vellykket,	og	at	den	massive	motstanden	i	et	stort	flertall	av	folkeavstemningene	er	som	forventet?	At	det	i	folkeavstemninger	kan	bli	et	stort	nei-flertall	en	del	steder,	er	som	forventet.	Dette	har	vi	vært	gjennom	mange	ganger	før.	Det	er	en	krevende	operasjon	å	argumentere	for	forandring.	Det	er	lettere	å	si	ja	til	status	quo.	Jeg	kjenner	noen	av	disse	kommunene	–	Eidfjord	ble	nevnt	bl.a.	Det	er	selvfølgelig	at	når	en	av	landets	rikeste	kommuner	skal	dele	pengene	med	noen	ikke	så	rike	kommuner,	er	det	ikke	sånn	at	folket	går	jublende	av	sted	for	å	stemme	for	det.	Men	de	burde	minnes	om	at	de	også	lovet	at	de	skulle	gjøre	denne	kommunesammenslåingen	som	en	konsekvens	av	at	vi	bygget	Hardangerbroen.	Det	var	faktisk	en	av	premissene	som	de	samme	kommunene	solgte	inn,	den	gangen	vi	fra	regjeringen	for	litt	over	ti	år	siden	fremmet	Hardangerbroen,	for	det	var	så	viktig	for	å	ha	felles	bo-	og	arbeidsmarkedsregion.	Den	gangen	var	det	en	hindring.	Jeg	mener	at	det	er	forventet	at	vi	kommer	til	å	få	mange	nei.	Men	så	er	jeg	glad	for	at	det	var	mange	spenstige	forsøk.	For	eksempel	var	det	mange	store	regionskommuner	som	ble	forsøkt	bygget.	Det	var	tiden	sannsynligvis	umoden	for,	og	det	viser	reaksjonen	på	det.	Samtidig	ser	vi	at	det	er	mange	steder	hvor	de	mindre	kommunene	ser	seg	tjent	med	å	slå	seg	sammen,	fordi	de	kanskje	ser	at	skal	de	gi	et	godt	faglig	tilbud	til	sine	innbyggere	på	de	kritiske	områdene	for	dem	som	trenger	mest	hjelp,	er	det	riktig	å	slå	seg	sammen.	Så	har	vi	noen	utfordringer	på	noen	områder,	som	dreier	seg	om	at	det	er	noen	kommuner	som	har	sagt	ja,	og	noen	som	har	sagt	nei,	og	som	egentlig	henger	sammen.	Det	er	et	spørsmål	som	vi	er	nødt	til	å	ta	stilling	til	etter	hvert.	Når	statsministeren	sier	at	enkelte	steder	har	sagt	nei,	er	det	å	underdrive.	Det	er	87	kommuner	som	har	sagt	nei,	og	det	er	20	har	sagt	ja.	Velferdstjenester	som	eldreomsorg	og	skole	nær	folk	betyr	mye	for	mange.	Folk	har	solid	erfaring	med	at	sammenslåing	betyr	sentralisering.	Det	er	det	som	gjør	at	folk	stemmer	nei	til	sammenslåing	av	kommuner.	Alle	undersøkelser	viser	at	folk	i	mindre	kommuner	er	godt	fornøyd	med	egen	kommune	og	egen	velferd.	Som	et	argument	for	at	det	nå	trengs	endring,	har	Høyre	vist	til	at	Høyre	som	parti	i	30	år	har	jobbet	for	kommunesammenslåing.	Det	har	ikke	slått	statsministeren	at	grunnen	til	at	partiet	ikke	har	lyktes,	er	at	argumentene	for	sammenslåing	ikke	er	gode	nok?	Etter	30	års	mislykket	arbeid	for	kommunesammenslåing	må	en	kunne	spørre	seg	om	statsministeren	noen	gang	har	reflektert	over	det	–	at	større	kommuner	kanskje	ikke	er	det	eneste	saliggjørende,	og	at	folk	ikke	ser	på	det	som	svaret	for	å	få	gode	velferdstjenester	innenfor	eldreomsorg,	helse	og	skole?	Nå	er	situasjonen	at	det	er	46	kommuner	som	har	sagt	ja	ved	folkeavstemninger,	og	109	har	sagt	nei.	Det	er	de	tallene	vi	sitter	med.	Det	er	nok	et	litt	annet	bilde	enn	de	tallene	Marit	Arnstad	nevnte,	selv	om	det	er	et	stort	nei-flertall.	Det	har	vært	en	litt	forvirrende	meny	man	skulle	votere	over	enkelte	steder.	Men	vi	vet	også	at	vi	har	18	kommuner	som	har	vedtatt	sammenslåinger	–	6	sammenslåinger	totalt.	Det	betyr	at	man	er	godt	på	vei.	Jeg	mener	at	det	at	vi	er	noe	forut	for	folkemeningen	av	og	til,	kjennetegner	et	parti	som	er	opptatt	av	å	løse	problemene	for	fremtiden.	Vi	er	opptatt	av	at	vi	skal	sørge	for	at	Norge	blir	et	godt	sted	å	bo	fremover.	Mye	av	denne	regjeringens	arbeid	dreier	seg	om	å	sikre	fremtiden	for	velferdsstaten	Norge.	Det	dreier	seg	også	om	å	sørge	for	at	vi	har	respekt	for	fagkompetanse,	og	respekt	f ...
# ...
# SEGMENT	og	ekte	eee	samboend	og	ektefelles	økonomi	betydelig	i	tillegg	til	minstepensjonistenes	økonomi	og	de	huvodaas	i	eee	budsjettet	også	når	det	gjelder	inntektsutviklingen	til	pensjonistene	så	kan	jeg	vise	til	en	utmerket	rapport	under	pensjonspolitiske	råd	eee	som	ble	offentliggjort	i	går	som	vister	en	formidabel	inntektsutvikling	for	pensjonistene	de	siste	årene	og	det	her	anbefalt	lesning	for	alle	som	er	interessert	ja	takk	resident	president	spørsmålet	gjaldt	eee	fordelingsvirkninger	men	eee	nok	om	det	budsjettet	er	jo	feil	timing	i	forhold	til	trygdeoppgjøret	og	jeg	har	lyst	til	å	vise	til	budsjetthøringa	for	eee	i	fjor	tj	eee	budsjett	2016	da	advarte	pensjonistforbundet	mot	den	nye	budsjettpraksisen	eee	i	budsjettinnstillinga	merka	regjeringspartiene	og	venstre	seg	at	ny	budsjetteringsrunde	ikke	skulle	påvirke	gjennomføring	av	trygdeoppgjørene	så	viser	det	seg	at	gjennomføringa	av	trygdeoppgjøret	tross	forsikringa	fra	flertallet	ble	endret	på	et	svært	vesentlig	punkt	det	kommer	ikke	lenger	til	stortinget	på	samme	måte	som	før	det	er	veleee	vanlig	praksis	at	merknader	fra	regjeringspartiene	sjekkes	ut	med	angjeldende	statsråd	betyr	det	at	denne	forsikringa	fra	flertallspartiene	slapp	igjennom	ven	glipp	eller	er	det	ulikt	syn	mellom	qqq	regjeringa	og	stortingsgruppen	i	denne	saken	eller	er	det	fordi	regjeringa	vil	forhindrer	at	frp	nok	en	gang	kjører	dobbeltspill	om	pensjoner	i	stortingetstatsråd	hauglie	president	her	er	det	så	mange	det	her	er	det	så	mange	premisser	i	spørsmålet	at	jeg	vet	nesten	ikke	hvor	jeg	skal	begynne	for	det	første	så	ser	vi	at	inntektsutviklingen	for	pensjonistene	har	vært	god	vi	ser	at	kjøpekraften	nå	har	gått	ned	pga.	eee	fordi	lønnsoppgjørene	for	øvrig	eee	har	gått	ned	men	pensjonistisk	økonomi	har	blitt	vesentlig	bedre	ikke	minst	som	en	følge	av	budsjettforliket	mellom	høyre	eee	fre	fremskrittspartiet	krf	og	venstre	pga.	skattepolitikken	pga.	eee	økningen	av	eee	grunnbeløpet	til	gifte	og	samboende	og	økningen	til	minspensjonistene	trygdeoppgjøret	gjennomføres	jo	som	før	vi	har	jo	hatt	trygdeoppgjør	hvor	man	diskuterer	både	disse	spørsmålene	men	også	andre	spørsmål	som	som	pensjonistene	er	opptatt	av	og	det	skal	man	jo	fortsette	med	forskjellen	i	år	sammenliknet	med	i	fjor	er	at	man	ikke	flytter	pengene	fysisk	fra	finansdepartementets	budsjettpost	til	arbeids	og	sosialdepartementets	budsjettpost	f	ordi	det	gjorde	man	allerede	i	budsjettet	så	jeg	er	opptatt	av	at	pensjonistene	de	skal	ha	god	økonomi	og	de	skal	ha	en	god	inntektsutvikling	akkurat	nå	så	er	det	en	vanskelig	situasjon	ikke	minst	pga.	økonomien	f	for	øvrig	men	stortinget	e	blir	invitert	til	høsten	i	forbindelse	med	budsjettet	og	diskuterer	også	andre	spørsmål	som	pensjonistene	er	opptatt	av	spørsmål	nummer	19	fra	representanten	martin	henriksen	til	kulturminister	linda	k	hofstad	helleland	henriksen	president	det	store	flertallet	i	norge	ønsker	å	beholde	søndagen	som	en	annerledes	dag	da	regjeringa	for	to	år	siden	ville	liberalisere	heldigdagsfredsloven	fikk	til	en	klar	beskjed	om	at	verken	arbeidsgivere	eller	arbeidstakere	i	bransjen	sjøl	ønska	å	søndagsåpne	flere	butikker	likevel	har	statsråden	signalisert	at	hun	ønsker	å	utrede	loven	på	nytt	hvorfor	vil	statsråden	skape	en	ny	usikkerhet	og	bruke	ressurser	på	ei	utredning	kort	tid	etter	den	forrige	i	stedet	for	å	sørge	for	at	dagens	lovverk	overholdes	og	håndheves	statsråd	helleland	qqq	ja	president	på	initiativ	fra	bl.a.	handel	og	kontor	så	hadde	jeg	et	hastemøte	6.	mai	der	tema	var	søndags	åpne	butikker	og	på	det	her	møtet	så	stilte	eee	representanter	både	fra	handel	og	kontor	fra	virke	fra	nho	handel	samfu	og	i	tillegg	til	remae	1000	så	var	også	norgesgruppen	og	og	cop	til	stede	der	uttalte	de	fleste	av	aktørene	som	var	der	et	stort	behov	for	bedre	kunnskapsgrunnlag	og	en	nærmere	utredning	av	spørsmålet	om	endring	i	regelverket	om	søndagsåpne	butikker	på	mitt	spørsmål	om	loven	i	dag	var	uklar	eller	eee	om	det	var	vanskelig	å	forstå	loven	så	svarte	alle	nei	likevel	sa	de	repre ...
# RATIO 	 0.6190476190476191
# --------------
# CORPUS	søndagshandel	og	søndagsåpent.	Det	gir	jo	visse	utfordringer.	Regjeringens	forslag	ville	ført	til	mindre	konkurransevridning.	Jeg	kunne	ønsket	at	vi	kunne	endret	regelverket	i	tråd	med	det,	og	synes	egentlig	at	dagens	ordning	ikke	er	optimal.	Nå	sier	kulturministeren	at	hun	ønsker	hun	kunne	endret	regelverket.	Når	hun	viser	til	tidligere	oppkonstruerte	problemstillinger,	er	det	slik	at	en	problemstilling	som	ikke	er	oppkonstruert,	er	at	en	del	av	sektoren	hun	er	ansvarlig	for,	nemlig	frivilligheten	og	idretten,	er	tydelig	på	at	de	ikke	ønsker	liberalisering	som	fører	til	flere	søndagsåpne	butikker.	De	er	avhengig	av	at	folk	kan	stille	opp	som	fotballdommere,	lagledere	og	kursledere	også	på	søndagen	i	helgene.	Har	kulturministeren	tenkt	over	forholdene	for	norsk	frivillighet	og	idrett	når	hun	nå	signaliserer	at	hun	ønsker	en	ny	utredning	og	dermed	også	endringer	i	søndagsåpent?	Det	må	være	en	misforståelse	når	representanten	Henriksen	viser	til	at	jeg	vil	endre	lovverket.	Det	er	ikke	mulig	å	endre	lovverket	slik	det	politiske	flertallet	på	Stortinget	er	satt	sammen	i	dag.	Det	tar	regjeringen	konsekvensen	av,	og	derfor	fremmer	vi	ikke	noe	forslag	om	noen	liberalisering.	Det	vil	jeg	bare	gjøre	helt	klart	ikke	kommer	til	å	skje.	Jeg	har	stor	forståelse	for	at	mange	ønsker	å	holde	søndagen	som	annerledesdag	og	ikke	handle,	og	jeg	ser	at	veldig	mange	bruker	søndagen	til	å	handle.	Når	jeg	er	innom	de	såkalte	Brustad-buene,	er	det	kø	og	massevis	av	folk	i	de	fleste	butikkene.	Så	det	er	noen	i	Norge	som	ønsker	å	få	lov	til	å	handle	på	søndager.	Problemet	med	regelverket	i	dag	er	at	det	er	konkurransevridende.	Det	er	synd,	men	jeg	må	ta	konsekvens	av	flertallet	i	Stortinget,	og	det	betyr	ingen	liberalisering	sånn	som	det	er	i	dag.	Jeg	tillater	meg	å	stille	følgende	spørsmål
# SEGMENT	eee	og	det	gir	jo	visse	utfordringer	regjeringas	forslag	har	f	ville	ha	ført	til	mindre	konkurranseutridning	jeg	kunne	ønske	at	vi	kunne	ha	endra	regelverket	i	i	tråd	med	det	og	syns	egentlig	at	e	qqq	dagens	eee	ordning	er	ikke	optimal	president	nå	sier	jo	eee	kulturministeren	tun	kulturministeren	at	hun	ønsker	å	kunne	endra	regelverket	når	dun	viser	til	tidligere	oppkonstruerte	problemstilling	så	er	det	jo	at	ei	problemstilling	som	ikke	er	oppkonstruert	er	at	en	del	av	den	sektoren	o	er	ansvarlig	for	nemlig	frivilligheten	eee	og	idretten	de	har	vært	tydelige	på	at	de	ikke	ønsker	ei	liberalisering	eee	som	fører	til	flere	søndagsåpne	butikker	de	er	avhengige	av	at	folk	kan	stille	opp	som	fotballdommere	lagledere	og	kursledere	også	på	søndagen	eee	i	helgen	har	kulturministeren	tenkt	over	forholdene	for	norsk	frivillighet	og	idrett	når	hun	nå	signaliserer	at	hun	ønsker	ei	ny	utredning	eee	og	dermed	også	endringer	i	eee	søndagsåpenrådla	eee	president	det	må	være	en	en	misforståelse	da	som	eventuelt	eee	når	eventuelt	eee	når	når	representanten	henriksen	viser	til	at	jeg	vil	endre	lovverket	det	er	ikke	mulig	å	endre	lovverket	slik	det	politiske	flertallet	i	stortinget	har	satt	sammen	i	dag	det	tar	regjeringa	konsekvensen	av	og	derfor	fremmer	vi	ikke	noe	forslag	om	noen	liberalisering	så	det	vil	jeg	bare	gjøre	helt	klart	president	at	det	kjem	ikke	til	å	skjeså	har	jeg	stor	forståelse	for	at	mange	ønsker	å	holde	eee	holde	søndagen	som	man	allerledest	dag	og	ikke	handel	så	ser	jeg	at	veldig	mange	bruker	søndagen	til	å	handle	når	jeg	er	innom	eee	de	såkalte	brusavbuene	så	er	det	jo	kø	eee	og	massevis	av	folk	eee	i	de	fleste	av	de	butikkene	så	det	er	noen	i	norge	som	ønsker	å	få	lov	til	å	å	handle	på	søndager	problemet	med	regelverket	i	dag	er	at	det	er	konkurransevridende	det	er	synd	men	jeg	må	ta	konsekvensene	av	eee	flertallet	i	stortinget	og	det	betyr	ingen	liberalisering	sånn	som	det	er	i	dagda	går	vi	til	spørsmål
# RATIO 	 0.5686274509803921
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS	kan	bare	i	særlige	tilfeller	gi	støtte	til	privatarkiv.	Hva	vil	statsråden	gjøre	for	å	bedre	finansieringen	av	privatarkivarbeidet?»	Privatarkivarbeidet	ivaretas	av	ulike	kulturarvinstitusjoner.	Arkivstatistikken	for	2014	viser	at	bevarte	privatarkiv	utgjør	en	mengde	tilsvarende	en	hylle	på	110	km.	Av	dette	har	Arkivverket	ansvar	for	40	km,	kommunale	og	fylkeskommunale	arkiver	har	27	km,	museene	har	ansvar	for	over	23	km	og	private	arkivinstitusjoner	for	14	km,	så	vi	snakker	betydelig	med	kilometer	arkiv	her.	Arkivverkets	privatarkivarbeid	finansieres	med	årlige	bevilgninger	over	kulturbudsjettet.	I	tillegg	gir	Kulturdepartementet	driftstilskudd	til	museer	og	til	privatarkivinstitusjonene	Misjonsarkivet	og	Arbeiderbevegelsens	arkiv	og	bibliotek	2015	var	det	første	året	Arkivverket	forvaltet	særskilte	arkivutviklingsmidler.	Disse	midlene	finansieres	med	tildeling	fra	spilleoverskuddet	til	Norsk	Tipping.	I	2015	ble	det	fordelt	4	mill.	kr	til	utviklingsprosjekter	for	kommunale	arkiv,	privatarkiv	og	arkiv	i	digital	forvaltning.	Av	dette	tildelte	Arkivverket	1,6	mill.	kr	til	utviklingsprosjekter	for	privatarkiv.	De	4	mill.	kr	som	representanten	Haukeland	Liadal	nevner,	gjelder	altså	fjorårets	tildeling.	Fordelingen	av	spilleoverskuddet	til	kulturformål	for	2016	er	ennå	ikke	foretatt.	Det	vil	være	klart	om	ikke	så	altfor	lenge,	og	jeg	vil	i	den	forbindelse	vurdere	den	økonomiske	rammen	for	arkivutviklingsmidlene,	inkludert	midlene	til	privatarkiv,	som	representanten	Haukeland	Liadal	peker	på.	Jeg	takker	for	svaret.	Museer	kan	i	praksis	ikke	tildeles	støtte	til	privatarkivprosjekter.	Det	gjelder	etter	omorganiseringen	av	Kulturrådet	i	2014,	som	legger	ansvaret	for	privatarkiv	i	museer	under	Kulturrådet,	mens	privatarkiv	i	andre	institusjoner	er	Arkivverkets	ansvar.	Til	tross	for	dette	har	Kulturrådet	uttalt	at	de	ikke	har	faglig	kompetanse	til	å	vurdere	søknader	som	gjelder	privatarkiv	i	museer,	og	Arkivverket	avviser	museene	med	å	vise	til	at	det	er	Kulturrådet	som	forvalter	privatarkivstøtte	til	museer.	Det	er	derfor	ikke	delt	ut	støtte	til	privatarkivarbeidet	i	museer.	Hva	mener	kulturministeren	om	svekkelsen	av	finansieringen	av	privatarkivarbeidet	gjennom	oppsplittingen	av	feltet	mellom	Kulturrådet	og	Arkivverket?	Spillemidlene	til	kulturformål	går	til	en	rekke	formål,	bl.a.	Den	kulturelle	skolesekken	og	Frifond.	Det	er	mye	av	dette	representanten	Haukeland	Liadal	kjenner	godt	til.	Nå	er	fordelingen	av	spillemidlene	mellom	de	enkelte	formålene	ikke	avgjort.	Det	skal	fastsettes	av	Kongen	i	statsråd,	og	det	er	derfor	jeg	ikke	kan	gå	inn	på	finansieringen	her.	Men	til	det	konkrete	spørsmålet	fra	representanten:	Jeg	har	tillit	til	at	det	grunnlaget	som	Arkivverket	skal	bruke	til	å	avgjøre	hvor	mye	som	skal	gå	til	privatarkivarbeidet	i	år,	vil	bli	ivaretatt	på	en	god	og	forsvarlig	måte.	Dette	er	noe	uklart.	Jeg	ser	at	i	perioden	2010–2014	ble	det	i	gjennomsnitt	delt	ut	3,2	mill.	kr	til	privatarkivarbeidet,	og	ifølge	tilbakemeldinger	vi	nå	får	fra	Landslaget	for	lokal-	og	privatarkiv,	er	beløpet	sunket	til	0	kr.	Hva	tenker	statsråden	om	at	Kulturrådet	aldri	har	delt	ut	øremerkede	midler	til	privatarkivarbeidet	i	museer,	slik	Stortinget	forutsatte,	og	at
# SEGMENT	kan	bare	i	særlige	tilfeller	gi	støtte	til	privat	arkiv	så	president	mitt	spørsmål	blir	eee	hva	vil	kulturministenrarund	gjøre	for	å	bedre	finansieringen	av	privatarkivarbeidetstatsråd	helleland	president	p	privatarkivarbeidet	ivaretas	av	ulike	kulturarvinstitusjoner	arkivstatistikken	for	2014	viser	at	bevarte	i	privatarkiv	utgjør	en	mengde	tilsvarende	i	hylle	på	110	km	og	av	det	her	har	arkivverket	ansvar	for	40	km	kommunal	og	fylkeskommunale	arkiv	har	27	km	og	museene	her	ansvaret	for	over	treogtyve	km	og	private	arkivinstitusjoner	for	14	km	så	vi	snakker	betydelig	km	med	arkiv	her	arkivverkets	privat	arkivarbeid	finansieres	med	årlige	bevilgninger	over	kulturbudsjettet	i	tillegg	så	gir	kulturdepartementet	driftstilskudd	til	musea	og	til	privat	arkivinstitusjonene	misjonsarkivet	og	arbeiderbevegelsens	arkiv	og	bibliotek	i	2015	så	var	det	det	første	året	arkivverket	forvalta	særskilte	arkivutviklingsmidler	de	midlene	finansieres	med	tildering	fra	spilloverskuddet	til	norsk	tipping	og	i	2015	så	ble	det	fordelt	fire	millioner	kroner	til	utviklingsprosjekter	for	kommunale	arkiv	privatarkiv	og	arkiv	i	digital	forvaltning	av	det	her	tildelte	arkivverket	en	komma	16	millioner	kroner	til	utviklingsprosjekter	for	privatarkiv	de	fire	millionene	president	som	representanten	liadal	nevner	det	gjelder	altså	for	fjorårets	tildeling	så	fordelinga	av	spilloverskuddet	til	kulturformål	for	2016	president	det	er	ennå	ikke	foretatt	det	vil	være	klart	om	ikke	så	altfor	lenge	og	jeg	vil	da	i	den	forbindelse	vurderer	den	økonomiske	ramma	for	arkivutviklingsmidlene	inkludert	midlene	til	privatarkivet	som	representanten	liadal	peker	pålialpresident	jeg	takker	for	svaret	musier	kan	i	praksis	ikke	tildeles	støtte	til	privatarkivprosjekter	det	etter	omorganiseringen	av	kulturrådet	i	2014	eee	som	eee	ligger	ansvaret	for	privat	arkiv	i	museumer	under	kulturrådet	mens	privatarkiv	i	andre	institusjoner	er	arkivverkets	ansvar	til	tross	for	dette	så	har	kulturrådet	uttalt	at	de	ikke	har	faglig	kompetanse	til	å	vurdere	søknader	som	gjelder	privatarkiv	i	museum	og	arkivverket	avviser	museumene	med	å	vise	til	at	det	er	kulturrådet	som	forvalte	privatarkivstøtte	til	museumer	det	er	derfor	eee	ikke	delt	ut	støtte	til	privatarkivarbeidet	i	museumer	hva	meiner	kulturministeren	om	svekkelsen	av	eee	finansieringen	av	privatarkivarbeidet	gjennom	oppsplittingen	av	feltet	mellom	kulturrådet	og	arkivverket	statsråd	helleland	ja	president	ee	spillemidlene	til	kulturformål	går	jo	til	en	rekke	formål	bl.a.	kulturelle	skolesekken	og	frif	fond	ogee	ja	det	er	mye	av	det	her	som	representanten	liadal	kjenner	godt	til	og	nå	er	jo	da	fordelinga	av	spillemidlene	mellom	de	enkelte	formålene	ikke	avgjort	det	skal	fastsettes	av	kongen	i	statsråd	og	det	derfor	ikke	jeg	kan	gå	inn	på	eee	finansieringa	eee	her	men	eee	til	det	kontr	konkrete	spørsmålet	fra	representanten	president	så	eee	har	jeg	tilliten	til	at	det	grunnlaget	som	arkivverket	skal	avgjøre	hvor	mye	som	skal	gå	til	privark	privatarkivarbeidet	i	år	vil	bli	ivaretatt	på	eee	på	en	god	og	en	forsvarlig	måte	liadalja	president	det	er	noe	uklart	jeg	eee	ser	at	i	perioden	2010	til	2014	så	blei	det	i	gjennomsnitt	delt	ut	3,2	millioner	tre	privatarkivarbeidet	og	tilbakemeldingen	vi	nå	får	fra	landslaget	for	lokal	og	privatarkiv	så	er	beløpet	sunket	til	nullhva	tenker	statsråden	om	at	kulturrådet	aldri	har	delt	ut	øremerka	midler	til	privatarkivarbeidet	i	museumer	sånn	som	stortinget	forutsatte	og	at
# RATIO 	 0.5901639344262295
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# NoneType

# %% [markdown]
# There are still some errors above, that is why we will merge a bunch of consecutive segments together and use Kaldi to force re-align everything. We use Kaldi for this because it has fewer issues with working on large audio files. Although it's WER may be slightly worse than the above HuggingSound example, the alignment is generally good enough and works well. Here we merge the segments into larger chunks:

# %%
positions = matcher.resegment_positions(positions)
matcher.print_debug(positions)
# Out:
# Printing 109 segments:
# ==============
# CORPUS	å	møte	enkeltmenneskene.	Det	er	f.eks.	Gloria	på	16	år,	som	ble	tvunget	til	å	selge	sex	utenfor	Oslo	City.	Det	er	Hannah	på	14	år,	som	ble	voldtatt	av	menneskesmuglere	og	tatt	til	Norge	for	å	selge	sex,	eller	Linda	på	16	år,	som	måtte	jobbe	gratis	som	vaskehjelp	og
# SEGMENT	stortingets	møte	er	lovlig	satt	representanten	frank	jjensen	som	har	vært	permittert	har	igjen	tatt	sete	fra	fremskrittspartiets	stortingsgruppe	foreligger	det	søknad	om	permisjon	for	representanten	åse	michaelsen	i	dagene	andre	og	3.	juni	for	å	delta	i	ossokonferanse	i	marlin	denne	søknaden	foreslås	behandlet	straks	og	innvilget	og	det	anses	vedtatt
# RATIO 	 0.13592233009708743
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS	på	Oslo	universitetssykehus,	OUS,	på	én	klinikk,	skal	det	befinne	seg	over	15	000	pasienter	i	såkalte	interne	ventelister.	Pasientene	holdes	for	narr,	er	den	harde	dommen	fra	pasientombudet	for	Oslo	og	Akershus,	Anne-Lise	Kristensen.	Ventetid	er	komplisert	–	det	har	jeg	selv	erfart.	Det	må	håndteres	med	varsomhet.	Det	vi	har	hørt,	er	ganske	skråsikre	politikere	som	uten	særlig	faglig	begrunnelse	påstår	at	ventebildet	er	totalt	endret	på	få	år.	Denne	saken	er	alvorlig,	for	når	du	er	syk,	er	det	få	ting	som	betyr	mer	enn	tillit,	tillit	til	at	helsetjenesten	har	ditt	beste	øverst	på	agendaen,	ikke	styrt	av	politiske	mål	om	hvilken	liste	du	står	på.	Kvalitetssjefen	ved	Lovisenberg	sykehus	sier	at	de	dramatiske	endringene	i	ventetidene	de	siste	tre–fire	årene	er	«best	for	politikerne,	ikke	like	bra	for	pasientene».	Statsministeren	påstår	at	42	000	færre	pasienter	står	i	kø	nå	enn	i	2013.	Er	hun	sikker	på	at	disse	pasientene	faktisk	er	i	gang	med	behandling,	eller	er	mange	av	dem	bare	flyttet	til	en	kø	som	ikke	er	synlig	i	den	offisielle	statistikken?	Det	er	slik	at	helsekøene	i	Norge	går	ned.	Vi	har	flere	indikasjoner	på	at	de	går	ned.	Vi	er	også	veldig	opptatt	av	at	dersom	det	kan	settes	spørsmålstegn	ved	statistikken,	skal	man	gå	grundig	igjennom	den.	Men	det	er	gjort	et	stort	arbeid	for	å	redusere	ventetidene	rundt	omkring	på	norske	sykehus.	Man	blir	målt	på	det	i	sterkere	grad,	og	vi	ser	også	på	andre	indikatorer	enn	de	vanlige	ventelistene,	bl.a.	indikatoren	fra	når	henvisningene	er	mottatt	på	sykehusene,	til	pasientene
# SEGMENT	på	ous	på	en	klinikk	så	skal	det	befinne	seg	over	15000	pasienter	i	såkalte	interne	ventelister	pasientene	holdes	for	nar	er	den	hardedommen	fra	pasientombudet	for	oslo	og	akershus	anelise	christensen	president	ventetid	er	komplisert	det	har	jeg	selv	erfart	det	må	håndteres	med	varsomhet	det	vi	har	hørt	er	ganske	skråsikre	politikere	som	uten	særlig	faglig	begrunnelse	påstår	at	ventebildet	er	totalt	endret	på	få	år	denne	saken	er	alvorlig	for	når	du	er	syk	så	er	det	få	ting	som	betyr	mer	enn	tillit	tillit	til	at	helsetjenesten	har	ditt	beste	øverst	på	agendaen	ikke	styrt	av	politiske	mål	om	hvilken	liste	du	står	på	kvalitetssjefen	ved	lovisenberg	sykehus	sier	at	de	dramatiske	endringene	i	ventetidene	de	siste	tre	fire	årene	er	sitat	best	for	politikerne	ikke	like	bra	for	pasientene	statsministeren	påstår	at	42000	færre	pasienter	står	i	kø	enn	i	2013	er	hun	sikker	på	at	disse	pasientene	faktisk	er	i	gang	med	behandling	eller	er	mange	av	dem	bare	flyttet	til	en	kø	som	ikke	er	synlig	i	den	offisielle	statistikkenstatsminister	erna	solberg	vær	så	god	president	det	er	slik	at	helsekøene	i	norge	går	ned	vi	har	flere	indikasjoner	på	eee	at	de	går	ned	så	er	vi	også	veldig	opptatt	av	at	hvis	det	kan	stilles	spørsmålstegn	ved	statistikken	så	skal	man	gå	grundig	igjennom	den	statistikken	men	det	er	et	gjort	et	stort	arbeid	for	å	redusere	ventetidene	rundt	omkring	på	norske	sykehus	man	blir	målt	sterkere	på	det	ja	men	vi	ser	jo	også	på	andre	indikatorerenn	vanlige	ventelistene	bl.a.	på	indikatoren	eee	eee	am	henvisninger	når	henvisninger	er	mottatt	til	sykehusene	til	pasientene
# RATIO 	 0.639344262295082
# --------------
# CORPUS	nedgang	på	medianventetiden	på	syv	dager	fra	2013	til	2015.	Det	er	altså	andre	tall	enn	de	vanlige	ventelistetallene,	som	sier	at	det	foregår	en	endring,	at	folk	behandles	raskere	nå	enn	tidligere.	Men	vi	tar	på	alvor	oppslagene	som	har	vært	i	Dagens	Medisin,	for	vi	mener	at	det	ikke	er	riktig	at	man	bare	skal	henvises	for	en	konsultasjon,	eventuelt	en	kartlegging,	og	så	på	nytt	vente	for	å	få	behandling.	Et	av	de	viktigste	grepene	vi	tar	nettopp	for	ikke	å	ha	det	slik,	er	det	vi	har	gjort	med	pakkeforløp	for	kreft.	Da	skal	man	først	henvises	for	å	bli	undersøkt	for	om	man	har	kreft.	Så	er	det	et	detaljert	pakkeforløp	som	forteller	hvor	raskt	man	skal	igjennom,	og	om	stegene	på	veien.	Og	man	organiserer	seg	slik	at	behandlingen	skjer.	Pakkeforløp	er	en	av	de	tingene	denne	regjeringen	har	gjennomført	–	ut	fra	nye	ideer	om	hvordan	man	bruker	helsevesenet	på	en	bedre	måte.	Vi	jobber	nå	med	å	innføre	dette	for	flere	sykdomsbilder,	ikke	bare	på	kreftområdet,	for	det	har	gitt	så	vellykkede	erfaringer.	Vi	er	opptatt	av	at	man	skal	gå	igjennom	dette,	derfor	vil	Helsedirektoratet	få	i	oppdrag	fra	Helsedepartementet	å	gå	igjennom	opplysningene	og	sjekke	om	noen	sykehus	faktisk	bryter	regelverket	ved	å	sette	folk	på	en	ny	liste	i	stedet	for	gå	direkte	over	til	behandling	når	man	har	kartlagt	behovene	for	behandling.	Jeg	må	jo	tolke	det	dit	hen	at	statsministeren	kanskje	da	vil	være	varsom	med	bare	å	slå	fast	at	42	000	færre	mennesker	står	i	kø,	underforstått	at	de	får	behandling.	Vi	har	nå	fått	avdekket	at	veldig	mange	av	dem	står	på	interne	lister	–	de	er	kommet	til	sykehuset	etter	henvisning,	er	blitt	henvist	videre	til	behandling,	er	blitt	tikket	ut	som	behandlet,	og	så	står	de	på	interne	lister.	Jeg	tror	det	illustrerer	at	vi	som	politikere	trekker	veldig	kraftfulle	konklusjoner	av	tall	som	selv	fagfolkene	er	varsomme	med	og	advarer	mot.	Det	skal	vi	ta	med	oss.	Få	politikere,	om	noen,	har	bidratt	mer	enn	Erna	Solberg,	Bent	Høie	og	Siv	Jensen	til	å	slå	fast	–	så	ingen	kan	misforstå	–	at	42	000	flere	har	fått	behandling.	Det	mener	jeg	at	statsministeren	nå	bør	korrigere.	Jeg	har	lyst	til	å	spørre:	Gjør	det	inntrykk	på	henne	når	fagfolkene	sier	at	her	er	det	tall	som	mer	er	til	for	å	glede	politikerne	enn	for	å	være	til	det	beste	for	pasientene?	Gjør	det	inntrykk	på	statsministeren?	Jeg	vet	at	det	vi	gjør	på	helsesektoren,	er	til	det	beste	for	pasientene.	Jeg	ser	gjennom	oppslag	i	avisene	at	folk	har	opplevd	rekordrask	behandling	mot	kreft.	Vi	ser	gjennomføringsevnen	det	er	på	pakkeforløp	for	kreft.	Vi	har	sagt	at	vi	skal	gå	igjennom	disse	tallene	for	å	se	om	det	er
# SEGMENT	nedgang	på	medianventetiden	på	syv	dager	fra	2013	til	2015	ja	altså	andre	tall	enner	de	vanlige	ventelistallene	som	sier	at	det	foregår	en	endring	ved	at	folk	behandles	raskere	nå	enn	de	gjorde	tidligere	men	så	tar	vi	på	alvor	de	oppslagene	som	har	vært	i	dagens	medisin	for	vi	mener	jo	at	det	ikke	er	riktig	at	du	skal	eee	bare	henvises	til	å	få	en	konsultasjon	eventuelt	en	kartlegging	for	også	vente	på	ny	form	for	behandling	et	av	de	viktigste	grepene	vi	gjør	for	nettopp	å	ikke	ha	det	det	er	jo	det	vi	har	gjort	med	pakkeforløp	for	kreft	for	der	r	ikke	det	bare	de	da	skal	du	først	henvises	til	eee	til	å	bli	undersøkt	for	om	du	har	kreft	ja	men	da	er	der	et	detaljert	pakkeforløp	som	forteller	hvor	raskt	du	skal	igjennom	og	forteller	hvilke	steg	på	veien	hom	an	organis	ere	seg	sånn	at	behandlingen	er	dette	med	pakkeforløpet	er	jo	en	av	de	tingene	denne	regjeringen	har	gjort	som	nye	ideer	for	hvordan	vi	kan	bruke	helsevesenet	på	en	bedre	måte	og	vi	jobber	jo	nå	med	å	innføre	det	på	flere	sykdomsbilder	enn	bare	på	på	kreftområdet	for	det	har	så	vellykkete	eee	erfaringer	men	vi	er	opptatt	av	at	vi	skal	gå	igjennom	derfor	vil	helsedirektoratet	få	et	oppdrag	fra	helsedepartementet	for	å	gå	igjennom	de	opplysningene	og	sjekke	om	noen	sykehus	faktisk	bryter	regelverket	ved	å	å	sette	folk	på	en	ny	liste	istedenfor	å	gå	direkte	over	til	behandling	når	man	har	karta	at	hvilken	behov	som	er	for	behandlingjonas	gahr	støre	til	oppfølgingsspørsmål	vær	så	god	president	jeg	må	jo	tolke	det	di	tin	at	statsministeren	kanskje	da	vil	være	varsom	med	å	bare	slå	fast	at	42000	mennesker	færre	står	i	kø	unnerforså	at	de	får	behandling	når	vi	nå	får	avdekket	at	veldig	mange	av	dem	står	på	interne	lister	at	de	er	kommet	på	sykehuset	til	henvisning	er	blitt	henvist	videre	til	behandling	jeg	er	blitt	tak	tikket	ut	som	behandlet	men	så	står	de	på	interne	lister	og	president	jeg	tror	det	illustrerer	at	det	at	vi	som	politikere	skal	sj	trekke	veldig	kraftfulle	konklusjoner	av	tall	som	selv	fagfolkene	er	varsomme	med	og	advare	mot	det	skal	vi	ta	med	og	få	politikere	om	noen	har	bidratt	mer	enn	dette	enn	erna	solberg	bent	høie	og	siv	jensen	med	å	slå	fast	så	ingen	kan	misforstå	at	42000	flere	har	fått	behandling	og	det	mener	jeg	statsministeren	nå	bør	korrigere	og	jeg	har	lyst	på	å	spørre	han	gjør	det	inntrykk	poenget	når	fagfolkene	sier	at	her	er	det	tall	som	mere	er	til	for	å	glede	politikerne	enn	være	til	det	beste	for	pasientene	gjør	det	inntrykk	på	statsministerenstatsminister	erna	solberg	vær	så	godjeg	vet	at	det	vi	gjør	på	helse	sektoren	til	det	beste	for	pasientene	jeg	ser	det	gje	når	jeg	sår	oppslaget	i	avisen	om	folk	som	har	opplevd	rekordrask	behandling	for	psykefåforbilder	f.eks.	på	kreft	når	vi	ser	gjennomføringsevnen	det	er
# RATIO 	 0.6885245901639344
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS	en	annen	måte.	Men	det	er	noen	som	blir	sendt	til	utredning	som	ikke	får	behandling	etterpå	fordi	de	ikke	skal	ha	behandling.	En	av	de	tingene	som	skjer	med	pakkeforløp,	f.eks.,	er	at	folk	blir	sendt	til	utredning.	Så	finner	man	ut	at	de	ikke	har	kreft,	det	er	kanskje	noe	annet,	som	skal	behandles	på	en	helt	annen	måte,	eller	som	kanskje	vil	gå	over	av	seg	selv.	Man	vil	få	flere	som	kommer	til	utredning	raskere.	Det	er	en	del	av	det	pakkeforløpet	for	kreft	f.eks.	gjør:	Noen	flere	som	viser	seg	ikke	å	ha	kreft	og	ikke	trenger	behandling,	kommer	til	utredning.	Vi	skal	gå	gjennom	disse	tallene,	men	jeg	merker	meg	nå	at	Arbeiderpartiet	forsøker	å	snakke	ned	et	resultat	av	den	politikken	vi	fører,	og	som	flere	indikatorer	faktisk	viser	veldig	tydelig.	Jeg	synes	det	er	leit	for	alle	i	helsesektoren	som	står	på	og	jobber	døgnet	rundt	for	å	skape	disse	resultatene.	Det	blir	oppfølgingsspørsmål	–	først	Tove	Karoline	Knutsen.	Statsministeren	og	helseministeren	har	nå	i	lang	tid	påstått	at	regjeringa	har	kuttet	helsekøene	med	over	40	000.	Dagens	Medisin	har	avslørt	at	tallet	er	uriktig,	at	minst	like	mange	pasienter	er	sluset	forbi	statistikken	og	inn	på	en	venteliste	som	ikke	kan	gjenfinnes	i	offentlige	tall,	og	at	andelen	behandlinger	for	dem	som	er	utredet,	har	gått	dramatisk	ned,	fra	37	pst.	til	15	pst.	Uansett	tall:	Det	snodige	er	at	Norsk	pasientregister	understreker	at	antall	ventende	–	eller	helsekøen,	som	statsministeren	gjerne	snakker	om	–	er	tall	som	verken	sier	noe	om	behandlingskapasitet	eller	kvalitet	i	helsetjenestene.	Helseministeren	og	statsministeren	har	trukket	opp	enkelttabeller	med	pinsett	og	holdt	dem	fram	for	å	kunne	tegne	et	glansbilde	av	egen	politikk,	og	helseministeren	har	ikke	endret	retorikk	etter	avsløringene	som	nå	har	kommet.	Mitt	spørsmål	er:	Vil	statsministeren	fremdeles,	som	helseministeren,	insistere	på	den	fortellingen	om	helsekøen	som	vi	har	hørt	til	nå,	eller	vil	det	som	er	avdekket,	endre	den	fortellingen?	Helsekøene	i	Helse-Norge	går	ned,	det	viser	alle	de	andre	indikatorene	også.	Om	de	har	gått	ned	så	mye,	er	spørsmålet	etter	Dagens	Medisins	oppslag.	Vi	skal	altså	foreta	en	kontroll	av	om	det	er	slik	at	sykehusene	faktisk	bryter	loven	og	regelverket	de	styres	av,	ved	å	føre	andre	typer	lister	og	ikke	få	folk	til	behandling.	Vi	er	opptatt	av	å	se	at	vi	faktisk	møter	mange	andre	kvalitetskriterier:	Det	å	få	kortere	tid	for	avklaring	av	om	man	er	syk	eller	ikke,	hvilken	sykdom	man	har,	det	å	jobbe	med	pakkeforløp,	det	å	jobbe	med	kvalitetsregister	og	systemer	fremover	–	som	bidrar	til	å	løfte	kvaliteten	–	er	en	like	viktig	del	av	dette.	Men	med	alle	styringssystemer	vil	det	av	og	til	være	noen	utslag	hvor	man	forsøker	å	tilpasse	seg	styringssystemet.	Det	er	ikke	noen	ny	debatt,	slik	har	det	vært	under	tidligere	regjeringer	også.	Vi	er	opptatt	av	å	løse	opp	i	dette,	for	norske	pasienter	som	trenger	behandling,	skal	ha	raskere	behandling.	Olaug	V.	Bollestad	–	til	oppfølgingsspørsmål.	Nye	tall	fra	Norsk	pasientregister	viser	at	i	denne	perioden	gjentar	problematikken	med	usynlige	ventelister	seg.	Dette	er	ikke	noe	nytt	i	norsk	helsevesen.	Kristelig	Folkeparti	deler	regjeringens	ambisjoner	om	at	flere	pasienter	skal	få	raskere	hjelp,	utredning	og	behandling.	Lengden	på	ventetiden	må	være	medisinsk	begrunnet	–	og	ingenting	annet.	Derfor	er	utviklingen	vi	nå	ser,	bekymringsfull.	Som	helseministeren	skriver:	«Bevisst	flytting	av	ventetiden	til	etter	første	konsultasjon,	for	å	innfri	fristen,	men	samtidig	gi	pasienten	den	reelle	ventetiden	etter,	er	i	strid	med	loven	og	ikke	akseptabelt.»	Ansvaret	for	dette	kan	vi	ikke	bare	legge	på	sykehusledelsen	og	de	ansatte.	Vi	er	nødt	til	å	se	på	systemene	og	om	kravene	virker	inn	på	prioriteringene	i	sykehus.	Ser	statsministeren	at	det	kunne	vært	hensiktsmessig	å	sette	medisinsk	begrunnede	frister	for	behandling	av	ulike	pasientgrupper,	nettopp	for	å	sikre	at	en	ikke	får	usynlige	ventelister?	Det	er	mulig	å	sette	ulike	medisinske	frister.	Det	som	er	vanskelig, ...
# SEGMENT	en	av	de	tingene	som	skjer	med	pakkeforløp	f.eks.	er	at	folk	blir	sendt	for	utredning	så	finner	man	ut	i	at	harike	kreft	det	er	kanskje	noe	annet	som	skal	behandles	på	en	helt	annen	måte	eller	som	kanskje	vil	gå	over	av	seg	selv	og	da	vil	du	altså	få	flere	som	kommer	til	utredning	raskere	eee	det	er	en	del	av	det	pakkeforløpene	på	kreft	f.eks.	gjør	er	at	noen	flere	kommer	til	utredning	som	derved	viser	seg	ikke	har	kreft	og	ikke	trenger	behandling	men	vi	skal	gå	igjennom	de	tallene	men	jeg	merka	meg	nå	at	arbeiderpartiet	forsøker	å	snakke	ned	et	resultat	av	den	politikken	som	vi	fører	som	flere	andre	indikatorer	faktisk	viser	seg	veldig	tydelig	og	jeg	syns	det	er	leit	for	alle	de	i	helsesektoren	som	står	på	og	jobber	døgnet	rundt	for	å	skape	disse	resultatene	det	blir	gitt	anledning	til	tilleggsspørsmål	første	tilleggsspørsmål	er	fra	representanten	tove	karoline	knutsen	deretter	olaug	bollestad	knutsen	vær	så	god	ja	president	eee	statsministeren	og	helseministeren	har	jo	i	lang	tid	nå	påstått	at	regjeringa	har	kutta	helsekøen	over	eee	40000	dagens	medisin	har	nå	avslørt	at	det	tall	er	uriktig	og	at	minst	like	mange	pasienter	slusa	forbistatistikken	og	inn	på	en	venteliste	som	ikke	kan	gjenfinnes	i	offentlige	tall	og	at	andelen	behandlinger	av	de	som	er	utreda	har	gått	dramatisk	ned	fra	syvogtredve	prosent	til	15%	men	noensett	tall	det	snodige	er	jo	at	norsk	eee	pasientregister	understreker	at	antall	ventene	eller	helsekøen	som	statsministeren	gjerne	snakker	om	er	et	tall	som	verken	sier	noe	om	behandlingskapasitet	eller	kvalitet	i	helsetjenestene	eee	helseministeren	og	statsministeren	har	trukket	opp	enkelttabeller	med	pinsett	og	holdt	den	fram	for	å	kunne	tegne	et	glandsbilde	av	egen	politikk	eee	og	helseministeren	har	ikke	endra	retorikk	etter	de	avsløringene	som	nå	er	kommen	mitt	spørsmål	er	vil	også	statsministeren	fremdeles	som	helseministeren	insistere	på	den	fortellinga	om	helsekøen	som	vi	har	hørt	til	nå	eller	det	som	vil	det	som	er	avdekka	endre	den	fortellinga	statsminister	erna	solberg	vær	så	god	eee	president	helsekvøen	i	helsenorge	går	ned	det	viser	alle	de	andre	indikatorene	også	om	de	har	gått	ned	så	mye	er	spørsmålet	etter	dagens	næringsliv	eee	dagens	medisinske	oppslag	eee	og	det	skal	vi	altså	foreta	en	kontroll	og	vi	skal	foreta	en	kontroll	av	om	det	er	slik	at	sykehusene	eee	ee	faktisk	bryter	loven	og	bryter	regelverket	de	styres	un	dar	ved	å	føre	andre	typer	lister	og	ikke	levere	folk	til	behandling	men	vi	er	opptatt	av	å	se	at	vi	faktisk	på	mange	andre	kriterier	har	møter	kvalitetskriteriene	også	det	å	få	kortere	aee	tid	for	avklaring	om	du	er	syk	eller	ikke	eee	om	hva	slags	sykdom	du	har	det	å	jobbe	med	pakkeforløp	det	å	jobbe	med	kvalitetsregisteret	og	systemer	fremover	som	bidrar	til	å	løfte	mer	kvalitet	er	en	like	viktig	del	av	dette	men	det	er	sånn	at	med	alle	styringssystemer	så	vil	det	være	noen	utslag	av	og	til	hvor	man	forsøker	å	eee	tilpasse	seg	styringssystemet	det	er	ikke	noe	ny	debatt	det	hadde	vært	under	tidligere	regjeringer	også	men	vi	er	altså	opptatt	av	å	løse	opp	i	dette	for	norske	norske	pasienter	som	trenger	behandling	skal	ha	raskere	behandlingneste	tilleggsspørsmål	er	fra	representanten	olaug	bollestad	deretter	kjersti	toppe	bollestad	vær	så	god	takk	president	nye	tall	ifra	pasient	ee	norsk	pasientregister	viser	at	i	denne	perioden	så	gjentar	problematikken	seg	om	usynlige	ventelister	dette	er	ikke	noe	nytt	i	norsk	helsevesen	krf	med	deler	regjeringen	sine	ambisjoner	om	at	flere	pasienter	skal	få	raskere	hjelp	og	utredning	og	behandling	lengden	på	ventetida	med	å	være	be	medisinsk	begrunna	og	ingenting	annet	derfor	er	utviklingen	vi	nå	ser	bekymringsfullt	som	s	helseministeren	skriver	bevisst	flytting	av	ventetid	etter	fyrste	konsultasjon	f	for	å	innfri	fristen	men	samtidig	gir	pasienten	reelle	ventetid	etter	er	i	strid	med	loven	og	ikke	akseptabelt	ansvaret	for	dette	kan	vi	ikke	bare	legge	på	sykehusledelsen	og	de	ansatte	vi	er	nødt	for	å	se	på	system	emene	og	om	krav	å	virk ...
# RATIO 	 0.5764705882352941
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS	at	det	er	en	utfordring	særlig	med	folk	som	har	sammensatte	symptomer	og	annet.	Det	er	en	av	grunnene	til	at	vi	på	Stortinget	i	forrige	periode	ivret	for	diagnosesentre,	som	gjør	at	man	ikke	gir	slipp	på	en	pasient	som	kommer	med	en	ikke	avklart	sykdom,	men	at	man	faktisk	avklarer	hvordan	den	sykdommen	er.	Jeg	har	vært	og	besøkt	noen	av	de	første	diagnosesentrene.	De	gjør	en	fantastisk	jobb.	Det	er	en	lettelse	for	de	pasientene	som	har	vært	der,	og	som	kanskje	opplever	å	få	beskjed	om	at	de	ikke	har	kreft,	men	en	annen	type	sykdom.	Så	kan	behandlingsløpet	gå,	istedenfor	at	de	blir	sendt	via	fastlegen	til	nye	henvisninger	for	hver	enkelt	utredning.	Derfor	jobber	vi	også	med	å	etablere	diagnosesentre	på	andre	områder,	bl.a.	det	som	vi	kaller	muskelutmattelse	–	den	typen	immunnedsettelser	–	som	er	representert	ved	en	av	de	svakeste	gruppene	i	helsevesenet,	men	som	oftest	opplever	ikke	å	få	svar.	Derfor	er	det	viktig	hvordan	vi	organiserer	inne	i	sykehusene,	også	for	å	sørge	for	at	vi	får	et	ordentlig	svar	på	det	som	ikke	er	helt	avklarte	sykdommer.	Ketil	Kjenseth	–	til	oppfølgingsspørsmål.	Fra	2002,	da	staten	overtok	sykehusene,	og	fram	til	i	dag	har	sykehusbudsjettet	vokst	fra	50	mrd.	til	140	mrd.	kr	årlig.	Lønns-	og	kostnadsvekst	og	flere	innbyggere	er	en	naturlig	del	av	forklaringen,	men	et	stadig	mer	intrikat	byråkrati	for	å	holde	orden	på	tellekanter,	ventetider,	rapportering	og	papirer	er	også	en	stor	del	av	veksten.	Mens	Arbeiderpartiet	og	Høyre	knives	om	å	forklare	oss	om	vi	står	i	feil	kø,	og	detaljregulere	sykehussektoren	med	oppdrag,	DRG-er,	rapportering	og	tilhørende	byråkrati,	er	Venstres	svar	å	satse	mer	på	forebygging,	folkehelse	og	velferdsteknologi,	så	folk	slipper	å	bli	venteliste-	eller	svingdørspasienter.	De	første	evalueringene	av	det	store	nasjonale	prosjektet	med	velferdsteknologi	rettet	mot	kronikere	tyder	på	en	halvering	av	sykehusinnleggelser.	Vil	statsministeren	bli	med	Venstre	på	å	satse	litt	mer	på	folkehelse	og	forebygging	og	litt	mindre	på	fritt	valg	av	usynlige	ventelister?	Regjeringen	mener	at	det	forebyggende	arbeidet	er	det	absolutt	viktigste	i	det	lange	løp	for	å	gjøre	noe	med	helsen.	Det	å	sørge	for	at	folk	kan	mestre	sin	egen	helse	på	en	bedre	måte	kan	i	stor	grad	avlaste	en	del	av	de	offentlige	helsetilbudene.	Det	vi	gjør	bl.a.	ved	at	sykepleierne	får	flere	muligheter	for	spesialisering,	at	de	får	være	i	kommunene	og	ha	ansvar	for	enkelte	grupper,	gir	også	en	lettere	oppfølging,	og	folk	kan	bo	hjemme.	Alt	dette	er	en	del	av	den	meldingen	vi	hadde	om	primærhelsetjenesten,	som	altså	skal	være	forebyggende,	men	også	avlastende,	for	at	de	som	har	kroniske	sykdommer,	får	bedre	hjelp	uten	at	de	skal	inn	i	sykehusene.	Det	blir	en	oppbygging	av	den	typen	helsetjenester	ute	i	kommunene	i	årene	som	kommer.	Velferdsteknologi	er	også	viktig,	ikke	minst	for	å	sørge	for	at	eldre	mennesker	skal	kunne	klare	å	bo	lenger	hjemme	og	føle	mer	kontroll	og	mer	verdighet	i	sitt	eget	liv	når	de	får	hjelp.	Men	vi	må	behandle	folk	som	har	fått	kreft,	på	sykehus,	og	vi	må	også	behandle	lårhalsbrudd	og	annet	på	sykehus.	Så	det	går	ikke	an	å	la	være	å	si	at	vi	ikke	skal	gjøre	det.	Vi	må	også	gjøre	det.	Audun	Lysbakken	–	til	oppfølgingsspørsmål.	Det	Dagens	Medisin	har	avdekket,	er	en	skandale,	og	jeg	synes	det	er	oppsiktsvekkende	at	statsministeren	tar	det	med	så	stor	ro	som	disse	svarene	gir	inntrykk	av.	Disse	svarene	har	en	smak	av	bortforklaring.	Vi	må	bort	fra	den	debatten	som	sånne	saker	alltid	ender	i,	nemlig	at	man	peker	på	individuelle	ledere	eller	spesielle	institusjoner	i	helsevesenet,	og	at	Høyre	og	Arbeiderpartiet	utveksler	gjensidige	beskyldninger.	Og	så	må	vi	snakke	om	det	systemet	som	skaper	sånne	skandaler.	Systemet	er	problemet,	og	i	Norge	har	vi	et	sykehussystem	med	omfattende	stykkprisfinansiering,	med	sterkt	politisk	press	for	å	få	ned	ventelistene	så	det	ser	bra	ut	for	helseministeren.	For	mye	rigges	etter	hva	vi	kan	måle,	i	stedet	for	etter	det	pasientene	har	behov	for.	Systemet	settes	for	oft ...
# SEGMENT	at	det	er	en	utfordring	særlig	med	folk	som	har	sammensatte	symptomer	og	annet	det	er	en	av	grunnene	til	at	vi	på	stortinget	forrige	periode	e	ivret	for	diagnosesentret	som	gjør	at	du	da	ikke	vil	slippe	på	på	en	pasient	som	kommer	med	en	med	en	ikke	avklart	sykdom	men	du	faktisk	avklarer	hvordan	den	sykdommen	er	jeg	har	hatti	besøkt	noen	av	de	første	diagnosesentrene	de	gjør	en	fantastisk	jobb	og	det	er	en	lettelse	for	de	pasientene	som	faktisk	har	vært	der	og	som	opplever	at	ja	kanskje	de	får	beskjed	om	at	de	ikke	har	kreft	men	de	har	en	annen	type	sykdom	og	så	kanne	behandlingsvep	på	gå	istedenfor	at	de	blir	sendt	via	fastlegggen	til	nye	henvisninger	for	hver	enkelt	eee	utredning	derfor	jobber	jo	vi	også	med	å	etablere	diagnosesentre	på	andre	områder	bl.a.	på	det	som	da	vi	kaller	altså	muskelutmattelse	den	typen	imune	og	eee	nedsettelser	som	er	en	av	de	svakeste	gruppene	i	helsevesenet	og	som	oftest	opplever	at	de	ikke	får	svar	derfor	så	er	det	viktig	hvordan	vi	organiserer	inn	i	sykehusene	også	for	å	sørge	for	at	vi	får	et	ordentlig	svar	på	det	som	ikke	er	helt	avklarte	sykdommer	og	neste	tilleggsspørsmål	er	fra	representanten	ketil	kjenseth	og	til	slutt	audun	lysbakken	kjenseth	vær	så	godtakk	president	fra	2002	da	staten	overtok	eee	sykehusene	og	fram	tid	i	dag	har	sykehusbudsjettet	vokst	fra	50	milliarder	til	140	milliarder	kroner	årlig	lønns	og	kostnadsvekst	av	flere	innbyggere	er	en	naturlig	del	av	forklaringen	men	et	stadig	mer	integrart	byråkrati	for	å	holde	orden	på	telekanter	ventetider	rapportering	og	papirer	er	også	en	stor	del	av	veksten	mens	arbeiderpartiet	og	høyre	knives	om	å	forklare	oss	om	det	står	i	feil	kø	detaljregulere	sykehussektoren	med	oppdrag	drger	rapportering	og	tilhørende	byråkrati	er	venstres	svar	å	satse	mer	på	forebygging	folkehelse	og	velferdsteknologi	så	folk	slipper	å	bli	ventelista	eller	svingders	pasient	de	første	elve	evalueringene	av	det	store	nasjonale	prosjektet	med	velferdsteknologi	retta	mot	kronikere	tyder	på	en	halvering	av	eee	sykehusinnleggelser	vil	statsministeren	bli	med	venstre	på	å	satse	litt	mer	på	folkehelse	og	forebygging	og	litt	mindre	på	frittvalget	av	ei	synlig	ventelistestatsminister	erna	solberg	vær	så	godsit	regjeringen	mener	at	det	forebyggende	arbeide	er	det	absolutt	viktigste	i	det	lange	løp	for	for	å	gjøre	noe	med	helse	og	det	å	sørge	for	at	folk	kan	mestre	sin	egen	helse	på	en	bedre	måte	kan	avlastedet	i	stor	grad	også	en	del	av	de	offentlige	helsetilbudene	det	vi	gjør	bl.a.	med	å	si	at	sykepleiere	bør	kunne	få	mer	muligheter	i	eee	på	spesialisering	og	være	i	kommunene	ha	ansvar	for	enkelte	grupper	pe	gir	oss	en	lettere	oppfølging	hvor	folk	kan	bo	hjemme	alt	dette	var	jo	en	del	av	av	eee	den	meldingen	vi	hadde	om	primærhelsetjenesten	som	altså	skal	være	forebyggende	men	også	avlastende	for	de	som	har	kroniske	sykdommer	får	bedre	hjelp	med	å	kunne	få	det	uten	at	de	skal	inn	i	spesialistsy	sykehusene	så	det	blir	jo	en	oppbygging	av	den	typen	helsetjenester	ute	i	kommunene	i	årene	så	k	ommer	velferdsteknologi	er	også	viktig	ikke	minst	for	å	sørge	for	at	eldre	mennesker	kan	kunne	klare	å	bo	lenger	i	hjemmet	og	følge	mer	kontroll	og	mer	verdighet	i	sitt	eget	liv	når	de	får	hjelpen	men	vi	må	også	behandle	folk	som	har	fått	kreft	på	sykehus	og	vi	må	også	behandle	lårehalsbrudd	og	annet	så	det	går	ikke	an	å	la	være	å	si	at	vi	ikke	skal	gjøre	det	vi	må	også	gjøre	detsiste	tilleggsspørsmål	er	ved	audun	lysbakken	lysbakken	vær	så	god	president	det	dagens	medisiner	her	avdekket	er	en	eee	skandale	og	jeg	eee	synes	det	er	oppsiktsvekkende	at	statsministeren	tar	det	med	så	stor	ro	som	disse	svarene	gir	inntrykk	av	disse	svarene	har	en	smak	abortforklaring	vi	må	bort	fra	den	debatten	som	sånne	saker	alltid	ender	i	nemlig	at	man	peker	på	individuelle	leder	eller	spesielle	institusjoner	i	helsevesenet	og	at	høyre	og	arbeiderpartiet	utveksler	gjensidige	beskyldninger	og	så	må	vi	snakke	om	det	systemet	som	skaper	sånne	skandaler	systemet	er	problemet	i	norge	har	vi	et	sykeh ...
# RATIO 	 0.7177033492822966
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS	områder	som	ikke	er	så	lette	å	ta	inn	i	det.	Vi	behandler	flere	i	norsk	helsevesen	i	dag	enn	vi	gjorde	tidligere.	Vi	gjør	det	bl.a.	fordi	vi	har	et	system	som	gjør	at	vi	får	incentiver	til	å	behandle	flere.	Vi	bruker	ressursene	på	en	mer	effektiv	måte	i	norsk	helsevesen	enn	det	vi	gjorde	tidligere.	Det	tror	jeg	ikke	vi	kan	komme	bort	fra.	Jeg	skjønner	at	SV	ønsker	et	helt
# SEGMENT	områder	som	ikke	er	så	lett	å	ta	inn	i	det	men	det	er	sånn	at	vi	behandler	flere	i	norsk	helsevesen	i	dag	enn	det	vi	gjorde	tidligere	vi	gjør	det	bl.a.	fordi	vi	har	et	system	som	gjør	at	du	får	eee	et	insentiv	til	å	behandle	flere	vi	bruker	ressursene	på	en	mer	effektiv	måte	i	norsk	helsevesen	enn	det	vi	gjorde	tidligere	eee	det	tror	jeg	ikke	vi	kan	komme	bort	fra	eee	jeg	skjønner	at	sv	ønsker	et	helt
# RATIO 	 0.759493670886076
# --------------
# CORPUS	annet	finansieringssystem,	de	ønsker	gjerne	ikke	å	se	hvilke	områder	det	er	utfordringer	på.	En	del	av	det	vi	gjør	når	vi	har	kontrollsystemer,	er	faktisk	å	sikre	at	pasientene	får	de	rettighetene	de	skal	ha,	at	vi	setter	pasienten	og	ikke	systemet	i	sentrum.	Det	SV	foreslår,	er	å	sette	profesjonene	i	sentrum	i	stedet	for	pasientene.	Det	synes	ikke	jeg	er	noen	god
# SEGMENT	annet	finansieringssystem	de	ønsker	gjerne	ikke	å	se	hvilke	områder	der	er	utfordringer	på	for	di	at	når	en	del	av	det	som	som	vi	gjør	når	vi	har	kontrollsystemet	ont	det	er	jo	faktisk	å	sikre	at	pasientene	får	de	rettighetene	de	skal	at	vi	setter	pasientene	i	sentrum	og	ikkesystemet	det	sv	foreslår	er	å	sette	profesjonene	i	sentrum	eee	istedenfor	pasientene	det	synes	ikke	er	noen	god
# RATIO 	 0.6617647058823529
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS	som	måtte	jobbe	gratis	som	vaskehjelp	og	ble	holdt	fanget.	Det	er	noen	av	enkeltmenneskene.	I	flere	av	historiene	som	Fafo-rapporten	beskriver,	kommer	det	fram	at	voksne	visste	–	eller	iallfall	hadde	en	anelse	om	–	hva	som	foregikk.	De	skjønte	at	den	unge	jenta	på	mottaket	ble	misbrukt	som	sexslave,	eller	at	den	unge	gutten	ble	tvunget	til	å	selge	narkotika,	men	de	gjorde	ingenting.	I	noen	tilfeller	var	barnevern	og	politi	varslet,	men	likevel	skriver	Fafo	at	ting	ikke	ble	gjort.	Det	er	totalt	uakseptabelt.	Derfor	er	mitt	spørsmål	til	statsministeren:	Hvilket	inntrykk	gjør	det	på	statsministeren	når	hun	hører	eller	leser	historier	om	at	barn	i	vårt	eget	land	blir	utnyttet	på	denne	måten?	Det	gjør	et	sterkt	inntrykk.	Det	gjør	et	inntrykk	også	fordi	det	viser	at	vi	ennå	ikke	klarer	å	hjelpe	alle	i	vårt	samfunn.	Det	er	helt	uakseptabelt	at	dette	forekommer,	og	det	er	helt	uakseptabelt	at	det	ikke	meldes	fra	om,	av	dem	som	eventuelt	har	mistanke	eller	annet,	at	barn	utnyttes,	at	man	har	menneskesmugling,	at	man	utnyttes	i	prostitusjon	eller	på	andre	områder.	Vi	vet	at	noe	av	det	viktigste	vi	kan	gjøre,	er	å	slåss	mot	bakmennene	og	systemene	som	er	knyttet	til	dette.	Veldig	mange	av	disse	systemene	knyttes	sammen	med	det	som	vi	også	ser	driver	arbeidslivskriminaliteten.	Det	vi	ser	nå,	er	at	det	samarbeidet	som	vi	gjør	på	arbeidslivskriminalitetsområdet,	avdekker	folk	som	jobber	til	en	minimumslønn,	som	jobber	på	dårlige	vilkår	–	ja,	nærmest	slavelignende	vilkår.	Derfor	er	det	så	viktig	at	vi	har	dette	samarbeidet	mellom	etatene,	som	kan	se	både	på	økonomi	og	på	skattebetalingen,	som	er	på	innvandringssiden	og	på	politisiden,	for	å	følge	med.	I	dette	tette	samarbeidet	har	man	avslørt	bakmenn	som	driver	med	det	vi	vil	kalle	menneskesmugling,	og	som	diversifiserer,	for	de	gjør	ofte	flere	forskjellige	ting	på	en	gang	–	de	er	blandet	inn	i	flere	kriminelle	nettverk.	Dette	kan	bidra	til	å	gjøre	noe	med	nettopp	menneskesmugling.	Så	er	det	viktig	at	vi	har	et	godt	støtteapparat	for	dem	som	finnes.	Der	vet	vi	at	vi	ikke	er	gode	nok,	også	fordi	det	ofte	er	et	spørsmål	om	bevisføring.	Det	er	ting	vi	alltid	må	se	bedre	på,	om	vi	kan	klare	å	få	bedre	oppfølgingstiltak	for	dem	som	har	vært	ofre,	og	som	det	avklares	at	har	vært	ofre	for	slavehandel	og	for	menneskesmuglere	og	utnyttelse	i	det	norske	samfunnet.	Jeg	vil	takke	statsministeren	for	svaret	og	engasjementet	hun	viser.	Det	er	ekstremt	viktig	at	vi	som	politikere	tar	et	større	ansvar,	og	i	denne	salen	tror	jeg	at	jeg	har	mast	kanskje	opp	mot	ti	ganger	på	justisministeren	for	å	få	en	handlingsplan,	for	den	forrige	gikk	ut	i	2014.	Det	ville	vært	koordinering	på	alle	de	områdene	som	statsministeren	er	opptatt	av.	Men	jeg	skal	love	statsministeren	at	gjennom	justiskomiteens	arbeid	har	vi	løftet	inn	flere	millioner	kroner	til	arbeid	for	politi,	støtteapparat	osv.	Et	viktig	vedtak	som	ble	fattet	i	denne	sal,	var	at	det	skulle	opprettes	menneskehandel-team	på	hvert	mottak	der	det	er	mindreårige	mellom	15	og	18	år.	På	Hvalstad	transittmottak	hadde	de	et	slikt	team,	og	bare	i	2011	identifiserte	de	26	mulige	ofre,	og	i	2012	identifiserte	de	42	mulige	ofre.	Altså	fikk	mange	barn	hjelp	på	grunn	av	de	teamene.	Nå	har	Stortinget	sagt	at	dette	skal	komme.	Men	mitt	spørsmål	er:	Hvordan	ligger	det	an	med	den	typen	arbeid?	Jeg	kan	ikke	svare	detaljert	på	hvor	langt	vi	er	kommet	når	det	gjelder	dette.	Det	er	viktig	at	de	som	jobber	på	mottakene,	har	kompetanse	på	disse	spørsmålene,	at	de	har	kompetanse	på	hvor	de	skal	henvende	seg,	og	hvem	de	skal	melde	til.	Det	er	også	viktig	at	man	er	tydelig	på	at	når	ungdom	og	barn	forsvinner	fra	mottak,	skal	det	igangsettes	politietterforskning.	Det	ligger	i	dagens	retningslinjer	at	det	skal	være	politietterforskning	av	de	sakene.	En	del	ganger	er	det	fordi	de	har	foreldre	som	er	et	annet	sted	–	det	vet	vi.	Vi	vet	også	at	mange	av	de	som	jobber	på	mottakene,	merker	seg	det	og	ser	at	noen	f.eks.	har	foreldre	som	har	kommet	til	Tyskland,	i	en	situasjon	hvor	de	er	f ...
# SEGMENT	som	måtte	jobbe	gratis	som	vaskehjelp	og	blei	holdt	fanga	det	er	noen	av	enkeltmenneskene	og	i	flere	av	historiene	som	faforapporten	eee	beskriver	så	kjem	det	fram	at	voksne	visste	eller	i	allfall	hadde	en	anelse	av	hva	som	foregikk	de	skjønte	at	en	unge	jenter	på	mottaket	blei	misbrukt	som	seklave	eller	at	den	unge	gutten	blei	tvunget	til	å	selge	narkotika	men	de	gjorde	ingenting	i	noen	tilfeller	så	var	au	barnevern	og	politi	varsla	men	likevel	så	skriver	fare	for	at	ting	blei	ikke	gjort	president	det	er	totalt	uakseptabelt	så	derfor	så	er	mitt	spørsmål	til	statsministeren	og	sin	inntrykk	gjør	statsministeren	når	hun	hører	historia	eller	lese	historie	om	barn	i	vor	eget	land	blir	utnytta	på	denne	måtenstatsminister	erna	solberg	vær	så	god	predent	det	gjør	et	sterkt	inntrykk	eee	det	gjør	et	inntrykk	ee	også	for	det	det	viser	at	vi	enneikke	klarer	å	hjelpe	alle	i	vårt	samfunn	og	det	er	helt	uakseptabelt	eee	at	dette	eee	forekommer	og	det	er	helt	uakseptabelt	at	det	ikke	meldes	fra	om	fra	de	som	eventuelt	har	mistanke	eller	annet	om	at	eee	fo	at	barn	utnyttes	at	eee	at	man	har	menneskesmugling	at	man	eee	utnyttes	i	posisjon	eller	andre	områder	så	vet	jo	vi	at	noe	av	den	viktigste	vi	kan	gjøre	er	også	slåss	mot	bakmennene	og	systemene	som	er	knyttet	til	dette	og	veldig	mange	av	disse	systemene	knyttet	sammen	il	det	som	vi	også	ser	på	som	driver	arbeidslivskriminaliteten	det	vi	ser	nå	er	at	det	samarbeidet	som	vi	gjør	på	arbeidslivskriminalitetsområdet	avdekker	folk	som	jobber	til	en	minimum	sjøn	som	jo	var	på	dårlige	vilkår	ja	så	ligger	i	nærmestesave	slavelignende	vilkår	og	derfor	så	er	det	så	viktig	at	vi	har	disse	samarbeidet	mellom	etatene	som	kan	se	både	på	økonomi	eee	på	skattebetalingen	som	er	på	innvandringssiden	og	som	er	på	politisiden	for	å	følge	med	og	at	vi	har	dette	tette	samarbeidet	i	det	samarbeidet	så	har	man	avslått	bakmenn	for	det	vi	vil	kaller	menneskesmogling	den	andre	siden	er	vikt	eee	og	og	som	som	diversifiserer	for	de	gjør	ofte	flere	forskjellige	ting	på	en	gang	de	er	blandet	inn	i	flere	kriminelle	kriminelle	nettverk	og	eee	det	kan	bidra	til	å	å	å	gjøre	noe	med	med	nettopp	eee	menneskesmugling	så	er	det	viktig	at	vi	har	et	godt	støtte	apparat	for	de	som	finnes	der	vet	at	vi	ikke	er	gode	nok	også	fordi	at	det	ofte	er	et	spørsmål	om	bevisføring	eee	det	er	ting	vi	alltid	må	se	bedre	på	om	vi	kan	klare	å	få	bedre	oppfølgingstiltak	for	de	som	har	vært	ofre	og	som	avklares	at	d	t	har	vært	ofre	for	slavehandel	og	for	for	menneskesmugler	og	utnyttelse	i	det	norske	samfunnet	kjell	ingolf	ropstad	til	oppfølgingsspørsmål	vær	så	god	gode	president	ee	f	jeg	vil	takke	statsministeren	for	svaret	og	for	engasjement	å	vise	det	er	ekstremt	viktig	at	vi	som	politikere	tar	et	større	ansvar	og	i	denne	salen	så	drarr	jeg	mast	kanskje	opp	mot	ti	ganger	president	eee	på	justisministeren	for	å	få	en	handlingsplan	for	den	forrige	gikk	ut	i	totusenogfr	jorten	det	ville	vært	koordinering	på	alle	de	områdene	som	statsministeren	er	opptatt	av	men	jeg	skal	love	statsministeren	at	gjennom	gjennom	justiskomiteens	arbeid	så	har	vi	løfta	inn	flere	millioner	til	arbeid	for	politi	å	få	støtteapparatet	osv.	og	et	viktig	vedtak	som	ble	fatta	i	denne	sal	var	at	det	skulle	ko	opprettes	menneskehandelteam	på	hvert	mottak	eee	f	der	det	er	mindre	år	mellom	15	og	18	år	eee	på	valstad	transittmottak	så	hadde	de	et	sånt	team	og	bare	i	2011	så	ide	identifiserte	de	26	mulige	ofre	og	i	2012	så	identifiserte	de	42	mulige	ofre	altså	mange	mennesker	eller	barn	fikk	hjelp	pga.	de	mo	eee	de	i	timene	nå	har	stortinget	sagt	at	dette	skal	komme	men	mitt	spørsmål	er	åssen	ligger	det	an	med	den	type	arbeid	statsminister	erna	solberg	vær	så	god	president	det	kan	jeg	ikke	svare	detaljert	på	hvor	langt	vi	er	oe	hvor	langt	vi	er	kommet	i	forhold	til	dette	det	er	viktig	å	og	eee	det	er	viktig	at	de	som	jobber	på	mottakene	også	har	kompetanse	på	disse	spørsmålene	at	de	har	kompetanse	for	hvor	de	skal	henvende	seg	hvem	de	skal	melde	til	og	det	er	viktig	at	man	o ...
# RATIO 	 0.6766917293233083
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS	ganske	ødeleggende	for	disse	barna,	og	kanskje	er	det	flere	enn	dem	vi	blir	opplyst	om	gjennom	denne	avisreportasjen.	Det	spesielle	er	at	disse	er	allerede	kjent	i	sektoren.	De	er	oppdaget	og	sett.	Statsministeren	og	Statsministerens	kontor	har	ansvaret	for	å	koordinere	tiltak	mellom	departementene.	Disse	barna	trenger	tiltak	fra	flere	departementer,	og	de	trenger	tiltak	som	virker,	og	som	er	koordinerte.	Det	har	bl.a.	forlikspartiene	og	Arbeiderpartiet	lagt	inn	i	forliket	om	mottak	av	flyktninger.	Hva	gjør	statsministeren	for	å	koordinere	tiltakene	for	disse	barna	mellom	departementene?	Statsministerens	oppgave	er	å	utpeke	hvilket	departement	som	har	koordineringsansvaret	for	det.	Er	barna	under	15	år,	er	det	barne-	og	familieministeren	som	har	det	helhetlige	ansvaret	for	det	tiltaket	som	gjøres.	Er	barna	over	15	år,	er	ansvaret	mellom	Justis-	og	beredskapsdepartementet	og	Barne-,	likestillings-	og	inkluderingsdepartementet.	Det	gjøres	viktig	arbeid	i	samhandlingen	mellom	disse	to	departementene	på	kompetanse,	kunnskap	og	ikke	bare	på	menneskesmugling	knyttet	til	de	som	er	barn,	for	dette	er	også	et	spørsmål	for	en	del	voksne,	det	er	et	spørsmål	for	en	del	kvinner.	Så	slavehandel	og	slavelignende	tilstander	skjer	også	blant	voksne	som	har	kommet	hit	på	ulike	måter.	Særlig	er	det	vanskelig	når	det	gjelder	veldig	mange	av	dem	som	ikke	lenger	har	opphold,	og	som	dermed	oppholder	seg	ulovlig	i	Norge,	og	som	står	i	en	veldig	sårbar	situasjon	for	å	kunne	bli	utnyttet	til	slavelignende	arbeid.	Marit	Arnstad	–	til	oppfølgingsspørsmål.	Som	flere	har	pekt	på,	er	mange	av	de	barna	som	dette	gjelder,	barn	som	har	bodd,	eller	som	bor	i	asylmottak.	Vi	kan	slå	fast	at	langvarig	opphold	i	asylmottak	er	ikke	bra	for	barn.	De	forsvinningene	fra	asylmottak	vi	har	sett,	er	også	veldig	problematisk.	Når	det	gjelder	det	å	få	bosatt	barn	i	asylmottak,	er	det	faktisk	det	eneste	området	der	det	er	kø,	og	årsaken	til	det	er	finansieringen.	Årsaken	til	det	er	at	kommunene	ikke	vil	bosette,	fordi	storsamfunnet	ikke	stiller	opp	med	den	finansieringen	som	trengs.	Kommunene	har	ikke	noen	egen	pott	til	å	bosette,	heller	ikke	til	å	bosette	barn.	Spørsmålet	mitt	er	rett	og	slett:	Hva	vil	statsministeren	gjøre	for	å	få	enslige	mindreårige	asylsøkere	raskere	bosatt	i	kommunene	og	bedre	ivaretatt	også	av	det	lokale	barnevernet,	og	hvordan	vil	en	bidra	til	en	bedre	finansiering	for	å	få	til	det?	Vi	ser	nå	heldigvis	at	bosettingstallene	for	de	yngste	enslige	mindreårige	øker	betydelig	ute	i	kommunene,	og	tilstrømningen	er	noe	mindre.	Derfor	er	det	en	litt	bedre	balanse	i	situasjonen	for	øyeblikket.	Det	er	god	barnefaglig	kompetanse	på	de	institusjonene	som	barn	under	15	år	er	på.	Det	er	institusjoner	i	barnevernets	regi,	og	som	har	god	oppfølging	av	dem.	Vi	har	foreslått	overfor	KS	–	og	vært	i	forhandlinger	med	KS	om	–	å	innføre	en	mer	stykkprisorientert	modell	for	dette,	slik	vi	har	for	andre	som	bosettes.	Den	refusjonsordningen	som	vi	har	i	dag,	har	den	utfordringen	ved	seg	at	man	da	får	refundert	uansett	hvilke	tiltak	man	legger	inn.	Det	betyr	også	at	man	har	et	veldig	feil	incentiv	til	å	øke	på	med	tiltak	som	kanskje	ikke	hadde	vært	nødvendig,	eller	til	ikke	nødvendigvis	å	være	kritisk	nok	til	hvilke	tiltak	man	gjennomfører,	og	om	de	er	de	beste.	Vi	mener	at	det	bør	være	en	mulighet	for	kommunene	som	er	gode	på	dette,	til	faktisk	–	når	de	får	en	stykkprisfinansiering	av	hver	bosetting,	som	skal	ta	høyde	for	de	store	kostnadene	–	å	tjene	på	det	til	andre	oppgaver	på	den	bosettingen.	Karin	Andersen	–	til	oppfølgingsspørsmål.	Vi	kan	prate	om	menneskehandel,	men	hvis	en	ikke	er	i	stand	til	å	reagere	i	enkeltsakene,	så	hjelper	det	lite.	Når	pågår	saken	om	Yasmin,	som	som	10-åring	ble	foreldreløs,	og	gjennom	15	år	har	vært	utsatt	for	menneskehandel	og	prostitusjon	i	mange	land.	Hun	kom	til	Norge	og	klarte	å	rømme	til	et	krisesenter,	men	nå	bruker	Norge	Dublin-reglene	for	å	kaste	henne	ut	til	Ungarn,	der	vi	veit	at	det	ikke	akkurat	er	«velkommen	hit»	til	menne ...
# SEGMENT	eee	ødeleggende	for	disse	barna	og	kanskje	flere	enn	det	vi	får	eee	opplyst	gjennom	den	avisreportasjen	det	spesielle	er	at	disse	er	allerede	kjent	i	sektoren	de	er	oppdaga	og	de	er	sett	og	statsministeren	har	og	statsministerens	kontor	har	ansvar	for	å	koordinere	tiltak	mellom	departementene	disse	barna	trenger	tiltak	fra	flere	departementer	og	de	trenger	tiltak	som	virker	og	som	er	koordinert	det	har	eee	bl.a.	forlikspartiene	og	arbeiderpartiet	lagt	inn	i	den	enigheten	som	er	på	eee	forliksavtalen	om	mottak	av	flyktninger	hva	gjør	statsministeren	for	å	koordinere	tiltakene	for	disse	barna	mellom	departementene	statsminister	erna	solberg	vær	så	godstatsministerens	oppgave	er	å	utpeke	hvilket	departement	som	har	koordineringsansvaret	for	det	er	barna	under	15	år	så	er	det	barne	e	så	er	det	barne	og	familieministeren	som	har	helhetlig	ansvar	for	det	tiltaket	som	gjøres	er	de	over	eee	over	eee	15	år	så	er	det	mellom	justisdepartementet	og	eee	og	barne	og	familiedepartementet	eee	og	og	det	gjøres	jo	da	eee	viktig	arbeid	i	samhandlingen	mellom	disse	to	departementene	på	kompetanse	på	kunnskap	og	på	ikke	bare	på	menneskesmuling	knyttet	til	de	som	er	barn	for	dette	er	jo	også	et	spørsmål	for	en	del	voksne	det	er	en	del	spørsmål	for	kvinner	eee	så	slaver	handel	eee	og	slav	eee	lignende	eee	tilstande	eee	det	skjer	også	blant	voksne	som	har	kommet	til	å	ha	ulike	på	ulike	måter	og	særlig	er	det	vanskelig	i	forhold	til	veldig	mange	av	de	som	er	eee	ikke	lengre	har	opphold	dermed	oppholder	seg	ulovlig	i	norge	og	som	står	i	en	veldig	sårbar	situasjon	for	å	kunne	bli	utnyttet	til	eee	slavelignende	arbeidneste	tilleggsspørsmål	er	fra	representanten	marit	arnstad	eee	og	deretter	karin	andersen	arnstad	vær	så	god	president	eee	som	flere	har	pekt	på	så	er	det	mange	av	de	barna	det	her	gjelder	er	barn	som	har	bodd	i	asylmottak	eller	som	bor	i	asylmottak	eee	og	vi	kan	jo	slå	fast	at	langvarig	opphold	i	asylmottak	er	ikke	bra	for	barn	eee	og	det	forsvinningene	vi	har	sett	ifra	asylmottak	er	også	veldig	problematisk	eee	så	er	det	jo	sånn	at	det	å	få	bosatt	barn	i	asylmottak	det	er	faktisk	det	eneste	område	der	det	er	kø	og	årsaken	til	det	er	finansieringa	årsaken	til	det	er	at	kommunene	ikke	vil	bosette	fordi	storsamfunnet	ikke	stiller	opp	med	den	finansieringa	som	trengs	eee	det	finnes	eee	ikke	kommunene	har	ikke	noe	egen	pott	til	å	bosette	heller	ikke	bosette	barn	så	spørsmålet	mitt	rett	og	slett	hva	vil	statsministeren	gjøre	for	å	få	enslige	mindreårige	asylsøkere	raskere	bosatt	i	kommunene	og	bedre	ivaretatt	også	av	det	lokale	barnevernet	og	hvordan	vil	en	bidra	til	en	bedre	finansiering	for	å	få	til	detstatsminister	erna	solberg	vær	så	god	president	vi	ser	nå	heldigvis	at	bosetningstallene	for	de	yngste	jenslige	mindreårigene	eee	øker	betydelig	ute	i	kommunene	og	tilstrømningen	er	noe	mindre	derfor	så	er	det	en	litt	bedre	balanse	i	i	situasjonen	for	øyeblikket	eee	nå	er	det	god	barnefaglig	kompetanse	på	de	eee	institusjonene	som	barn	eee	som	barn	under	15	år	er	på	det	er	institusjoner	i	barnevernets	regi	og	som	har	god	oppfølging	eee	av	de	men	eee	det	som	for	meg	altså	vi	har	foreslått	overfor	k	ks	og	vi	har	vært	i	forhandlinger	med	ks	om	å	innføre	en	en	mer	stykkeprisorientert	modell	for	dette	slik	som	vi	har	for	andre	eee	som	bosettes	eee	det	som	den	refusjonsordningen	som	vi	har	i	dag	den	har	den	utfordringen	ved	seg	at	at	du	da	re	får	refundert	uansett	hvilke	tiltak	du	legger	inn	eee	og	da	betyr	det	at	du	også	har	en	veldig	feil	insentiv	til	kanskje	å	øke	på	med	tiltak	som	ikke	hadde	vært	nødvendig	eller	ikke	nødvendigvis	være	kritisk	nok	på	hvilke	tiltak	man	gjennomfører	om	de	ir	de	de	beste	vi	mener	at	det	bør	være	en	mulighet	for	kommuner	som	er	gode	på	dette	og	faktisk	eee	når	di	får	n	syprisfinansiering	av	hver	bosetning	som	skal	ta	høyde	for	de	store	ukostnadenefaktisk	tjene	på	at	det	til	andre	oppgaver	og	den	boset	og	da	er	siste	tilleggsspørsmål	fra	representanten	karin	andersen	andersen	vær	så	god	ja	president	vi	kan	prate ...
# RATIO 	 0.6168224299065421
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS	kommunestyrerepresentanter	og	innbyggere.	Folk	stemmer	nei	og	atter	nei	i	folkeavstemninger.	Omtalen	av	reformen	varierer	mellom	«reformen	vakler	videre»,	«det	er	fiasko»	eller	«det	er	kaos».	Men	kommunalministeren	er	likevel	tilfreds.	Han	mener	prosessene	er	gode	og	at	det	tydelige	nei-flertallet	i	et	stort	flertall	av	kommunene	er	som	forventet.	Deler	statsministeren	kommunalministerens	vurdering	av	at	reformarbeidet	er	vellykket,	og	at	den	massive	motstanden	i	et	stort	flertall	av	folkeavstemningene	er	som	forventet?	At	det	i	folkeavstemninger	kan	bli	et	stort	nei-flertall	en	del	steder,	er	som	forventet.	Dette	har	vi	vært	gjennom	mange	ganger	før.	Det	er	en	krevende	operasjon	å	argumentere	for	forandring.	Det	er	lettere	å	si	ja	til	status	quo.	Jeg	kjenner	noen	av	disse	kommunene	–	Eidfjord	ble	nevnt	bl.a.	Det	er	selvfølgelig	at	når	en	av	landets	rikeste	kommuner	skal	dele	pengene	med	noen	ikke	så	rike	kommuner,	er	det	ikke	sånn	at	folket	går	jublende	av	sted	for	å	stemme	for	det.	Men	de	burde	minnes	om	at	de	også	lovet	at	de	skulle	gjøre	denne	kommunesammenslåingen	som	en	konsekvens	av	at	vi	bygget	Hardangerbroen.	Det	var	faktisk	en	av	premissene	som	de	samme	kommunene	solgte	inn,	den	gangen	vi	fra	regjeringen	for	litt	over	ti	år	siden	fremmet	Hardangerbroen,	for	det	var	så	viktig	for	å	ha	felles	bo-	og	arbeidsmarkedsregion.	Den	gangen	var	det	en	hindring.	Jeg	mener	at	det	er	forventet	at	vi	kommer	til	å	få	mange	nei.	Men	så	er	jeg	glad	for	at	det	var	mange	spenstige	forsøk.	For	eksempel	var	det	mange	store	regionskommuner	som	ble	forsøkt	bygget.	Det	var	tiden	sannsynligvis	umoden	for,	og	det	viser	reaksjonen	på	det.	Samtidig	ser	vi	at	det	er	mange	steder	hvor	de	mindre	kommunene	ser	seg	tjent	med	å	slå	seg	sammen,	fordi	de	kanskje	ser	at	skal	de	gi	et	godt	faglig	tilbud	til	sine	innbyggere	på	de	kritiske	områdene	for	dem	som	trenger	mest	hjelp,	er	det	riktig	å	slå	seg	sammen.	Så	har	vi	noen	utfordringer	på	noen	områder,	som	dreier	seg	om	at	det	er	noen	kommuner	som	har	sagt	ja,	og	noen	som	har	sagt	nei,	og	som	egentlig	henger	sammen.	Det	er	et	spørsmål	som	vi	er	nødt	til	å	ta	stilling	til	etter	hvert.	Når	statsministeren	sier	at	enkelte	steder	har	sagt	nei,	er	det	å	underdrive.	Det	er	87	kommuner	som	har	sagt	nei,	og	det	er	20	har	sagt	ja.	Velferdstjenester	som	eldreomsorg	og	skole	nær	folk	betyr	mye	for	mange.	Folk	har	solid	erfaring	med	at	sammenslåing	betyr	sentralisering.	Det	er	det	som	gjør	at	folk	stemmer	nei	til	sammenslåing	av	kommuner.	Alle	undersøkelser	viser	at	folk	i	mindre	kommuner	er	godt	fornøyd	med	egen	kommune	og	egen	velferd.	Som	et	argument	for	at	det	nå	trengs	endring,	har	Høyre	vist	til	at	Høyre	som	parti	i	30	år	har	jobbet	for	kommunesammenslåing.	Det	har	ikke	slått	statsministeren	at	grunnen	til	at	partiet	ikke	har	lyktes,	er	at	argumentene	for	sammenslåing	ikke	er	gode	nok?	Etter	30	års	mislykket	arbeid	for	kommunesammenslåing	må	en	kunne	spørre	seg	om	statsministeren	noen	gang	har	reflektert	over	det	–	at	større	kommuner	kanskje	ikke	er	det	eneste	saliggjørende,	og	at	folk	ikke	ser	på	det	som	svaret	for	å	få	gode	velferdstjenester	innenfor	eldreomsorg,	helse	og	skole?	Nå	er	situasjonen	at	det	er	46	kommuner	som	har	sagt	ja	ved	folkeavstemninger,	og	109	har	sagt	nei.	Det	er	de	tallene	vi	sitter	med.	Det	er	nok	et	litt	annet	bilde	enn	de	tallene	Marit	Arnstad	nevnte,	selv	om	det	er	et	stort	nei-flertall.	Det	har	vært	en	litt	forvirrende	meny	man	skulle	votere	over	enkelte	steder.	Men	vi	vet	også	at	vi	har	18	kommuner	som	har	vedtatt	sammenslåinger	–	6	sammenslåinger	totalt.	Det	betyr	at	man	er	godt	på	vei.	Jeg	mener	at	det	at	vi	er	noe	forut	for	folkemeningen	av	og	til,	kjennetegner	et	parti	som	er	opptatt	av	å	løse	problemene	for	fremtiden.	Vi	er	opptatt	av	at	vi	skal	sørge	for	at	Norge	blir	et	godt	sted	å	bo	fremover.	Mye	av	denne	regjeringens	arbeid	dreier	seg	om	å	sikre	fremtiden	for	velferdsstaten	Norge.	Det	dreier	seg	også	om	å	sørge	for	at	vi	har	respekt	for	fagkompetanse,	og	respekt	f ...
# ...
# SEGMENT	og	ekte	eee	samboend	og	ektefelles	økonomi	betydelig	i	tillegg	til	minstepensjonistenes	økonomi	og	de	huvodaas	i	eee	budsjettet	også	når	det	gjelder	inntektsutviklingen	til	pensjonistene	så	kan	jeg	vise	til	en	utmerket	rapport	under	pensjonspolitiske	råd	eee	som	ble	offentliggjort	i	går	som	vister	en	formidabel	inntektsutvikling	for	pensjonistene	de	siste	årene	og	det	her	anbefalt	lesning	for	alle	som	er	interessert	ja	takk	resident	president	spørsmålet	gjaldt	eee	fordelingsvirkninger	men	eee	nok	om	det	budsjettet	er	jo	feil	timing	i	forhold	til	trygdeoppgjøret	og	jeg	har	lyst	til	å	vise	til	budsjetthøringa	for	eee	i	fjor	tj	eee	budsjett	2016	da	advarte	pensjonistforbundet	mot	den	nye	budsjettpraksisen	eee	i	budsjettinnstillinga	merka	regjeringspartiene	og	venstre	seg	at	ny	budsjetteringsrunde	ikke	skulle	påvirke	gjennomføring	av	trygdeoppgjørene	så	viser	det	seg	at	gjennomføringa	av	trygdeoppgjøret	tross	forsikringa	fra	flertallet	ble	endret	på	et	svært	vesentlig	punkt	det	kommer	ikke	lenger	til	stortinget	på	samme	måte	som	før	det	er	veleee	vanlig	praksis	at	merknader	fra	regjeringspartiene	sjekkes	ut	med	angjeldende	statsråd	betyr	det	at	denne	forsikringa	fra	flertallspartiene	slapp	igjennom	ven	glipp	eller	er	det	ulikt	syn	mellom	qqq	regjeringa	og	stortingsgruppen	i	denne	saken	eller	er	det	fordi	regjeringa	vil	forhindrer	at	frp	nok	en	gang	kjører	dobbeltspill	om	pensjoner	i	stortingetstatsråd	hauglie	president	her	er	det	så	mange	det	her	er	det	så	mange	premisser	i	spørsmålet	at	jeg	vet	nesten	ikke	hvor	jeg	skal	begynne	for	det	første	så	ser	vi	at	inntektsutviklingen	for	pensjonistene	har	vært	god	vi	ser	at	kjøpekraften	nå	har	gått	ned	pga.	eee	fordi	lønnsoppgjørene	for	øvrig	eee	har	gått	ned	men	pensjonistisk	økonomi	har	blitt	vesentlig	bedre	ikke	minst	som	en	følge	av	budsjettforliket	mellom	høyre	eee	fre	fremskrittspartiet	krf	og	venstre	pga.	skattepolitikken	pga.	eee	økningen	av	eee	grunnbeløpet	til	gifte	og	samboende	og	økningen	til	minspensjonistene	trygdeoppgjøret	gjennomføres	jo	som	før	vi	har	jo	hatt	trygdeoppgjør	hvor	man	diskuterer	både	disse	spørsmålene	men	også	andre	spørsmål	som	som	pensjonistene	er	opptatt	av	og	det	skal	man	jo	fortsette	med	forskjellen	i	år	sammenliknet	med	i	fjor	er	at	man	ikke	flytter	pengene	fysisk	fra	finansdepartementets	budsjettpost	til	arbeids	og	sosialdepartementets	budsjettpost	f	ordi	det	gjorde	man	allerede	i	budsjettet	så	jeg	er	opptatt	av	at	pensjonistene	de	skal	ha	god	økonomi	og	de	skal	ha	en	god	inntektsutvikling	akkurat	nå	så	er	det	en	vanskelig	situasjon	ikke	minst	pga.	økonomien	f	for	øvrig	men	stortinget	e	blir	invitert	til	høsten	i	forbindelse	med	budsjettet	og	diskuterer	også	andre	spørsmål	som	pensjonistene	er	opptatt	av	spørsmål	nummer	19	fra	representanten	martin	henriksen	til	kulturminister	linda	k	hofstad	helleland	henriksen	president	det	store	flertallet	i	norge	ønsker	å	beholde	søndagen	som	en	annerledes	dag	da	regjeringa	for	to	år	siden	ville	liberalisere	heldigdagsfredsloven	fikk	til	en	klar	beskjed	om	at	verken	arbeidsgivere	eller	arbeidstakere	i	bransjen	sjøl	ønska	å	søndagsåpne	flere	butikker	likevel	har	statsråden	signalisert	at	hun	ønsker	å	utrede	loven	på	nytt	hvorfor	vil	statsråden	skape	en	ny	usikkerhet	og	bruke	ressurser	på	ei	utredning	kort	tid	etter	den	forrige	i	stedet	for	å	sørge	for	at	dagens	lovverk	overholdes	og	håndheves	statsråd	helleland	qqq	ja	president	på	initiativ	fra	bl.a.	handel	og	kontor	så	hadde	jeg	et	hastemøte	6.	mai	der	tema	var	søndags	åpne	butikker	og	på	det	her	møtet	så	stilte	eee	representanter	både	fra	handel	og	kontor	fra	virke	fra	nho	handel	samfu	og	i	tillegg	til	remae	1000	så	var	også	norgesgruppen	og	og	cop	til	stede	der	uttalte	de	fleste	av	aktørene	som	var	der	et	stort	behov	for	bedre	kunnskapsgrunnlag	og	en	nærmere	utredning	av	spørsmålet	om	endring	i	regelverket	om	søndagsåpne	butikker	på	mitt	spørsmål	om	loven	i	dag	var	uklar	eller	eee	om	det	var	vanskelig	å	forstå	loven	så	svarte	alle	nei	likevel	sa	de	repre ...
# RATIO 	 0.6190476190476191
# --------------
# CORPUS	søndagshandel	og	søndagsåpent.	Det	gir	jo	visse	utfordringer.	Regjeringens	forslag	ville	ført	til	mindre	konkurransevridning.	Jeg	kunne	ønsket	at	vi	kunne	endret	regelverket	i	tråd	med	det,	og	synes	egentlig	at	dagens	ordning	ikke	er	optimal.	Nå	sier	kulturministeren	at	hun	ønsker	hun	kunne	endret	regelverket.	Når	hun	viser	til	tidligere	oppkonstruerte	problemstillinger,	er	det	slik	at	en	problemstilling	som	ikke	er	oppkonstruert,	er	at	en	del	av	sektoren	hun	er	ansvarlig	for,	nemlig	frivilligheten	og	idretten,	er	tydelig	på	at	de	ikke	ønsker	liberalisering	som	fører	til	flere	søndagsåpne	butikker.	De	er	avhengig	av	at	folk	kan	stille	opp	som	fotballdommere,	lagledere	og	kursledere	også	på	søndagen	i	helgene.	Har	kulturministeren	tenkt	over	forholdene	for	norsk	frivillighet	og	idrett	når	hun	nå	signaliserer	at	hun	ønsker	en	ny	utredning	og	dermed	også	endringer	i	søndagsåpent?	Det	må	være	en	misforståelse	når	representanten	Henriksen	viser	til	at	jeg	vil	endre	lovverket.	Det	er	ikke	mulig	å	endre	lovverket	slik	det	politiske	flertallet	på	Stortinget	er	satt	sammen	i	dag.	Det	tar	regjeringen	konsekvensen	av,	og	derfor	fremmer	vi	ikke	noe	forslag	om	noen	liberalisering.	Det	vil	jeg	bare	gjøre	helt	klart	ikke	kommer	til	å	skje.	Jeg	har	stor	forståelse	for	at	mange	ønsker	å	holde	søndagen	som	annerledesdag	og	ikke	handle,	og	jeg	ser	at	veldig	mange	bruker	søndagen	til	å	handle.	Når	jeg	er	innom	de	såkalte	Brustad-buene,	er	det	kø	og	massevis	av	folk	i	de	fleste	butikkene.	Så	det	er	noen	i	Norge	som	ønsker	å	få	lov	til	å	handle	på	søndager.	Problemet	med	regelverket	i	dag	er	at	det	er	konkurransevridende.	Det	er	synd,	men	jeg	må	ta	konsekvens	av	flertallet	i	Stortinget,	og	det	betyr	ingen	liberalisering	sånn	som	det	er	i	dag.	Jeg	tillater	meg	å	stille	følgende	spørsmål
# SEGMENT	eee	og	det	gir	jo	visse	utfordringer	regjeringas	forslag	har	f	ville	ha	ført	til	mindre	konkurranseutridning	jeg	kunne	ønske	at	vi	kunne	ha	endra	regelverket	i	i	tråd	med	det	og	syns	egentlig	at	e	qqq	dagens	eee	ordning	er	ikke	optimal	president	nå	sier	jo	eee	kulturministeren	tun	kulturministeren	at	hun	ønsker	å	kunne	endra	regelverket	når	dun	viser	til	tidligere	oppkonstruerte	problemstilling	så	er	det	jo	at	ei	problemstilling	som	ikke	er	oppkonstruert	er	at	en	del	av	den	sektoren	o	er	ansvarlig	for	nemlig	frivilligheten	eee	og	idretten	de	har	vært	tydelige	på	at	de	ikke	ønsker	ei	liberalisering	eee	som	fører	til	flere	søndagsåpne	butikker	de	er	avhengige	av	at	folk	kan	stille	opp	som	fotballdommere	lagledere	og	kursledere	også	på	søndagen	eee	i	helgen	har	kulturministeren	tenkt	over	forholdene	for	norsk	frivillighet	og	idrett	når	hun	nå	signaliserer	at	hun	ønsker	ei	ny	utredning	eee	og	dermed	også	endringer	i	eee	søndagsåpenrådla	eee	president	det	må	være	en	en	misforståelse	da	som	eventuelt	eee	når	eventuelt	eee	når	når	representanten	henriksen	viser	til	at	jeg	vil	endre	lovverket	det	er	ikke	mulig	å	endre	lovverket	slik	det	politiske	flertallet	i	stortinget	har	satt	sammen	i	dag	det	tar	regjeringa	konsekvensen	av	og	derfor	fremmer	vi	ikke	noe	forslag	om	noen	liberalisering	så	det	vil	jeg	bare	gjøre	helt	klart	president	at	det	kjem	ikke	til	å	skjeså	har	jeg	stor	forståelse	for	at	mange	ønsker	å	holde	eee	holde	søndagen	som	man	allerledest	dag	og	ikke	handel	så	ser	jeg	at	veldig	mange	bruker	søndagen	til	å	handle	når	jeg	er	innom	eee	de	såkalte	brusavbuene	så	er	det	jo	kø	eee	og	massevis	av	folk	eee	i	de	fleste	av	de	butikkene	så	det	er	noen	i	norge	som	ønsker	å	få	lov	til	å	å	handle	på	søndager	problemet	med	regelverket	i	dag	er	at	det	er	konkurransevridende	det	er	synd	men	jeg	må	ta	konsekvensene	av	eee	flertallet	i	stortinget	og	det	betyr	ingen	liberalisering	sånn	som	det	er	i	dagda	går	vi	til	spørsmål
# RATIO 	 0.5686274509803921
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS	kan	bare	i	særlige	tilfeller	gi	støtte	til	privatarkiv.	Hva	vil	statsråden	gjøre	for	å	bedre	finansieringen	av	privatarkivarbeidet?»	Privatarkivarbeidet	ivaretas	av	ulike	kulturarvinstitusjoner.	Arkivstatistikken	for	2014	viser	at	bevarte	privatarkiv	utgjør	en	mengde	tilsvarende	en	hylle	på	110	km.	Av	dette	har	Arkivverket	ansvar	for	40	km,	kommunale	og	fylkeskommunale	arkiver	har	27	km,	museene	har	ansvar	for	over	23	km	og	private	arkivinstitusjoner	for	14	km,	så	vi	snakker	betydelig	med	kilometer	arkiv	her.	Arkivverkets	privatarkivarbeid	finansieres	med	årlige	bevilgninger	over	kulturbudsjettet.	I	tillegg	gir	Kulturdepartementet	driftstilskudd	til	museer	og	til	privatarkivinstitusjonene	Misjonsarkivet	og	Arbeiderbevegelsens	arkiv	og	bibliotek	2015	var	det	første	året	Arkivverket	forvaltet	særskilte	arkivutviklingsmidler.	Disse	midlene	finansieres	med	tildeling	fra	spilleoverskuddet	til	Norsk	Tipping.	I	2015	ble	det	fordelt	4	mill.	kr	til	utviklingsprosjekter	for	kommunale	arkiv,	privatarkiv	og	arkiv	i	digital	forvaltning.	Av	dette	tildelte	Arkivverket	1,6	mill.	kr	til	utviklingsprosjekter	for	privatarkiv.	De	4	mill.	kr	som	representanten	Haukeland	Liadal	nevner,	gjelder	altså	fjorårets	tildeling.	Fordelingen	av	spilleoverskuddet	til	kulturformål	for	2016	er	ennå	ikke	foretatt.	Det	vil	være	klart	om	ikke	så	altfor	lenge,	og	jeg	vil	i	den	forbindelse	vurdere	den	økonomiske	rammen	for	arkivutviklingsmidlene,	inkludert	midlene	til	privatarkiv,	som	representanten	Haukeland	Liadal	peker	på.	Jeg	takker	for	svaret.	Museer	kan	i	praksis	ikke	tildeles	støtte	til	privatarkivprosjekter.	Det	gjelder	etter	omorganiseringen	av	Kulturrådet	i	2014,	som	legger	ansvaret	for	privatarkiv	i	museer	under	Kulturrådet,	mens	privatarkiv	i	andre	institusjoner	er	Arkivverkets	ansvar.	Til	tross	for	dette	har	Kulturrådet	uttalt	at	de	ikke	har	faglig	kompetanse	til	å	vurdere	søknader	som	gjelder	privatarkiv	i	museer,	og	Arkivverket	avviser	museene	med	å	vise	til	at	det	er	Kulturrådet	som	forvalter	privatarkivstøtte	til	museer.	Det	er	derfor	ikke	delt	ut	støtte	til	privatarkivarbeidet	i	museer.	Hva	mener	kulturministeren	om	svekkelsen	av	finansieringen	av	privatarkivarbeidet	gjennom	oppsplittingen	av	feltet	mellom	Kulturrådet	og	Arkivverket?	Spillemidlene	til	kulturformål	går	til	en	rekke	formål,	bl.a.	Den	kulturelle	skolesekken	og	Frifond.	Det	er	mye	av	dette	representanten	Haukeland	Liadal	kjenner	godt	til.	Nå	er	fordelingen	av	spillemidlene	mellom	de	enkelte	formålene	ikke	avgjort.	Det	skal	fastsettes	av	Kongen	i	statsråd,	og	det	er	derfor	jeg	ikke	kan	gå	inn	på	finansieringen	her.	Men	til	det	konkrete	spørsmålet	fra	representanten:	Jeg	har	tillit	til	at	det	grunnlaget	som	Arkivverket	skal	bruke	til	å	avgjøre	hvor	mye	som	skal	gå	til	privatarkivarbeidet	i	år,	vil	bli	ivaretatt	på	en	god	og	forsvarlig	måte.	Dette	er	noe	uklart.	Jeg	ser	at	i	perioden	2010–2014	ble	det	i	gjennomsnitt	delt	ut	3,2	mill.	kr	til	privatarkivarbeidet,	og	ifølge	tilbakemeldinger	vi	nå	får	fra	Landslaget	for	lokal-	og	privatarkiv,	er	beløpet	sunket	til	0	kr.	Hva	tenker	statsråden	om	at	Kulturrådet	aldri	har	delt	ut	øremerkede	midler	til	privatarkivarbeidet	i	museer,	slik	Stortinget	forutsatte,	og	at
# SEGMENT	kan	bare	i	særlige	tilfeller	gi	støtte	til	privat	arkiv	så	president	mitt	spørsmål	blir	eee	hva	vil	kulturministenrarund	gjøre	for	å	bedre	finansieringen	av	privatarkivarbeidetstatsråd	helleland	president	p	privatarkivarbeidet	ivaretas	av	ulike	kulturarvinstitusjoner	arkivstatistikken	for	2014	viser	at	bevarte	i	privatarkiv	utgjør	en	mengde	tilsvarende	i	hylle	på	110	km	og	av	det	her	har	arkivverket	ansvar	for	40	km	kommunal	og	fylkeskommunale	arkiv	har	27	km	og	museene	her	ansvaret	for	over	treogtyve	km	og	private	arkivinstitusjoner	for	14	km	så	vi	snakker	betydelig	km	med	arkiv	her	arkivverkets	privat	arkivarbeid	finansieres	med	årlige	bevilgninger	over	kulturbudsjettet	i	tillegg	så	gir	kulturdepartementet	driftstilskudd	til	musea	og	til	privat	arkivinstitusjonene	misjonsarkivet	og	arbeiderbevegelsens	arkiv	og	bibliotek	i	2015	så	var	det	det	første	året	arkivverket	forvalta	særskilte	arkivutviklingsmidler	de	midlene	finansieres	med	tildering	fra	spilloverskuddet	til	norsk	tipping	og	i	2015	så	ble	det	fordelt	fire	millioner	kroner	til	utviklingsprosjekter	for	kommunale	arkiv	privatarkiv	og	arkiv	i	digital	forvaltning	av	det	her	tildelte	arkivverket	en	komma	16	millioner	kroner	til	utviklingsprosjekter	for	privatarkiv	de	fire	millionene	president	som	representanten	liadal	nevner	det	gjelder	altså	for	fjorårets	tildeling	så	fordelinga	av	spilloverskuddet	til	kulturformål	for	2016	president	det	er	ennå	ikke	foretatt	det	vil	være	klart	om	ikke	så	altfor	lenge	og	jeg	vil	da	i	den	forbindelse	vurderer	den	økonomiske	ramma	for	arkivutviklingsmidlene	inkludert	midlene	til	privatarkivet	som	representanten	liadal	peker	pålialpresident	jeg	takker	for	svaret	musier	kan	i	praksis	ikke	tildeles	støtte	til	privatarkivprosjekter	det	etter	omorganiseringen	av	kulturrådet	i	2014	eee	som	eee	ligger	ansvaret	for	privat	arkiv	i	museumer	under	kulturrådet	mens	privatarkiv	i	andre	institusjoner	er	arkivverkets	ansvar	til	tross	for	dette	så	har	kulturrådet	uttalt	at	de	ikke	har	faglig	kompetanse	til	å	vurdere	søknader	som	gjelder	privatarkiv	i	museum	og	arkivverket	avviser	museumene	med	å	vise	til	at	det	er	kulturrådet	som	forvalte	privatarkivstøtte	til	museumer	det	er	derfor	eee	ikke	delt	ut	støtte	til	privatarkivarbeidet	i	museumer	hva	meiner	kulturministeren	om	svekkelsen	av	eee	finansieringen	av	privatarkivarbeidet	gjennom	oppsplittingen	av	feltet	mellom	kulturrådet	og	arkivverket	statsråd	helleland	ja	president	ee	spillemidlene	til	kulturformål	går	jo	til	en	rekke	formål	bl.a.	kulturelle	skolesekken	og	frif	fond	ogee	ja	det	er	mye	av	det	her	som	representanten	liadal	kjenner	godt	til	og	nå	er	jo	da	fordelinga	av	spillemidlene	mellom	de	enkelte	formålene	ikke	avgjort	det	skal	fastsettes	av	kongen	i	statsråd	og	det	derfor	ikke	jeg	kan	gå	inn	på	eee	finansieringa	eee	her	men	eee	til	det	kontr	konkrete	spørsmålet	fra	representanten	president	så	eee	har	jeg	tilliten	til	at	det	grunnlaget	som	arkivverket	skal	avgjøre	hvor	mye	som	skal	gå	til	privark	privatarkivarbeidet	i	år	vil	bli	ivaretatt	på	eee	på	en	god	og	en	forsvarlig	måte	liadalja	president	det	er	noe	uklart	jeg	eee	ser	at	i	perioden	2010	til	2014	så	blei	det	i	gjennomsnitt	delt	ut	3,2	millioner	tre	privatarkivarbeidet	og	tilbakemeldingen	vi	nå	får	fra	landslaget	for	lokal	og	privatarkiv	så	er	beløpet	sunket	til	nullhva	tenker	statsråden	om	at	kulturrådet	aldri	har	delt	ut	øremerka	midler	til	privatarkivarbeidet	i	museumer	sånn	som	stortinget	forutsatte	og	at
# RATIO 	 0.5901639344262295
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------
# CORPUS
# SEGMENT
# RATIO 	 0
# --------------

# %% [markdown]
# ## Re-alignment
#
# We will create a temporary work directory. Using the above list of segments, we will create some files in the data dir of that work directory:

# %%
# %mkdir work
# %mkdir work/data
matcher.make_kaldi_dir(positions, Path('work/data'), Path('.'))

# %% [markdown]
# Here we will create the rest of the required files for the data dir. The `utt2spk` and `spk2utt` will simply assume each segment is a different speaker (for lack of a better solution) and the `reco2file_and_channel` will simply highlight that all the files are mono:

# %%
# %%bash
# cut -f1 -d' ' work/data/segments | awk '{print $1,$1}' > work/data/utt2spk
# cut -f1 -d' ' work/data/wav.scp | awk '{print $1,$1,"A"}' > work/data/reco2file_and_channel
# cp work/data/utt2spk work/data/spk2utt
# export LC_ALL=C
# for f in work/data/* ; do
#     sort -o $f $f
# done

# %% [markdown]
# Next we will run the alignment procedure. This assumes Kaldi is installed in `/opt/kaldi` on the host system. Take a look at the script for more details:

# %%
# !./utils/kaldi_align.sh
# Out:
# ./steps/make_mfcc.sh --nj 2 --mfcc-config conf/mfcc_hires.conf data
# utils/validate_data_dir.sh: Successfully validated data-directory data
# ./steps/make_mfcc.sh [info]: segments file exists: using that.
# ./steps/make_mfcc.sh: Succeeded creating MFCC features for data
# ./steps/compute_cmvn_stats.sh data
# Succeeded creating CMVN stats for data
# ./steps/online/nnet2/extract_ivectors_online.sh --nj 2 data exp/nnet3/extractor ivectors
# filter_scps.pl: warning: some input lines were output to multiple files [OK if splitting per utt]
# filter_scps.pl: warning: some input lines were output to multiple files [OK if splitting per utt]
# ./steps/online/nnet2/extract_ivectors_online.sh: extracting iVectors
# ./steps/online/nnet2/extract_ivectors_online.sh: combining iVectors across jobs
# ./steps/online/nnet2/extract_ivectors_online.sh: done extracting (online) iVectors to ivectors using the extractor in exp/nnet3/extractor.
# WARNING:phonetisaurus-apply:2022-05-18 00:06:28:  No pronunciation for word: 'e'
# ./utils/prepare_lang.sh dict <unk> tmp lang
# Checking dict/silence_phones.txt ...
# --> reading dict/silence_phones.txt
# --> text seems to be UTF-8 or ASCII, checking whitespaces
# --> text contains only allowed whitespaces
# --> dict/silence_phones.txt is OK
#
# Checking dict/optional_silence.txt ...
# --> reading dict/optional_silence.txt
# --> text seems to be UTF-8 or ASCII, checking whitespaces
# --> text contains only allowed whitespaces
# --> dict/optional_silence.txt is OK
#
# Checking dict/nonsilence_phones.txt ...
# --> reading dict/nonsilence_phones.txt
# --> text seems to be UTF-8 or ASCII, checking whitespaces
# --> text contains only allowed whitespaces
# --> dict/nonsilence_phones.txt is OK
#
# Checking disjoint: silence_phones.txt, nonsilence_phones.txt
# --> disjoint property is OK.
#
# Checking dict/lexicon.txt
# --> reading dict/lexicon.txt
# --> text seems to be UTF-8 or ASCII, checking whitespaces
# --> text contains only allowed whitespaces
# --> dict/lexicon.txt is OK
#
# Checking dict/extra_questions.txt ...
# --> dict/extra_questions.txt is empty (this is OK)
# --> SUCCESS [validating dictionary directory dict]
#
# **Creating dict/lexiconp.txt from dict/lexicon.txt
# fstaddselfloops lang/phones/wdisambig_phones.int lang/phones/wdisambig_words.int
# prepare_lang.sh: validating output directory
# utils/validate_lang.pl lang
# Checking existence of separator file
# separator file lang/subword_separator.txt is empty or does not exist, deal in word case.
# Checking lang/phones.txt ...
# --> text seems to be UTF-8 or ASCII, checking whitespaces
# --> text contains only allowed whitespaces
# --> lang/phones.txt is OK
#
# Checking words.txt: #0 ...
# --> text seems to be UTF-8 or ASCII, checking whitespaces
# --> text contains only allowed whitespaces
# --> lang/words.txt is OK
#
# Checking disjoint: silence.txt, nonsilence.txt, disambig.txt ...
# --> silence.txt and nonsilence.txt are disjoint
# --> silence.txt and disambig.txt are disjoint
# --> disambig.txt and nonsilence.txt are disjoint
# --> disjoint property is OK
#
# Checking sumation: silence.txt, nonsilence.txt, disambig.txt ...
# --> found no unexplainable phones in phones.txt
#
# Checking lang/phones/context_indep.{txt, int, csl} ...
# --> text seems to be UTF-8 or ASCII, checking whitespaces
# --> text contains only allowed whitespaces
# --> 15 entry/entries in lang/phones/context_indep.txt
# --> lang/phones/context_indep.int corresponds to lang/phones/context_indep.txt
# --> lang/phones/context_indep.csl corresponds to lang/phones/context_indep.txt
# --> lang/phones/context_indep.{txt, int, csl} are OK
#
# Checking lang/phones/nonsilence.{txt, int, csl} ...
# --> text seems to be UTF-8 or ASCII, checking whitespaces
# --> text contains only allowed whitespaces
# --> 120 entry/entries in lang/phones/nonsilence.txt
# --> lang/phones/nonsilence.int corresponds to lang/phones/nonsilence.txt
# --> lang/phones/nonsilence.csl corresponds to lang/phones/nonsilence.txt
# --> lang/phones/nonsilence.{txt, int, csl} are OK
#
# Checking lang/phones/silence.{txt, int, csl} ...
# --> text seems to be UTF-8 or ASCII, checking whitespaces
# --> text contains only allowed whitespaces
# --> 15 entry/entries in lang/phones/silence.txt
# --> lang/phones/silence.int corresponds to lang/phones/silence.txt
# --> lang/phones/silence.csl corresponds to lang/phones/silence.txt
# --> lang/phones/silence.{txt, int, csl} are OK
#
# Checking lang/phones/optional_silence.{txt, int, csl} ...
# --> text seems to be UTF-8 or ASCII, checking whitespaces
# --> text contains only allowed whitespaces
# --> 1 entry/entries in lang/phones/optional_silence.txt
# --> lang/phones/optional_silence.int corresponds to lang/phones/optional_silence.txt
# --> lang/phones/optional_silence.csl corresponds to lang/phones/optional_silence.txt
# --> lang/phones/optional_silence.{txt, int, csl} are OK
#
# Checking lang/phones/disambig.{txt, int, csl} ...
# --> text seems to be UTF-8 or ASCII, checking whitespaces
# --> text contains only allowed whitespaces
# --> 2 entry/entries in lang/phones/disambig.txt
# --> lang/phones/disambig.int corresponds to lang/phones/disambig.txt
# --> lang/phones/disambig.csl corresponds to lang/phones/disambig.txt
# --> lang/phones/disambig.{txt, int, csl} are OK
#
# Checking lang/phones/roots.{txt, int} ...
# --> text seems to be UTF-8 or ASCII, checking whitespaces
# --> text contains only allowed whitespaces
# --> 33 entry/entries in lang/phones/roots.txt
# --> lang/phones/roots.int corresponds to lang/phones/roots.txt
# --> lang/phones/roots.{txt, int} are OK
#
# Checking lang/phones/sets.{txt, int} ...
# --> text seems to be UTF-8 or ASCII, checking whitespaces
# --> text contains only allowed whitespaces
# --> 33 entry/entries in lang/phones/sets.txt
# --> lang/phones/sets.int corresponds to lang/phones/sets.txt
# --> lang/phones/sets.{txt, int} are OK
#
# Checking lang/phones/extra_questions.{txt, int} ...
# --> text seems to be UTF-8 or ASCII, checking whitespaces
# --> text contains only allowed whitespaces
# --> 9 entry/entries in lang/phones/extra_questions.txt
# --> lang/phones/extra_questions.int corresponds to lang/phones/extra_questions.txt
# --> lang/phones/extra_questions.{txt, int} are OK
#
# Checking lang/phones/word_boundary.{txt, int} ...
# --> text seems to be UTF-8 or ASCII, checking whitespaces
# --> text contains only allowed whitespaces
# --> 135 entry/entries in lang/phones/word_boundary.txt
# --> lang/phones/word_boundary.int corresponds to lang/phones/word_boundary.txt
# --> lang/phones/word_boundary.{txt, int} are OK
#
# Checking optional_silence.txt ...
# --> reading lang/phones/optional_silence.txt
# --> lang/phones/optional_silence.txt is OK
#
# Checking disambiguation symbols: #0 and #1
# --> lang/phones/disambig.txt has "#0" and "#1"
# --> lang/phones/disambig.txt is OK
#
# Checking topo ...
#
# Checking word_boundary.txt: silence.txt, nonsilence.txt, disambig.txt ...
# --> lang/phones/word_boundary.txt doesn't include disambiguation symbols
# --> lang/phones/word_boundary.txt is the union of nonsilence.txt and silence.txt
# --> lang/phones/word_boundary.txt is OK
#
# Checking word-level disambiguation symbols...
# --> lang/phones/wdisambig.txt exists (newer prepare_lang.sh)
# Checking word_boundary.int and disambig.int
# --> generating a 99 word/subword sequence
# --> resulting phone sequence from L.fst corresponds to the word sequence
# --> L.fst is OK
# --> generating a 98 word/subword sequence
# --> resulting phone sequence from L_disambig.fst corresponds to the word sequence
# --> L_disambig.fst is OK
#
# Checking lang/oov.{txt, int} ...
# --> text seems to be UTF-8 or ASCII, checking whitespaces
# --> text contains only allowed whitespaces
# --> 1 entry/entries in lang/oov.txt
# --> lang/oov.int corresponds to lang/oov.txt
# --> lang/oov.{txt, int} are OK
#
# --> lang/L.fst is olabel sorted
# --> lang/L_disambig.fst is olabel sorted
# --> SUCCESS [validating lang directory lang]
# ./steps/nnet3/align.sh --nj 2 --use-gpu false --online-ivector-dir ivectors --beam 100 --retry-beam 400 data lang exp/nnet3/tdnn1a_sp ali
# ./steps/nnet3/align.sh: feature type is raw
# ./steps/nnet3/align.sh: aligning data in data using model from exp/nnet3/tdnn1a_sp, putting alignments in ali
# steps/diagnostic/analyze_alignments.sh --cmd run.pl lang ali
# analyze_phone_length_stats.py: WARNING: optional-silence sp is seen only 50.0% of the time at utterance begin.  This may not be optimal.
# analyze_phone_length_stats.py: WARNING: optional-silence sp is seen only 50.0% of the time at utterance end.  This may not be optimal.
# steps/diagnostic/analyze_alignments.sh: see stats in ali/log/analyze_alignments.log
# ./steps/nnet3/align.sh: done aligning data.
# ./steps/get_train_ctm.sh --use-segments true data lang ali

# %% [markdown]
# The final result of the script is a CTM file stored in the `work/ali` dir. Here is a preview of that file:

# %%
# !head work/ali/ctm
# Out:
# reco000 A 6.38 0.54 poštovane
# reco000 A 6.92 0.67 zastupnice
# reco000 A 7.59 0.03 i
# reco000 A 7.62 0.88 zastupnici
# reco000 A 9.65 0.52 zamolio
# reco000 A 10.17 0.34 bih
# reco000 A 11.33 0.31 prije
# reco000 A 11.64 0.30 nego
# reco000 A 11.94 0.59 se
# reco000 A 13.20 0.34 krene

# %% [markdown]
# It contains a list of words and their location within the file. We will load this file and convert it into 20 second segments again:

# %%
from pathlib import Path
from utils.matching import ctm_to_segments

segments = ctm_to_segments(Path('work/data/wav.scp'), Path('work/ali/ctm'))
print(f'Created {len(segments)} segments...')
# Out:
# Created 54 segments...

# %% [markdown]
# The segments are dumped into a JSON list file again:

# %%
import json
with open('final_segments.json', 'w') as f:
    for seg in segments:
        f.write(json.dumps(seg.to_dict()) + '\n')

# %% [markdown]
# This is the preview of the final segment list:

# %%
# !head final_segments.json
# Out:
# {"file": "/home/guest/PycharmProjects/ParlaSpeechAlignment/sample.wav", "start": 6.38, "end": 8.5, "text": ["po\u0161tovane", "zastupnice", "i", "zastupnici"]}
# {"file": "/home/guest/PycharmProjects/ParlaSpeechAlignment/sample.wav", "start": 9.65, "end": 26.95, "text": ["zamolio", "bih", "prije", "nego", "se", "krene", "sa", "obja\u0161njenjima", "stanke", "koju", "su", "uzeli", "po\u0161tovani", "zastupnici", "da", "omogu\u0107imo", "pravobraniteljici", "za", "osobe", "s", "invaliditetom", "imenovanje", "dakle"]}
# {"file": "/home/guest/PycharmProjects/ParlaSpeechAlignment/sample.wav", "start": 27.96, "end": 46.64, "text": ["pri\u0161li", "bi", "davali", "prisege", "pravobraniteljice", "za", "osobe", "s", "invaliditetom", "koju", "smo", "ju\u010der", "imenovali", "sla\u017eete", "li", "se", "hvala", "nakon", "\u0161to", "pro\u010ditam", "tekst", "prise\u017ee", "pravobraniteljica", "izgovara", "rije\u010d", "prise\u017eem"]}
# {"file": "/home/guest/PycharmProjects/ParlaSpeechAlignment/sample.wav", "start": 47.83, "end": 56.72, "text": ["tekst", "prisege", "glasi", "prise\u017eem", "da", "\u0107u", "se", "u", "svom", "radu", "dr\u017eati", "ustava", "i", "zakona", "po\u0161tovati", "pravni", "poredak"]}
# {"file": "/home/guest/PycharmProjects/ParlaSpeechAlignment/sample.wav", "start": 57.88, "end": 71.48, "text": ["erha", "i", "da", "\u0107u", "svoju", "du\u017enost", "obavljati", "pravi\u010dno", "\u010dasno", "savjesno", "i", "nepristrano", "u", "najboljem", "interesu", "osoba", "s", "invaliditetom", "prise\u017eem", "\u010destitam", "pravobraniteljici"]}
# {"file": "/home/guest/PycharmProjects/ParlaSpeechAlignment/sample.wav", "start": 78.9, "end": 88.81, "text": ["\u010destitam", "pravobraniteljici", "za", "osobe", "s", "invaliditetom", "na", "polo\u017eenoj", "prise\u017ei", "\u017eelim", "da", "ovu", "du\u017enost", "obavlja", "\u010dasno", "odgovorno", "i", "uspje\u0161no", "kao", "i", "do", "sada", "hvala"]}
# {"file": "/home/guest/PycharmProjects/ParlaSpeechAlignment/sample.wav", "start": 92.07, "end": 103.41, "text": ["prelazimo", "na", "daljnji", "dnevni", "red", "zamolio", "bih", "po\u0161tovanu", "zastupnicu", "anku", "mrak", "tarita\u0161", "za", "rije\u010d", "hvala"]}
# {"file": "/home/guest/PycharmProjects/ParlaSpeechAlignment/sample.wav", "start": 106.76, "end": 126.74, "text": ["lijepo", "gospodine", "predsjedni\u010de", "hrvatskoga", "sabora", "po\u0161tovane", "kolegice", "i", "kolege", "u", "ime", "kluba", "haenesa", "i", "haesua", "imali", "smo", "potrebu", "progovoriti", "o", "jednoj", "temi", "ta", "tema", "bi", "mogla", "imati", "radni", "naslov", "kuda", "plovi", "ovaj", "brod", "o", "\u010demu", "je", "zapravo", "rije\u010d", "u", "ovom", "uva\u017eenom"]}
# {"file": "/home/guest/PycharmProjects/ParlaSpeechAlignment/sample.wav", "start": 126.74, "end": 146.35, "text": ["domu", "smo", "u", "petak", "imali", "set", "zakona", "koji", "govori", "o", "ustrojstvu", "novih", "ministarstava", "odnosno", "vlade", "i", "svi", "koji", "smo", "diskutirali", "smo", "apsolutno", "rekli", "da", "nemamo", "nikakav", "problem", "da", "naravno", "oni", "koji", "su", "vladaju\u0107i", "da", "si", "mandatar", "poslo\u017ei", "ministarstva", "i", "vladu", "na", "odgovaraju\u0107i", "na\u010din", "no", "me\u0111utim"]}
# {"file": "/home/guest/PycharmProjects/ParlaSpeechAlignment/sample.wav", "start": 146.35, "end": 166.22, "text": ["desila", "se", "jedna", "neprilika", "da", "li", "slu\u010dajno", "ili", "nekako", "druga\u010dije", "na", "koju", "\u017eelimo", "ukazati", "i", "re\u0107i", "sljede\u0107e", "\u010detrnaest", "listopada", "u", "narodnim", "novinama", "koji", "su", "ovaj", "put", "svoj", "posao", "radili", "vrlo", "brzo", "i", "efikasno", "je", "objavljen", "zakon", "koji", "je", "stupio", "na", "snagu", "petnaestlistopada", "drugim", "rije\u010dima", "s", "petnaest"]}
